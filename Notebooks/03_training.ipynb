# %%
import numpy as np                  # Version: 1.24.3
import pandas as pd                 # Version: 1.5.3
import torch                        # Version: 2.5.1
import torch.nn as nn
from   torch.utils.data import DataLoader, Dataset
import sklearn                      # Version: 1.3.0
from   sklearn.metrics import accuracy_score, precision_score, recall_score, matthews_corrcoef, roc_auc_score
from   sklearn.metrics import precision_recall_curve

# Python version: 3.11.4
import os
import random

# %%
notebook_dir = os.getcwd()
parent_dir   = os.path.dirname(notebook_dir)
target_dir   = os.path.join(parent_dir, "Data")

def log_and_print(msg, file_handle):
    print(msg)
    file_handle.write(msg + "\n")

# %% [markdown]
# ### **Training Models A (S1)**

# %%
# MODEL A: Wildfire Prediction using LSTM-AE and Bi-LSTM-AE on Set 1 (S1)

random.seed(36)
np.random.seed(36)
torch.manual_seed(36)
torch.cuda.manual_seed_all(36)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark     = False
g = torch.Generator().manual_seed(36)

SEQUENCE_LENGTHS = {
    "10_day": 10,
    "2_week": 14,
    "monthly": 30
}

NUMERIC_FEATURES = [
    "NDVI_residual", "NDVI_std", "NDVI_trend", "Solar_de-seasonalized",
    "Temperature_residual", "Humidity_trend", "NDVI_var", "Humidity_residual",
    "NDVI_mean", "Temperature_trend", "Temperature [°C]_max",
    "Solar radiation [Jm2/day]_std", "Relative humidity [%]_mean",
    "Temperature [°C]_mean", "Solar radiation [Jm2/day]_sum"
]

CAT_FEATURE = "State"
TARGET_COL  = "fire"

class WildfireDataset(Dataset):
    def __init__(self, df, sequence_length, only_no_fire=True):
        self.sequence_length = sequence_length
        self.data = df.copy()
        self.features = NUMERIC_FEATURES
        self.cat_feature = CAT_FEATURE
        self.target = df[TARGET_COL].values
        grouped = [group for _, group in df.groupby('State', observed=False)]
        self.sequences = []
        self.targets = []
        for g in grouped:
            for i in range(len(g) - sequence_length):
                num_seq = g[self.features].iloc[i:i + sequence_length].values.astype(np.float32)
                cat_seq = g[self.cat_feature].iloc[i:i + sequence_length]
                cat_seq_encoded = cat_seq.astype('category').cat.codes.values.astype(np.float32).reshape(-1, 1)
                full_seq = np.hstack([num_seq, cat_seq_encoded])
                label = g[TARGET_COL].iloc[i + sequence_length - 1] # It predicts the last day of the sequence as fire/no-fire
                window_labels = g[TARGET_COL].iloc[i : i + sequence_length].values
                if only_no_fire and np.any(window_labels != 0):
                    # skip *any* sequence that contains a fire anywhere
                    continue
                self.sequences.append(full_seq)
                self.targets.append(label)
    def __len__(self):
        return len(self.sequences)
    def __getitem__(self, idx):
        return torch.tensor(self.sequences[idx], dtype=torch.float32), torch.tensor(self.targets[idx], dtype=torch.float32)

class LSTMAutoencoder(nn.Module):
    def __init__(self, input_dim, embedding_dim, layer_sizes, num_states, bidirectional=False, dropout=0.3):
        super().__init__()
        self.embedding = nn.Embedding(num_states, embedding_dim)
        self.embedding_dropout = nn.Dropout(dropout)
        # Encoder
        enc_input_dim = input_dim + embedding_dim
        self.encoder_layers = nn.ModuleList()
        self.encoder_dropouts = nn.ModuleList()
        for h in layer_sizes:
            self.encoder_layers.append(
                nn.LSTM(enc_input_dim, h, batch_first=True, bidirectional=bidirectional)
            )
            self.encoder_dropouts.append(nn.Dropout(dropout))
            enc_input_dim = h * (2 if bidirectional else 1)
        # Decoder
        dec_input_dim = enc_input_dim
        self.decoder_layers = nn.ModuleList()
        self.decoder_dropouts = nn.ModuleList()
        for h in reversed(layer_sizes[:-1]):
            self.decoder_layers.append(
                nn.LSTM(dec_input_dim, h, batch_first=True)
            )
            self.decoder_dropouts.append(nn.Dropout(dropout))
            dec_input_dim = h
        # Final projection
        self.output_layer = nn.Linear(dec_input_dim, input_dim + embedding_dim)
        self.tanh = nn.Tanh()
    def forward(self, x):
        # Embedding
        state_idx = x[..., -1].long()
        emb = self.embedding(state_idx)
        emb = self.embedding_dropout(emb)
        seq = torch.cat([x[..., :-1], emb], dim=-1)
        # Encoder
        out = seq
        for lstm, dropout in zip(self.encoder_layers, self.encoder_dropouts):
            out, _ = lstm(out)
            out = dropout(self.tanh(out))
        # Decoder
        for lstm, dropout in zip(self.decoder_layers, self.decoder_dropouts):
            out, _ = lstm(out)
            out = dropout(self.tanh(out))
        # Output
        decoded = self.output_layer(out)
        decoded = self.tanh(decoded)
        return decoded

def train_one_epoch(model, dataloader, optimizer, criterion):
    model.train()
    total_loss = 0
    for x, _ in dataloader:
        optimizer.zero_grad()
        x_hat = model(x)
        # Trim output and target to match dimensions
        x_hat_trimmed = x_hat[:, :, :-embedding_dim]
        x_trimmed = x[:, :, :-1]
        loss = criterion(x_hat_trimmed, x_trimmed)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(dataloader)

def evaluate_model(model, dataloader):
    model.eval()
    all_labels = []
    all_scores = []
    with torch.no_grad():
        for x, y in dataloader:
            x_hat = model(x)
            # Trim output and target to match dimensions
            x_hat_trimmed = x_hat[:, :, :-embedding_dim]
            x_trimmed = x[:, :, :-1]
            re = ((x_hat_trimmed - x_trimmed) ** 2).mean(dim=(1, 2))
            all_scores.extend(re.numpy())
            all_labels.extend(y.numpy())
    return np.array(all_scores), np.array(all_labels)

def compute_metrics(y_true, y_scores, threshold=None):
    if threshold is None:
        threshold = np.percentile(y_scores[y_true == 0], 95)
    y_pred = (y_scores > threshold).astype(int)
    metrics = {
        "ACC": accuracy_score(y_true, y_pred),
        "PRE": precision_score(y_true, y_pred, zero_division=0),
        "REC": recall_score(y_true, y_pred, zero_division=0),
        "MCC": matthews_corrcoef(y_true, y_pred),
    }
    metrics["AUC"] = roc_auc_score(y_true, y_scores)
    return metrics, threshold

def find_best_f1_threshold(y_true, y_scores):
    precision, recall, thresholds = precision_recall_curve(y_true, y_scores)
    f1_scores = 2 * (precision * recall) / (precision + recall + 1e-8)
    best_idx = np.argmax(f1_scores)
    return thresholds[best_idx], f1_scores[best_idx]

STATES_ORDER = [
    "Australian Capital Territory", "New South Wales", "Tasmania", "Western Australia"
]
s1_train = pd.read_csv(os.path.join(target_dir, "S1_scaled_train.csv"))
s1_train["State"]      = pd.Categorical(s1_train["State"], categories=STATES_ORDER, ordered=True)
s1_train["State_Code"] = s1_train["State"].cat.codes

logs_dir_s1 = os.path.join(target_dir, "00_1_training", "Model_A")

input_dim = len(NUMERIC_FEATURES)
embedding_dim = 4
hidden_dim = 32
num_states = s1_train[CAT_FEATURE].nunique()
layer_sizes = [256, 128, 64, 32, 16]
dropout = 0.1

s1_train["Year"] = pd.to_datetime(s1_train["Date"]).dt.year # type: ignore
years = list(range(2005, 2017))
for model_type in ["LSTM-AE", "Bi-LSTM-AE"]:
    for seq_name, seq_len in SEQUENCE_LENGTHS.items():
        print(f"Training {model_type} with sequence length: {seq_name}")
        for i in range(len(years) - 1):
            val_years   = [years[i], years[i + 1]]
            train_years = [y for y in years if y not in val_years]

            fold_train = s1_train[s1_train["Year"].isin(train_years)]
            fold_val   = s1_train[s1_train["Year"].isin(val_years)]
            
            train_ds = WildfireDataset(fold_train, seq_len, only_no_fire=True)
            val_ds = WildfireDataset(fold_val, seq_len, only_no_fire=False)

            train_loader = DataLoader(train_ds, batch_size=64, shuffle=True, generator = g)
            val_loader = DataLoader(val_ds, batch_size=64, shuffle=False)

            model = LSTMAutoencoder(
                input_dim, embedding_dim, layer_sizes, num_states,
                bidirectional=(model_type == "Bi-LSTM-AE"), dropout=dropout
            )
            optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
            criterion = nn.MSELoss()

            best_score = -float('inf')
            smoothed_best_score = -float('inf')
            min_epoch = 15
            patience, counter = 10, 0

            best_metrics = None
            best_threshold = None
            best_epoch = 0

            # Log path
            log_dir = os.path.join(logs_dir_s1, f"{model_type}")
            log_path = os.path.join(log_dir, f"01_train_{seq_name}_log.txt")

            smoothing_alpha = 0.1 # smoothing factor for exponential moving average
            smoothed_score = None

            with open(log_path, 'a') as f:
                log_and_print(f"\n{'='*50}", f)
                log_and_print(f"Training {model_type} with sequence length: {seq_name} | Fold {i+1} (years: {val_years})", f)
                for epoch in range(1, 201):
                    loss = train_one_epoch(model, train_loader, optimizer, criterion)
                    val_scores, val_labels = evaluate_model(model, val_loader)
                    threshold, _ = find_best_f1_threshold(val_labels, val_scores)
                    val_metrics, _ = compute_metrics(val_labels, val_scores, threshold)

                    val_loss = np.mean(val_scores)

                    mcc = val_metrics["MCC"]
                    rec = val_metrics["REC"]
                    pre = val_metrics["PRE"]
                    auc = val_metrics["AUC"]

                    scaled_mcc = (mcc + 1) / 2   # MCC: [-1, 1] → [0, 1]
                    scaled_auc = (auc - 0.5) * 2 # AUC: [0.5, 1] → [0, 1]

                    combo_score = 0.6 * scaled_mcc + 0.05 * rec + 0.05 * pre + 0.05 * scaled_auc
                    if smoothed_score is None:
                        smoothed_score = combo_score
                    else:
                        smoothed_score = (smoothing_alpha * combo_score + (1 - smoothing_alpha) * smoothed_score)

                    log_and_print(f"Epoch {epoch:02d} | Train loss: {loss:.5f} | Val loss: {val_loss:.5f} | "
                                f"Combo score: {combo_score:.3f} | Smoothed: {smoothed_score:.3f} | "
                                f"MCC: {mcc:.3f} | REC: {rec:.3f} | PRE: {pre:.3f} | AUC: {auc:.3f} | Threshold: {threshold:.5f}", f)

                    if combo_score > best_score or smoothed_score > smoothed_best_score:
                        smoothed_best_score = smoothed_score
                        counter = 0
                        # Always track best model based on raw combo score
                        if combo_score > best_score:
                            best_score = combo_score
                            best_metrics = val_metrics
                            best_threshold = threshold
                            best_epoch = epoch
                            torch.save(model.state_dict(), os.path.join(log_dir, f"01_train_{seq_name}_fold{i+1}_best_model.pt"))
                    # Early stopping kicks in only after min_epoch
                    elif epoch >= min_epoch:
                        counter += 1
                        if counter >= patience:
                            log_and_print(f"Early stopping at epoch {epoch:02d} (no improvement in smoothed or combo score over {patience} epochs)", f)
                            break

                # Summary logging
                log_and_print(f"\n--- Fold {i+1} summary (years: {val_years}) ---", f)
                print(f"Number of fire events in validation: ({(val_labels == 1).sum()} / {len(val_labels)})") # type: ignore
                log_and_print(f"Best epoch: {best_epoch}", f)
                if best_threshold is not None:
                    log_and_print(f"Threshold used: {best_threshold:.5f}", f)
                else:
                    log_and_print("Threshold used: N/A", f)
                if best_metrics is not None:
                    log_and_print("Validation metrics:", f)
                    for k, v in best_metrics.items():
                        if k in ["ACC", "PRE", "REC"]:
                            log_and_print(f"{k}: {v * 100:04.1f}%", f)
                        elif k in ["MCC", "AUC"]:
                            log_and_print(f"{k}: {v:.2f}", f)
                else:
                    log_and_print("No metrics saved.", f)

                log_and_print("=" * 50 + "\n", f)

print("Model A training and evaluation complete.")
# Out:
# Training LSTM-AE with sequence length: 10_day
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 1 (years: [2005, 2006])
# Epoch 01 | Train loss: 0.05986 | Val loss: 0.04001 | Combo score: 0.396 | Smoothed: 0.396 | MCC: 0.183 | REC: 0.324 | PRE: 0.156 | AUC: 0.669 | Threshold: 0.09800
# Epoch 02 | Train loss: 0.02144 | Val loss: 0.02132 | Combo score: 0.389 | Smoothed: 0.395 | MCC: 0.111 | REC: 0.755 | PRE: 0.057 | AUC: 0.649 | Threshold: 0.01994
# Epoch 03 | Train loss: 0.01497 | Val loss: 0.01869 | Combo score: 0.413 | Smoothed: 0.397 | MCC: 0.181 | REC: 0.461 | PRE: 0.119 | AUC: 0.803 | Threshold: 0.03129
# Epoch 04 | Train loss: 0.01244 | Val loss: 0.01714 | Combo score: 0.396 | Smoothed: 0.397 | MCC: 0.146 | REC: 0.471 | PRE: 0.093 | AUC: 0.736 | Threshold: 0.02647
# Epoch 05 | Train loss: 0.01161 | Val loss: 0.01642 | Combo score: 0.402 | Smoothed: 0.397 | MCC: 0.158 | REC: 0.471 | PRE: 0.101 | AUC: 0.755 | Threshold: 0.02668
# Epoch 06 | Train loss: 0.01104 | Val loss: 0.01684 | Combo score: 0.427 | Smoothed: 0.400 | MCC: 0.221 | REC: 0.441 | PRE: 0.159 | AUC: 0.808 | Threshold: 0.03197
# Epoch 07 | Train loss: 0.00984 | Val loss: 0.01519 | Combo score: 0.404 | Smoothed: 0.401 | MCC: 0.168 | REC: 0.422 | PRE: 0.117 | AUC: 0.768 | Threshold: 0.02699
# Epoch 08 | Train loss: 0.00850 | Val loss: 0.01302 | Combo score: 0.422 | Smoothed: 0.403 | MCC: 0.213 | REC: 0.441 | PRE: 0.152 | AUC: 0.784 | Threshold: 0.02724
# Epoch 09 | Train loss: 0.00800 | Val loss: 0.01262 | Combo score: 0.425 | Smoothed: 0.405 | MCC: 0.216 | REC: 0.500 | PRE: 0.140 | AUC: 0.783 | Threshold: 0.02385
# Epoch 10 | Train loss: 0.00757 | Val loss: 0.01214 | Combo score: 0.408 | Smoothed: 0.405 | MCC: 0.184 | REC: 0.441 | PRE: 0.126 | AUC: 0.741 | Threshold: 0.02234
# Epoch 11 | Train loss: 0.00733 | Val loss: 0.01195 | Combo score: 0.420 | Smoothed: 0.407 | MCC: 0.212 | REC: 0.451 | PRE: 0.148 | AUC: 0.768 | Threshold: 0.02465
# Epoch 12 | Train loss: 0.00716 | Val loss: 0.01201 | Combo score: 0.421 | Smoothed: 0.408 | MCC: 0.218 | REC: 0.451 | PRE: 0.153 | AUC: 0.759 | Threshold: 0.02597
# Epoch 13 | Train loss: 0.00692 | Val loss: 0.01206 | Combo score: 0.424 | Smoothed: 0.410 | MCC: 0.226 | REC: 0.412 | PRE: 0.174 | AUC: 0.773 | Threshold: 0.02853
# Epoch 14 | Train loss: 0.00668 | Val loss: 0.01112 | Combo score: 0.419 | Smoothed: 0.411 | MCC: 0.212 | REC: 0.422 | PRE: 0.156 | AUC: 0.760 | Threshold: 0.02427
# Epoch 15 | Train loss: 0.00656 | Val loss: 0.01222 | Combo score: 0.427 | Smoothed: 0.412 | MCC: 0.228 | REC: 0.441 | PRE: 0.167 | AUC: 0.783 | Threshold: 0.02853
# Epoch 16 | Train loss: 0.00639 | Val loss: 0.01134 | Combo score: 0.418 | Smoothed: 0.413 | MCC: 0.206 | REC: 0.441 | PRE: 0.145 | AUC: 0.766 | Threshold: 0.02395
# Epoch 17 | Train loss: 0.00628 | Val loss: 0.01092 | Combo score: 0.410 | Smoothed: 0.413 | MCC: 0.193 | REC: 0.451 | PRE: 0.131 | AUC: 0.734 | Threshold: 0.02132
# Epoch 18 | Train loss: 0.00617 | Val loss: 0.01124 | Combo score: 0.429 | Smoothed: 0.414 | MCC: 0.233 | REC: 0.490 | PRE: 0.158 | AUC: 0.771 | Threshold: 0.02379
# Epoch 19 | Train loss: 0.00615 | Val loss: 0.01139 | Combo score: 0.430 | Smoothed: 0.416 | MCC: 0.235 | REC: 0.490 | PRE: 0.160 | AUC: 0.771 | Threshold: 0.02408
# Epoch 20 | Train loss: 0.00604 | Val loss: 0.01101 | Combo score: 0.429 | Smoothed: 0.417 | MCC: 0.233 | REC: 0.490 | PRE: 0.158 | AUC: 0.763 | Threshold: 0.02295
# Epoch 21 | Train loss: 0.00596 | Val loss: 0.01065 | Combo score: 0.412 | Smoothed: 0.417 | MCC: 0.196 | REC: 0.431 | PRE: 0.138 | AUC: 0.744 | Threshold: 0.02266
# Epoch 22 | Train loss: 0.00587 | Val loss: 0.01077 | Combo score: 0.425 | Smoothed: 0.418 | MCC: 0.227 | REC: 0.412 | PRE: 0.174 | AUC: 0.777 | Threshold: 0.02660
# Epoch 23 | Train loss: 0.00578 | Val loss: 0.01095 | Combo score: 0.425 | Smoothed: 0.418 | MCC: 0.228 | REC: 0.431 | PRE: 0.169 | AUC: 0.764 | Threshold: 0.02515
# Epoch 24 | Train loss: 0.00574 | Val loss: 0.01122 | Combo score: 0.425 | Smoothed: 0.419 | MCC: 0.228 | REC: 0.402 | PRE: 0.178 | AUC: 0.780 | Threshold: 0.02823
# Epoch 25 | Train loss: 0.00569 | Val loss: 0.01097 | Combo score: 0.427 | Smoothed: 0.420 | MCC: 0.229 | REC: 0.461 | PRE: 0.162 | AUC: 0.769 | Threshold: 0.02504
# Epoch 26 | Train loss: 0.00559 | Val loss: 0.01085 | Combo score: 0.423 | Smoothed: 0.420 | MCC: 0.227 | REC: 0.412 | PRE: 0.174 | AUC: 0.757 | Threshold: 0.02682
# Epoch 27 | Train loss: 0.00550 | Val loss: 0.01006 | Combo score: 0.414 | Smoothed: 0.419 | MCC: 0.207 | REC: 0.392 | PRE: 0.159 | AUC: 0.740 | Threshold: 0.02390
# Epoch 28 | Train loss: 0.00558 | Val loss: 0.01032 | Combo score: 0.398 | Smoothed: 0.417 | MCC: 0.174 | REC: 0.333 | PRE: 0.142 | AUC: 0.725 | Threshold: 0.02556
# Epoch 29 | Train loss: 0.00542 | Val loss: 0.01014 | Combo score: 0.398 | Smoothed: 0.415 | MCC: 0.174 | REC: 0.333 | PRE: 0.142 | AUC: 0.721 | Threshold: 0.02583
# Epoch 30 | Train loss: 0.00536 | Val loss: 0.01031 | Combo score: 0.405 | Smoothed: 0.414 | MCC: 0.190 | REC: 0.333 | PRE: 0.160 | AUC: 0.738 | Threshold: 0.02748
# Epoch 31 | Train loss: 0.00530 | Val loss: 0.00986 | Combo score: 0.395 | Smoothed: 0.412 | MCC: 0.167 | REC: 0.333 | PRE: 0.135 | AUC: 0.719 | Threshold: 0.02383
# Epoch 32 | Train loss: 0.00525 | Val loss: 0.01001 | Combo score: 0.401 | Smoothed: 0.411 | MCC: 0.173 | REC: 0.422 | PRE: 0.121 | AUC: 0.716 | Threshold: 0.01938
# Epoch 33 | Train loss: 0.00521 | Val loss: 0.00991 | Combo score: 0.396 | Smoothed: 0.410 | MCC: 0.170 | REC: 0.333 | PRE: 0.138 | AUC: 0.719 | Threshold: 0.02380
# Epoch 34 | Train loss: 0.00525 | Val loss: 0.01009 | Combo score: 0.400 | Smoothed: 0.409 | MCC: 0.176 | REC: 0.333 | PRE: 0.144 | AUC: 0.736 | Threshold: 0.02588
# Epoch 35 | Train loss: 0.00530 | Val loss: 0.00974 | Combo score: 0.397 | Smoothed: 0.408 | MCC: 0.173 | REC: 0.333 | PRE: 0.142 | AUC: 0.716 | Threshold: 0.02402
# Epoch 36 | Train loss: 0.00515 | Val loss: 0.01040 | Combo score: 0.407 | Smoothed: 0.408 | MCC: 0.195 | REC: 0.333 | PRE: 0.165 | AUC: 0.735 | Threshold: 0.02924
# Early stopping at epoch 36 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 1 summary (years: [2005, 2006]) ---
# Number of fire events in validation: (102 / 2880)
# Best epoch: 19
# Threshold used: 0.02408
# Validation metrics:
# ACC: 89.1%
# PRE: 16.0%
# REC: 49.0%
# MCC: 0.24
# AUC: 0.77
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 2 (years: [2006, 2007])
# Epoch 01 | Train loss: 0.05972 | Val loss: 0.03838 | Combo score: 0.423 | Smoothed: 0.423 | MCC: 0.247 | REC: 0.293 | PRE: 0.269 | AUC: 0.711 | Threshold: 0.09660
# Epoch 02 | Train loss: 0.02348 | Val loss: 0.01857 | Combo score: 0.433 | Smoothed: 0.424 | MCC: 0.228 | REC: 0.520 | PRE: 0.156 | AUC: 0.807 | Threshold: 0.02936
# Epoch 03 | Train loss: 0.01406 | Val loss: 0.01847 | Combo score: 0.439 | Smoothed: 0.426 | MCC: 0.246 | REC: 0.447 | PRE: 0.193 | AUC: 0.828 | Threshold: 0.03359
# Epoch 04 | Train loss: 0.01231 | Val loss: 0.01620 | Combo score: 0.396 | Smoothed: 0.423 | MCC: 0.162 | REC: 0.309 | PRE: 0.147 | AUC: 0.747 | Threshold: 0.02997
# Epoch 05 | Train loss: 0.01109 | Val loss: 0.01428 | Combo score: 0.385 | Smoothed: 0.419 | MCC: 0.143 | REC: 0.350 | PRE: 0.119 | AUC: 0.690 | Threshold: 0.02498
# Epoch 06 | Train loss: 0.01010 | Val loss: 0.01319 | Combo score: 0.398 | Smoothed: 0.417 | MCC: 0.173 | REC: 0.366 | PRE: 0.142 | AUC: 0.711 | Threshold: 0.02436
# Epoch 07 | Train loss: 0.00851 | Val loss: 0.01110 | Combo score: 0.407 | Smoothed: 0.416 | MCC: 0.193 | REC: 0.350 | PRE: 0.167 | AUC: 0.736 | Threshold: 0.02320
# Epoch 08 | Train loss: 0.00761 | Val loss: 0.01086 | Combo score: 0.414 | Smoothed: 0.416 | MCC: 0.210 | REC: 0.374 | PRE: 0.178 | AUC: 0.735 | Threshold: 0.02192
# Epoch 09 | Train loss: 0.00718 | Val loss: 0.01065 | Combo score: 0.414 | Smoothed: 0.416 | MCC: 0.208 | REC: 0.398 | PRE: 0.168 | AUC: 0.734 | Threshold: 0.01988
# Epoch 10 | Train loss: 0.00693 | Val loss: 0.01023 | Combo score: 0.412 | Smoothed: 0.415 | MCC: 0.201 | REC: 0.447 | PRE: 0.149 | AUC: 0.716 | Threshold: 0.01739
# Epoch 11 | Train loss: 0.00672 | Val loss: 0.01068 | Combo score: 0.415 | Smoothed: 0.415 | MCC: 0.213 | REC: 0.374 | PRE: 0.181 | AUC: 0.732 | Threshold: 0.02179
# Epoch 12 | Train loss: 0.00650 | Val loss: 0.01018 | Combo score: 0.413 | Smoothed: 0.415 | MCC: 0.207 | REC: 0.350 | PRE: 0.184 | AUC: 0.737 | Threshold: 0.02214
# Epoch 13 | Train loss: 0.00640 | Val loss: 0.00944 | Combo score: 0.410 | Smoothed: 0.414 | MCC: 0.205 | REC: 0.358 | PRE: 0.177 | AUC: 0.718 | Threshold: 0.01982
# Epoch 14 | Train loss: 0.00631 | Val loss: 0.01009 | Combo score: 0.415 | Smoothed: 0.414 | MCC: 0.214 | REC: 0.398 | PRE: 0.174 | AUC: 0.723 | Threshold: 0.02203
# Epoch 15 | Train loss: 0.00622 | Val loss: 0.01060 | Combo score: 0.417 | Smoothed: 0.415 | MCC: 0.215 | REC: 0.407 | PRE: 0.173 | AUC: 0.739 | Threshold: 0.02199
# Epoch 16 | Train loss: 0.00607 | Val loss: 0.00957 | Combo score: 0.404 | Smoothed: 0.414 | MCC: 0.193 | REC: 0.301 | PRE: 0.186 | AUC: 0.713 | Threshold: 0.02201
# Epoch 17 | Train loss: 0.00601 | Val loss: 0.00966 | Combo score: 0.413 | Smoothed: 0.414 | MCC: 0.202 | REC: 0.439 | PRE: 0.151 | AUC: 0.725 | Threshold: 0.01795
# Epoch 18 | Train loss: 0.00596 | Val loss: 0.01003 | Combo score: 0.418 | Smoothed: 0.414 | MCC: 0.217 | REC: 0.431 | PRE: 0.168 | AUC: 0.729 | Threshold: 0.01991
# Epoch 19 | Train loss: 0.00589 | Val loss: 0.00985 | Combo score: 0.415 | Smoothed: 0.414 | MCC: 0.208 | REC: 0.447 | PRE: 0.155 | AUC: 0.728 | Threshold: 0.01894
# Epoch 20 | Train loss: 0.00583 | Val loss: 0.00982 | Combo score: 0.419 | Smoothed: 0.415 | MCC: 0.222 | REC: 0.415 | PRE: 0.177 | AUC: 0.734 | Threshold: 0.02089
# Epoch 21 | Train loss: 0.00575 | Val loss: 0.00971 | Combo score: 0.413 | Smoothed: 0.415 | MCC: 0.201 | REC: 0.455 | PRE: 0.147 | AUC: 0.728 | Threshold: 0.01835
# Epoch 22 | Train loss: 0.00573 | Val loss: 0.00970 | Combo score: 0.415 | Smoothed: 0.415 | MCC: 0.208 | REC: 0.431 | PRE: 0.159 | AUC: 0.728 | Threshold: 0.01917
# Epoch 23 | Train loss: 0.00556 | Val loss: 0.00946 | Combo score: 0.408 | Smoothed: 0.414 | MCC: 0.196 | REC: 0.341 | PRE: 0.174 | AUC: 0.730 | Threshold: 0.02143
# Epoch 24 | Train loss: 0.00552 | Val loss: 0.00941 | Combo score: 0.410 | Smoothed: 0.414 | MCC: 0.205 | REC: 0.341 | PRE: 0.183 | AUC: 0.728 | Threshold: 0.02257
# Early stopping at epoch 24 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 2 summary (years: [2006, 2007]) ---
# Number of fire events in validation: (123 / 2880)
# Best epoch: 3
# Threshold used: 0.03359
# Validation metrics:
# ACC: 89.7%
# PRE: 19.3%
# REC: 44.7%
# MCC: 0.25
# AUC: 0.83
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 3 (years: [2007, 2008])
# Epoch 01 | Train loss: 0.05895 | Val loss: 0.02401 | Combo score: 0.391 | Smoothed: 0.391 | MCC: 0.150 | REC: 0.247 | PRE: 0.142 | AUC: 0.764 | Threshold: 0.04693
# Epoch 02 | Train loss: 0.01873 | Val loss: 0.01793 | Combo score: 0.387 | Smoothed: 0.391 | MCC: 0.137 | REC: 0.381 | PRE: 0.097 | AUC: 0.718 | Threshold: 0.02916
# Epoch 03 | Train loss: 0.01702 | Val loss: 0.01753 | Combo score: 0.387 | Smoothed: 0.390 | MCC: 0.147 | REC: 0.258 | PRE: 0.134 | AUC: 0.737 | Threshold: 0.03479
# Epoch 04 | Train loss: 0.01437 | Val loss: 0.01371 | Combo score: 0.406 | Smoothed: 0.392 | MCC: 0.179 | REC: 0.330 | PRE: 0.147 | AUC: 0.786 | Threshold: 0.02969
# Epoch 05 | Train loss: 0.01242 | Val loss: 0.01202 | Combo score: 0.386 | Smoothed: 0.391 | MCC: 0.144 | REC: 0.330 | PRE: 0.112 | AUC: 0.706 | Threshold: 0.02325
# Epoch 06 | Train loss: 0.01183 | Val loss: 0.01202 | Combo score: 0.395 | Smoothed: 0.392 | MCC: 0.165 | REC: 0.340 | PRE: 0.129 | AUC: 0.722 | Threshold: 0.02489
# Epoch 07 | Train loss: 0.01154 | Val loss: 0.01212 | Combo score: 0.400 | Smoothed: 0.392 | MCC: 0.178 | REC: 0.289 | PRE: 0.160 | AUC: 0.739 | Threshold: 0.02854
# Epoch 08 | Train loss: 0.01075 | Val loss: 0.01028 | Combo score: 0.399 | Smoothed: 0.393 | MCC: 0.183 | REC: 0.268 | PRE: 0.176 | AUC: 0.716 | Threshold: 0.02484
# Epoch 09 | Train loss: 0.00992 | Val loss: 0.01028 | Combo score: 0.401 | Smoothed: 0.394 | MCC: 0.184 | REC: 0.268 | PRE: 0.177 | AUC: 0.730 | Threshold: 0.02424
# Epoch 10 | Train loss: 0.00948 | Val loss: 0.00962 | Combo score: 0.402 | Smoothed: 0.395 | MCC: 0.190 | REC: 0.268 | PRE: 0.184 | AUC: 0.726 | Threshold: 0.02391
# Epoch 11 | Train loss: 0.00904 | Val loss: 0.00983 | Combo score: 0.401 | Smoothed: 0.395 | MCC: 0.183 | REC: 0.258 | PRE: 0.181 | AUC: 0.742 | Threshold: 0.02610
# Epoch 12 | Train loss: 0.00876 | Val loss: 0.00964 | Combo score: 0.394 | Smoothed: 0.395 | MCC: 0.176 | REC: 0.247 | PRE: 0.176 | AUC: 0.702 | Threshold: 0.02541
# Epoch 13 | Train loss: 0.00829 | Val loss: 0.00930 | Combo score: 0.398 | Smoothed: 0.395 | MCC: 0.179 | REC: 0.247 | PRE: 0.180 | AUC: 0.731 | Threshold: 0.02850
# Epoch 14 | Train loss: 0.00741 | Val loss: 0.00797 | Combo score: 0.396 | Smoothed: 0.396 | MCC: 0.176 | REC: 0.258 | PRE: 0.171 | AUC: 0.715 | Threshold: 0.02259
# Epoch 15 | Train loss: 0.00698 | Val loss: 0.00788 | Combo score: 0.398 | Smoothed: 0.396 | MCC: 0.178 | REC: 0.258 | PRE: 0.174 | AUC: 0.730 | Threshold: 0.02345
# Epoch 16 | Train loss: 0.00673 | Val loss: 0.00776 | Combo score: 0.398 | Smoothed: 0.396 | MCC: 0.175 | REC: 0.258 | PRE: 0.170 | AUC: 0.742 | Threshold: 0.02228
# Epoch 17 | Train loss: 0.00653 | Val loss: 0.00819 | Combo score: 0.403 | Smoothed: 0.397 | MCC: 0.184 | REC: 0.278 | PRE: 0.172 | AUC: 0.749 | Threshold: 0.02615
# Epoch 18 | Train loss: 0.00641 | Val loss: 0.00760 | Combo score: 0.395 | Smoothed: 0.397 | MCC: 0.175 | REC: 0.258 | PRE: 0.169 | AUC: 0.714 | Threshold: 0.02296
# Epoch 19 | Train loss: 0.00632 | Val loss: 0.00745 | Combo score: 0.398 | Smoothed: 0.397 | MCC: 0.178 | REC: 0.258 | PRE: 0.174 | AUC: 0.727 | Threshold: 0.02447
# Epoch 20 | Train loss: 0.00615 | Val loss: 0.00781 | Combo score: 0.397 | Smoothed: 0.397 | MCC: 0.178 | REC: 0.247 | PRE: 0.179 | AUC: 0.724 | Threshold: 0.02585
# Epoch 21 | Train loss: 0.00611 | Val loss: 0.00759 | Combo score: 0.394 | Smoothed: 0.396 | MCC: 0.178 | REC: 0.258 | PRE: 0.174 | AUC: 0.686 | Threshold: 0.02572
# Epoch 22 | Train loss: 0.00602 | Val loss: 0.00761 | Combo score: 0.422 | Smoothed: 0.399 | MCC: 0.218 | REC: 0.495 | PRE: 0.141 | AUC: 0.747 | Threshold: 0.01511
# Epoch 23 | Train loss: 0.00595 | Val loss: 0.00720 | Combo score: 0.397 | Smoothed: 0.399 | MCC: 0.178 | REC: 0.258 | PRE: 0.174 | AUC: 0.722 | Threshold: 0.02284
# Epoch 24 | Train loss: 0.00592 | Val loss: 0.00795 | Combo score: 0.398 | Smoothed: 0.399 | MCC: 0.183 | REC: 0.247 | PRE: 0.186 | AUC: 0.717 | Threshold: 0.03035
# Epoch 25 | Train loss: 0.00587 | Val loss: 0.00741 | Combo score: 0.394 | Smoothed: 0.398 | MCC: 0.176 | REC: 0.258 | PRE: 0.171 | AUC: 0.698 | Threshold: 0.02384
# Epoch 26 | Train loss: 0.00581 | Val loss: 0.00747 | Combo score: 0.400 | Smoothed: 0.398 | MCC: 0.184 | REC: 0.258 | PRE: 0.182 | AUC: 0.722 | Threshold: 0.02537
# Epoch 27 | Train loss: 0.00582 | Val loss: 0.00732 | Combo score: 0.396 | Smoothed: 0.398 | MCC: 0.175 | REC: 0.258 | PRE: 0.169 | AUC: 0.722 | Threshold: 0.02275
# Epoch 28 | Train loss: 0.00581 | Val loss: 0.00764 | Combo score: 0.397 | Smoothed: 0.398 | MCC: 0.181 | REC: 0.258 | PRE: 0.177 | AUC: 0.705 | Threshold: 0.02737
# Epoch 29 | Train loss: 0.00572 | Val loss: 0.00729 | Combo score: 0.396 | Smoothed: 0.398 | MCC: 0.182 | REC: 0.278 | PRE: 0.170 | AUC: 0.690 | Threshold: 0.02117
# Epoch 30 | Train loss: 0.00564 | Val loss: 0.00786 | Combo score: 0.395 | Smoothed: 0.398 | MCC: 0.179 | REC: 0.247 | PRE: 0.180 | AUC: 0.702 | Threshold: 0.02869
# Epoch 31 | Train loss: 0.00559 | Val loss: 0.00749 | Combo score: 0.397 | Smoothed: 0.398 | MCC: 0.183 | REC: 0.258 | PRE: 0.180 | AUC: 0.707 | Threshold: 0.02448
# Epoch 32 | Train loss: 0.00559 | Val loss: 0.00775 | Combo score: 0.401 | Smoothed: 0.398 | MCC: 0.185 | REC: 0.289 | PRE: 0.169 | AUC: 0.728 | Threshold: 0.02602
# Early stopping at epoch 32 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 3 summary (years: [2007, 2008]) ---
# Number of fire events in validation: (97 / 2884)
# Best epoch: 22
# Threshold used: 0.01511
# Validation metrics:
# ACC: 88.1%
# PRE: 14.1%
# REC: 49.5%
# MCC: 0.22
# AUC: 0.75
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 4 (years: [2008, 2009])
# Epoch 01 | Train loss: 0.06164 | Val loss: 0.03623 | Combo score: 0.461 | Smoothed: 0.461 | MCC: 0.329 | REC: 0.390 | PRE: 0.338 | AUC: 0.760 | Threshold: 0.10130
# Epoch 02 | Train loss: 0.01933 | Val loss: 0.01582 | Combo score: 0.484 | Smoothed: 0.463 | MCC: 0.372 | REC: 0.279 | PRE: 0.551 | AUC: 0.809 | Threshold: 0.03890
# Epoch 03 | Train loss: 0.01315 | Val loss: 0.01283 | Combo score: 0.444 | Smoothed: 0.461 | MCC: 0.276 | REC: 0.228 | PRE: 0.397 | AUC: 0.803 | Threshold: 0.03244
# Epoch 04 | Train loss: 0.01154 | Val loss: 0.01087 | Combo score: 0.445 | Smoothed: 0.460 | MCC: 0.276 | REC: 0.353 | PRE: 0.279 | AUC: 0.808 | Threshold: 0.02574
# Epoch 05 | Train loss: 0.01046 | Val loss: 0.01000 | Combo score: 0.451 | Smoothed: 0.459 | MCC: 0.281 | REC: 0.500 | PRE: 0.219 | AUC: 0.806 | Threshold: 0.02017
# Epoch 06 | Train loss: 0.00893 | Val loss: 0.00786 | Combo score: 0.443 | Smoothed: 0.457 | MCC: 0.276 | REC: 0.257 | PRE: 0.361 | AUC: 0.789 | Threshold: 0.02173
# Epoch 07 | Train loss: 0.00763 | Val loss: 0.00638 | Combo score: 0.432 | Smoothed: 0.455 | MCC: 0.271 | REC: 0.228 | PRE: 0.388 | AUC: 0.695 | Threshold: 0.02082
# Epoch 08 | Train loss: 0.00701 | Val loss: 0.00612 | Combo score: 0.449 | Smoothed: 0.454 | MCC: 0.320 | REC: 0.228 | PRE: 0.508 | AUC: 0.659 | Threshold: 0.02031
# Epoch 09 | Train loss: 0.00653 | Val loss: 0.00548 | Combo score: 0.465 | Smoothed: 0.455 | MCC: 0.340 | REC: 0.228 | PRE: 0.564 | AUC: 0.731 | Threshold: 0.02003
# Epoch 10 | Train loss: 0.00622 | Val loss: 0.00561 | Combo score: 0.467 | Smoothed: 0.456 | MCC: 0.347 | REC: 0.228 | PRE: 0.585 | AUC: 0.720 | Threshold: 0.01917
# Epoch 11 | Train loss: 0.00601 | Val loss: 0.00527 | Combo score: 0.464 | Smoothed: 0.457 | MCC: 0.336 | REC: 0.228 | PRE: 0.554 | AUC: 0.740 | Threshold: 0.01836
# Epoch 12 | Train loss: 0.00583 | Val loss: 0.00515 | Combo score: 0.458 | Smoothed: 0.457 | MCC: 0.323 | REC: 0.228 | PRE: 0.517 | AUC: 0.738 | Threshold: 0.01763
# Epoch 13 | Train loss: 0.00572 | Val loss: 0.00503 | Combo score: 0.452 | Smoothed: 0.457 | MCC: 0.308 | REC: 0.228 | PRE: 0.477 | AUC: 0.744 | Threshold: 0.01655
# Epoch 14 | Train loss: 0.00559 | Val loss: 0.00497 | Combo score: 0.444 | Smoothed: 0.455 | MCC: 0.289 | REC: 0.221 | PRE: 0.441 | AUC: 0.739 | Threshold: 0.01522
# Epoch 15 | Train loss: 0.00550 | Val loss: 0.00487 | Combo score: 0.465 | Smoothed: 0.456 | MCC: 0.336 | REC: 0.228 | PRE: 0.554 | AUC: 0.746 | Threshold: 0.01812
# Epoch 16 | Train loss: 0.00537 | Val loss: 0.00486 | Combo score: 0.462 | Smoothed: 0.457 | MCC: 0.336 | REC: 0.228 | PRE: 0.554 | AUC: 0.724 | Threshold: 0.01860
# Epoch 17 | Train loss: 0.00522 | Val loss: 0.00471 | Combo score: 0.465 | Smoothed: 0.458 | MCC: 0.336 | REC: 0.228 | PRE: 0.554 | AUC: 0.748 | Threshold: 0.01712
# Epoch 18 | Train loss: 0.00506 | Val loss: 0.00444 | Combo score: 0.454 | Smoothed: 0.457 | MCC: 0.320 | REC: 0.228 | PRE: 0.508 | AUC: 0.716 | Threshold: 0.01559
# Epoch 19 | Train loss: 0.00489 | Val loss: 0.00456 | Combo score: 0.466 | Smoothed: 0.458 | MCC: 0.336 | REC: 0.228 | PRE: 0.554 | AUC: 0.761 | Threshold: 0.01705
# Epoch 20 | Train loss: 0.00472 | Val loss: 0.00422 | Combo score: 0.468 | Smoothed: 0.459 | MCC: 0.343 | REC: 0.228 | PRE: 0.574 | AUC: 0.752 | Threshold: 0.01936
# Epoch 21 | Train loss: 0.00456 | Val loss: 0.00402 | Combo score: 0.467 | Smoothed: 0.460 | MCC: 0.343 | REC: 0.228 | PRE: 0.574 | AUC: 0.738 | Threshold: 0.01872
# Epoch 22 | Train loss: 0.00436 | Val loss: 0.00398 | Combo score: 0.469 | Smoothed: 0.461 | MCC: 0.343 | REC: 0.228 | PRE: 0.574 | AUC: 0.755 | Threshold: 0.01684
# Epoch 23 | Train loss: 0.00423 | Val loss: 0.00396 | Combo score: 0.464 | Smoothed: 0.461 | MCC: 0.336 | REC: 0.228 | PRE: 0.554 | AUC: 0.743 | Threshold: 0.01636
# Epoch 24 | Train loss: 0.00406 | Val loss: 0.00380 | Combo score: 0.467 | Smoothed: 0.462 | MCC: 0.340 | REC: 0.228 | PRE: 0.564 | AUC: 0.751 | Threshold: 0.01496
# Early stopping at epoch 24 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 4 summary (years: [2008, 2009]) ---
# Number of fire events in validation: (136 / 2884)
# Best epoch: 2
# Threshold used: 0.03890
# Validation metrics:
# ACC: 95.5%
# PRE: 55.1%
# REC: 27.9%
# MCC: 0.37
# AUC: 0.81
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 5 (years: [2009, 2010])
# Epoch 01 | Train loss: 0.06064 | Val loss: 0.02082 | Combo score: 0.466 | Smoothed: 0.466 | MCC: 0.300 | REC: 0.650 | PRE: 0.211 | AUC: 0.832 | Threshold: 0.02867
# Epoch 02 | Train loss: 0.01892 | Val loss: 0.01724 | Combo score: 0.449 | Smoothed: 0.465 | MCC: 0.262 | REC: 0.656 | PRE: 0.179 | AUC: 0.789 | Threshold: 0.02246
# Epoch 03 | Train loss: 0.01777 | Val loss: 0.01671 | Combo score: 0.412 | Smoothed: 0.459 | MCC: 0.184 | REC: 0.500 | PRE: 0.149 | AUC: 0.744 | Threshold: 0.02256
# Epoch 04 | Train loss: 0.01732 | Val loss: 0.01634 | Combo score: 0.423 | Smoothed: 0.456 | MCC: 0.211 | REC: 0.478 | PRE: 0.176 | AUC: 0.771 | Threshold: 0.02556
# Epoch 05 | Train loss: 0.01375 | Val loss: 0.01344 | Combo score: 0.431 | Smoothed: 0.453 | MCC: 0.234 | REC: 0.461 | PRE: 0.200 | AUC: 0.777 | Threshold: 0.02114
# Epoch 06 | Train loss: 0.01228 | Val loss: 0.01248 | Combo score: 0.460 | Smoothed: 0.454 | MCC: 0.303 | REC: 0.450 | PRE: 0.283 | AUC: 0.825 | Threshold: 0.02511
# Epoch 07 | Train loss: 0.01183 | Val loss: 0.01168 | Combo score: 0.445 | Smoothed: 0.453 | MCC: 0.271 | REC: 0.444 | PRE: 0.246 | AUC: 0.795 | Threshold: 0.02099
# Epoch 08 | Train loss: 0.01058 | Val loss: 0.01047 | Combo score: 0.457 | Smoothed: 0.453 | MCC: 0.301 | REC: 0.444 | PRE: 0.284 | AUC: 0.807 | Threshold: 0.02147
# Epoch 09 | Train loss: 0.00921 | Val loss: 0.00830 | Combo score: 0.424 | Smoothed: 0.451 | MCC: 0.235 | REC: 0.172 | PRE: 0.408 | AUC: 0.748 | Threshold: 0.03041
# Epoch 10 | Train loss: 0.00835 | Val loss: 0.00711 | Combo score: 0.426 | Smoothed: 0.448 | MCC: 0.246 | REC: 0.172 | PRE: 0.437 | AUC: 0.723 | Threshold: 0.02726
# Epoch 11 | Train loss: 0.00746 | Val loss: 0.00645 | Combo score: 0.437 | Smoothed: 0.447 | MCC: 0.265 | REC: 0.172 | PRE: 0.492 | AUC: 0.741 | Threshold: 0.02732
# Epoch 12 | Train loss: 0.00701 | Val loss: 0.00630 | Combo score: 0.432 | Smoothed: 0.445 | MCC: 0.255 | REC: 0.172 | PRE: 0.463 | AUC: 0.732 | Threshold: 0.02410
# Epoch 13 | Train loss: 0.00681 | Val loss: 0.00742 | Combo score: 0.475 | Smoothed: 0.448 | MCC: 0.355 | REC: 0.294 | PRE: 0.505 | AUC: 0.782 | Threshold: 0.02298
# Epoch 14 | Train loss: 0.00662 | Val loss: 0.00552 | Combo score: 0.435 | Smoothed: 0.447 | MCC: 0.265 | REC: 0.172 | PRE: 0.492 | AUC: 0.717 | Threshold: 0.02147
# Epoch 15 | Train loss: 0.00637 | Val loss: 0.00563 | Combo score: 0.447 | Smoothed: 0.447 | MCC: 0.289 | REC: 0.172 | PRE: 0.564 | AUC: 0.734 | Threshold: 0.02367
# Epoch 16 | Train loss: 0.00622 | Val loss: 0.00572 | Combo score: 0.446 | Smoothed: 0.447 | MCC: 0.286 | REC: 0.172 | PRE: 0.554 | AUC: 0.738 | Threshold: 0.02414
# Epoch 17 | Train loss: 0.00613 | Val loss: 0.00514 | Combo score: 0.448 | Smoothed: 0.447 | MCC: 0.286 | REC: 0.172 | PRE: 0.554 | AUC: 0.760 | Threshold: 0.02440
# Epoch 18 | Train loss: 0.00594 | Val loss: 0.00490 | Combo score: 0.444 | Smoothed: 0.447 | MCC: 0.280 | REC: 0.172 | PRE: 0.534 | AUC: 0.744 | Threshold: 0.02117
# Epoch 19 | Train loss: 0.00579 | Val loss: 0.00481 | Combo score: 0.445 | Smoothed: 0.446 | MCC: 0.280 | REC: 0.172 | PRE: 0.534 | AUC: 0.759 | Threshold: 0.02308
# Epoch 20 | Train loss: 0.00561 | Val loss: 0.00493 | Combo score: 0.425 | Smoothed: 0.444 | MCC: 0.224 | REC: 0.361 | PRE: 0.225 | AUC: 0.783 | Threshold: 0.00804
# Epoch 21 | Train loss: 0.00548 | Val loss: 0.00468 | Combo score: 0.440 | Smoothed: 0.444 | MCC: 0.277 | REC: 0.172 | PRE: 0.525 | AUC: 0.719 | Threshold: 0.02077
# Epoch 22 | Train loss: 0.00536 | Val loss: 0.00448 | Combo score: 0.437 | Smoothed: 0.443 | MCC: 0.265 | REC: 0.172 | PRE: 0.492 | AUC: 0.739 | Threshold: 0.01667
# Epoch 23 | Train loss: 0.00509 | Val loss: 0.00438 | Combo score: 0.434 | Smoothed: 0.442 | MCC: 0.263 | REC: 0.172 | PRE: 0.484 | AUC: 0.721 | Threshold: 0.01546
# Epoch 24 | Train loss: 0.00490 | Val loss: 0.00433 | Combo score: 0.431 | Smoothed: 0.441 | MCC: 0.263 | REC: 0.172 | PRE: 0.484 | AUC: 0.693 | Threshold: 0.01620
# Early stopping at epoch 24 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 5 summary (years: [2009, 2010]) ---
# Number of fire events in validation: (180 / 2880)
# Best epoch: 13
# Threshold used: 0.02298
# Validation metrics:
# ACC: 93.8%
# PRE: 50.5%
# REC: 29.4%
# MCC: 0.36
# AUC: 0.78
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 6 (years: [2010, 2011])
# Epoch 01 | Train loss: 0.06167 | Val loss: 0.02861 | Combo score: 0.380 | Smoothed: 0.380 | MCC: 0.145 | REC: 0.167 | PRE: 0.196 | AUC: 0.685 | Threshold: 0.04825
# Epoch 02 | Train loss: 0.01931 | Val loss: 0.01528 | Combo score: 0.428 | Smoothed: 0.385 | MCC: 0.224 | REC: 0.508 | PRE: 0.159 | AUC: 0.779 | Threshold: 0.02414
# Epoch 03 | Train loss: 0.01406 | Val loss: 0.01298 | Combo score: 0.436 | Smoothed: 0.390 | MCC: 0.241 | REC: 0.508 | PRE: 0.174 | AUC: 0.799 | Threshold: 0.02168
# Epoch 04 | Train loss: 0.01254 | Val loss: 0.01251 | Combo score: 0.426 | Smoothed: 0.394 | MCC: 0.216 | REC: 0.523 | PRE: 0.149 | AUC: 0.774 | Threshold: 0.01910
# Epoch 05 | Train loss: 0.01183 | Val loss: 0.01184 | Combo score: 0.451 | Smoothed: 0.399 | MCC: 0.290 | REC: 0.386 | PRE: 0.279 | AUC: 0.806 | Threshold: 0.02293
# Epoch 06 | Train loss: 0.01069 | Val loss: 0.01023 | Combo score: 0.459 | Smoothed: 0.405 | MCC: 0.317 | REC: 0.409 | PRE: 0.305 | AUC: 0.785 | Threshold: 0.02001
# Epoch 07 | Train loss: 0.00925 | Val loss: 0.00945 | Combo score: 0.453 | Smoothed: 0.410 | MCC: 0.303 | REC: 0.447 | PRE: 0.265 | AUC: 0.763 | Threshold: 0.01785
# Epoch 08 | Train loss: 0.00867 | Val loss: 0.00994 | Combo score: 0.450 | Smoothed: 0.414 | MCC: 0.288 | REC: 0.386 | PRE: 0.276 | AUC: 0.807 | Threshold: 0.02202
# Epoch 09 | Train loss: 0.00822 | Val loss: 0.00880 | Combo score: 0.463 | Smoothed: 0.419 | MCC: 0.319 | REC: 0.371 | PRE: 0.333 | AUC: 0.823 | Threshold: 0.02002
# Epoch 10 | Train loss: 0.00772 | Val loss: 0.01021 | Combo score: 0.444 | Smoothed: 0.421 | MCC: 0.265 | REC: 0.409 | PRE: 0.234 | AUC: 0.820 | Threshold: 0.02605
# Epoch 11 | Train loss: 0.00747 | Val loss: 0.00869 | Combo score: 0.465 | Smoothed: 0.426 | MCC: 0.322 | REC: 0.409 | PRE: 0.312 | AUC: 0.825 | Threshold: 0.02256
# Epoch 12 | Train loss: 0.00725 | Val loss: 0.00815 | Combo score: 0.469 | Smoothed: 0.430 | MCC: 0.331 | REC: 0.417 | PRE: 0.322 | AUC: 0.823 | Threshold: 0.02046
# Epoch 13 | Train loss: 0.00705 | Val loss: 0.00825 | Combo score: 0.473 | Smoothed: 0.434 | MCC: 0.340 | REC: 0.439 | PRE: 0.320 | AUC: 0.825 | Threshold: 0.02085
# Epoch 14 | Train loss: 0.00702 | Val loss: 0.00824 | Combo score: 0.490 | Smoothed: 0.440 | MCC: 0.381 | REC: 0.432 | PRE: 0.390 | AUC: 0.843 | Threshold: 0.02322
# Epoch 15 | Train loss: 0.00691 | Val loss: 0.00793 | Combo score: 0.477 | Smoothed: 0.444 | MCC: 0.352 | REC: 0.402 | PRE: 0.366 | AUC: 0.830 | Threshold: 0.02405
# Epoch 16 | Train loss: 0.00673 | Val loss: 0.00803 | Combo score: 0.475 | Smoothed: 0.447 | MCC: 0.344 | REC: 0.432 | PRE: 0.331 | AUC: 0.833 | Threshold: 0.02119
# Epoch 17 | Train loss: 0.00665 | Val loss: 0.00792 | Combo score: 0.476 | Smoothed: 0.450 | MCC: 0.348 | REC: 0.402 | PRE: 0.358 | AUC: 0.835 | Threshold: 0.02320
# Epoch 18 | Train loss: 0.00653 | Val loss: 0.00807 | Combo score: 0.484 | Smoothed: 0.453 | MCC: 0.364 | REC: 0.402 | PRE: 0.387 | AUC: 0.849 | Threshold: 0.02579
# Epoch 19 | Train loss: 0.00643 | Val loss: 0.00760 | Combo score: 0.478 | Smoothed: 0.455 | MCC: 0.355 | REC: 0.417 | PRE: 0.359 | AUC: 0.821 | Threshold: 0.02188
# Epoch 20 | Train loss: 0.00631 | Val loss: 0.00731 | Combo score: 0.474 | Smoothed: 0.457 | MCC: 0.347 | REC: 0.386 | PRE: 0.370 | AUC: 0.824 | Threshold: 0.02309
# Epoch 21 | Train loss: 0.00623 | Val loss: 0.00744 | Combo score: 0.482 | Smoothed: 0.460 | MCC: 0.366 | REC: 0.409 | PRE: 0.383 | AUC: 0.826 | Threshold: 0.02139
# Epoch 22 | Train loss: 0.00619 | Val loss: 0.00747 | Combo score: 0.482 | Smoothed: 0.462 | MCC: 0.365 | REC: 0.386 | PRE: 0.402 | AUC: 0.833 | Threshold: 0.02403
# Epoch 23 | Train loss: 0.00613 | Val loss: 0.00725 | Combo score: 0.481 | Smoothed: 0.464 | MCC: 0.361 | REC: 0.455 | PRE: 0.343 | AUC: 0.830 | Threshold: 0.02092
# Epoch 24 | Train loss: 0.00606 | Val loss: 0.00744 | Combo score: 0.472 | Smoothed: 0.465 | MCC: 0.342 | REC: 0.432 | PRE: 0.328 | AUC: 0.820 | Threshold: 0.02135
# Epoch 25 | Train loss: 0.00601 | Val loss: 0.00738 | Combo score: 0.472 | Smoothed: 0.466 | MCC: 0.341 | REC: 0.409 | PRE: 0.342 | AUC: 0.818 | Threshold: 0.02198
# Epoch 26 | Train loss: 0.00601 | Val loss: 0.00726 | Combo score: 0.466 | Smoothed: 0.466 | MCC: 0.329 | REC: 0.409 | PRE: 0.323 | AUC: 0.809 | Threshold: 0.01984
# Epoch 27 | Train loss: 0.00588 | Val loss: 0.00775 | Combo score: 0.480 | Smoothed: 0.467 | MCC: 0.360 | REC: 0.394 | PRE: 0.385 | AUC: 0.831 | Threshold: 0.02795
# Epoch 28 | Train loss: 0.00584 | Val loss: 0.00694 | Combo score: 0.474 | Smoothed: 0.468 | MCC: 0.349 | REC: 0.386 | PRE: 0.372 | AUC: 0.814 | Threshold: 0.02223
# Epoch 29 | Train loss: 0.00582 | Val loss: 0.00703 | Combo score: 0.471 | Smoothed: 0.468 | MCC: 0.342 | REC: 0.402 | PRE: 0.349 | AUC: 0.813 | Threshold: 0.02078
# Epoch 30 | Train loss: 0.00584 | Val loss: 0.00694 | Combo score: 0.479 | Smoothed: 0.469 | MCC: 0.360 | REC: 0.409 | PRE: 0.372 | AUC: 0.820 | Threshold: 0.02033
# Epoch 31 | Train loss: 0.00579 | Val loss: 0.00698 | Combo score: 0.478 | Smoothed: 0.470 | MCC: 0.357 | REC: 0.432 | PRE: 0.352 | AUC: 0.818 | Threshold: 0.01989
# Epoch 32 | Train loss: 0.00572 | Val loss: 0.00701 | Combo score: 0.481 | Smoothed: 0.471 | MCC: 0.360 | REC: 0.386 | PRE: 0.392 | AUC: 0.838 | Threshold: 0.02321
# Epoch 33 | Train loss: 0.00568 | Val loss: 0.00722 | Combo score: 0.460 | Smoothed: 0.470 | MCC: 0.314 | REC: 0.386 | PRE: 0.315 | AUC: 0.811 | Threshold: 0.01962
# Epoch 34 | Train loss: 0.00567 | Val loss: 0.00743 | Combo score: 0.485 | Smoothed: 0.472 | MCC: 0.371 | REC: 0.402 | PRE: 0.398 | AUC: 0.834 | Threshold: 0.02645
# Epoch 35 | Train loss: 0.00558 | Val loss: 0.00699 | Combo score: 0.479 | Smoothed: 0.472 | MCC: 0.360 | REC: 0.402 | PRE: 0.379 | AUC: 0.822 | Threshold: 0.02276
# Epoch 36 | Train loss: 0.00554 | Val loss: 0.00730 | Combo score: 0.483 | Smoothed: 0.473 | MCC: 0.369 | REC: 0.386 | PRE: 0.408 | AUC: 0.822 | Threshold: 0.02520
# Epoch 37 | Train loss: 0.00557 | Val loss: 0.00712 | Combo score: 0.477 | Smoothed: 0.474 | MCC: 0.352 | REC: 0.409 | PRE: 0.360 | AUC: 0.830 | Threshold: 0.02184
# Epoch 38 | Train loss: 0.00548 | Val loss: 0.00696 | Combo score: 0.477 | Smoothed: 0.474 | MCC: 0.352 | REC: 0.394 | PRE: 0.371 | AUC: 0.829 | Threshold: 0.02247
# Epoch 39 | Train loss: 0.00545 | Val loss: 0.00723 | Combo score: 0.474 | Smoothed: 0.474 | MCC: 0.341 | REC: 0.447 | PRE: 0.317 | AUC: 0.831 | Threshold: 0.02086
# Epoch 40 | Train loss: 0.00542 | Val loss: 0.00764 | Combo score: 0.479 | Smoothed: 0.474 | MCC: 0.357 | REC: 0.402 | PRE: 0.373 | AUC: 0.833 | Threshold: 0.02444
# Epoch 41 | Train loss: 0.00536 | Val loss: 0.00788 | Combo score: 0.465 | Smoothed: 0.474 | MCC: 0.322 | REC: 0.409 | PRE: 0.312 | AUC: 0.826 | Threshold: 0.02387
# Epoch 42 | Train loss: 0.00538 | Val loss: 0.00751 | Combo score: 0.486 | Smoothed: 0.475 | MCC: 0.373 | REC: 0.402 | PRE: 0.402 | AUC: 0.840 | Threshold: 0.02750
# Epoch 43 | Train loss: 0.00532 | Val loss: 0.00751 | Combo score: 0.477 | Smoothed: 0.475 | MCC: 0.350 | REC: 0.394 | PRE: 0.369 | AUC: 0.835 | Threshold: 0.02533
# Epoch 44 | Train loss: 0.00536 | Val loss: 0.00706 | Combo score: 0.482 | Smoothed: 0.476 | MCC: 0.366 | REC: 0.402 | PRE: 0.390 | AUC: 0.828 | Threshold: 0.02371
# Epoch 45 | Train loss: 0.00530 | Val loss: 0.00701 | Combo score: 0.478 | Smoothed: 0.476 | MCC: 0.353 | REC: 0.447 | PRE: 0.335 | AUC: 0.827 | Threshold: 0.01970
# Epoch 46 | Train loss: 0.00527 | Val loss: 0.00709 | Combo score: 0.476 | Smoothed: 0.476 | MCC: 0.352 | REC: 0.409 | PRE: 0.360 | AUC: 0.822 | Threshold: 0.02263
# Epoch 47 | Train loss: 0.00521 | Val loss: 0.00737 | Combo score: 0.476 | Smoothed: 0.476 | MCC: 0.349 | REC: 0.424 | PRE: 0.344 | AUC: 0.829 | Threshold: 0.02414
# Epoch 48 | Train loss: 0.00515 | Val loss: 0.00769 | Combo score: 0.453 | Smoothed: 0.474 | MCC: 0.295 | REC: 0.417 | PRE: 0.270 | AUC: 0.802 | Threshold: 0.02041
# Epoch 49 | Train loss: 0.00516 | Val loss: 0.00689 | Combo score: 0.479 | Smoothed: 0.474 | MCC: 0.358 | REC: 0.402 | PRE: 0.376 | AUC: 0.829 | Threshold: 0.02249
# Epoch 50 | Train loss: 0.00515 | Val loss: 0.00696 | Combo score: 0.477 | Smoothed: 0.475 | MCC: 0.353 | REC: 0.402 | PRE: 0.368 | AUC: 0.828 | Threshold: 0.02218
# Epoch 51 | Train loss: 0.00509 | Val loss: 0.00730 | Combo score: 0.475 | Smoothed: 0.475 | MCC: 0.346 | REC: 0.409 | PRE: 0.351 | AUC: 0.827 | Threshold: 0.02168
# Epoch 52 | Train loss: 0.00511 | Val loss: 0.00693 | Combo score: 0.473 | Smoothed: 0.474 | MCC: 0.344 | REC: 0.439 | PRE: 0.326 | AUC: 0.815 | Threshold: 0.01878
# Epoch 53 | Train loss: 0.00510 | Val loss: 0.00698 | Combo score: 0.472 | Smoothed: 0.474 | MCC: 0.344 | REC: 0.409 | PRE: 0.346 | AUC: 0.815 | Threshold: 0.02134
# Epoch 54 | Train loss: 0.00555 | Val loss: 0.00723 | Combo score: 0.473 | Smoothed: 0.474 | MCC: 0.341 | REC: 0.394 | PRE: 0.354 | AUC: 0.828 | Threshold: 0.02129
# Epoch 55 | Train loss: 0.00529 | Val loss: 0.00712 | Combo score: 0.480 | Smoothed: 0.475 | MCC: 0.362 | REC: 0.386 | PRE: 0.395 | AUC: 0.820 | Threshold: 0.02318
# Epoch 56 | Train loss: 0.00513 | Val loss: 0.00726 | Combo score: 0.477 | Smoothed: 0.475 | MCC: 0.353 | REC: 0.402 | PRE: 0.368 | AUC: 0.826 | Threshold: 0.02320
# Early stopping at epoch 56 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 6 summary (years: [2010, 2011]) ---
# Number of fire events in validation: (132 / 2880)
# Best epoch: 14
# Threshold used: 0.02322
# Validation metrics:
# ACC: 94.3%
# PRE: 39.0%
# REC: 43.2%
# MCC: 0.38
# AUC: 0.84
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 7 (years: [2011, 2012])
# Epoch 01 | Train loss: 0.06096 | Val loss: 0.02234 | Combo score: 0.480 | Smoothed: 0.480 | MCC: 0.364 | REC: 0.423 | PRE: 0.394 | AUC: 0.800 | Threshold: 0.04523
# Epoch 02 | Train loss: 0.01802 | Val loss: 0.01422 | Combo score: 0.462 | Smoothed: 0.478 | MCC: 0.305 | REC: 0.526 | PRE: 0.260 | AUC: 0.815 | Threshold: 0.02253
# Epoch 03 | Train loss: 0.01465 | Val loss: 0.01373 | Combo score: 0.458 | Smoothed: 0.476 | MCC: 0.278 | REC: 0.706 | PRE: 0.186 | AUC: 0.800 | Threshold: 0.01840
# Epoch 04 | Train loss: 0.01331 | Val loss: 0.01275 | Combo score: 0.443 | Smoothed: 0.473 | MCC: 0.256 | REC: 0.479 | PRE: 0.223 | AUC: 0.813 | Threshold: 0.02123
# Epoch 05 | Train loss: 0.01252 | Val loss: 0.01189 | Combo score: 0.418 | Smoothed: 0.467 | MCC: 0.201 | REC: 0.505 | PRE: 0.167 | AUC: 0.742 | Threshold: 0.01657
# Epoch 06 | Train loss: 0.01181 | Val loss: 0.01200 | Combo score: 0.441 | Smoothed: 0.465 | MCC: 0.273 | REC: 0.299 | PRE: 0.339 | AUC: 0.771 | Threshold: 0.02416
# Epoch 07 | Train loss: 0.01109 | Val loss: 0.01129 | Combo score: 0.445 | Smoothed: 0.463 | MCC: 0.278 | REC: 0.289 | PRE: 0.359 | AUC: 0.787 | Threshold: 0.02448
# Epoch 08 | Train loss: 0.01058 | Val loss: 0.01116 | Combo score: 0.445 | Smoothed: 0.461 | MCC: 0.269 | REC: 0.428 | PRE: 0.257 | AUC: 0.799 | Threshold: 0.02097
# Epoch 09 | Train loss: 0.01005 | Val loss: 0.01046 | Combo score: 0.457 | Smoothed: 0.461 | MCC: 0.307 | REC: 0.289 | PRE: 0.415 | AUC: 0.796 | Threshold: 0.02318
# Epoch 10 | Train loss: 0.00924 | Val loss: 0.00893 | Combo score: 0.470 | Smoothed: 0.462 | MCC: 0.331 | REC: 0.459 | PRE: 0.322 | AUC: 0.814 | Threshold: 0.01727
# Epoch 11 | Train loss: 0.00895 | Val loss: 0.00899 | Combo score: 0.474 | Smoothed: 0.463 | MCC: 0.337 | REC: 0.474 | PRE: 0.322 | AUC: 0.827 | Threshold: 0.01757
# Epoch 12 | Train loss: 0.00856 | Val loss: 0.00838 | Combo score: 0.476 | Smoothed: 0.464 | MCC: 0.340 | REC: 0.485 | PRE: 0.321 | AUC: 0.839 | Threshold: 0.01545
# Epoch 13 | Train loss: 0.00825 | Val loss: 0.00840 | Combo score: 0.460 | Smoothed: 0.464 | MCC: 0.301 | REC: 0.448 | PRE: 0.287 | AUC: 0.825 | Threshold: 0.01482
# Epoch 14 | Train loss: 0.00798 | Val loss: 0.00845 | Combo score: 0.487 | Smoothed: 0.466 | MCC: 0.366 | REC: 0.474 | PRE: 0.362 | AUC: 0.850 | Threshold: 0.01689
# Epoch 15 | Train loss: 0.00756 | Val loss: 0.00806 | Combo score: 0.462 | Smoothed: 0.465 | MCC: 0.305 | REC: 0.438 | PRE: 0.298 | AUC: 0.831 | Threshold: 0.01584
# Epoch 16 | Train loss: 0.00744 | Val loss: 0.00784 | Combo score: 0.467 | Smoothed: 0.466 | MCC: 0.319 | REC: 0.433 | PRE: 0.319 | AUC: 0.836 | Threshold: 0.01634
# Epoch 17 | Train loss: 0.00736 | Val loss: 0.00885 | Combo score: 0.482 | Smoothed: 0.467 | MCC: 0.350 | REC: 0.495 | PRE: 0.329 | AUC: 0.852 | Threshold: 0.01712
# Epoch 18 | Train loss: 0.00715 | Val loss: 0.00880 | Combo score: 0.488 | Smoothed: 0.469 | MCC: 0.368 | REC: 0.474 | PRE: 0.365 | AUC: 0.854 | Threshold: 0.01887
# Epoch 19 | Train loss: 0.00702 | Val loss: 0.00831 | Combo score: 0.489 | Smoothed: 0.471 | MCC: 0.369 | REC: 0.479 | PRE: 0.363 | AUC: 0.860 | Threshold: 0.01810
# Epoch 20 | Train loss: 0.00704 | Val loss: 0.00772 | Combo score: 0.490 | Smoothed: 0.473 | MCC: 0.374 | REC: 0.479 | PRE: 0.371 | AUC: 0.854 | Threshold: 0.01664
# Epoch 21 | Train loss: 0.00690 | Val loss: 0.00829 | Combo score: 0.481 | Smoothed: 0.474 | MCC: 0.356 | REC: 0.485 | PRE: 0.342 | AUC: 0.831 | Threshold: 0.01658
# Epoch 22 | Train loss: 0.00684 | Val loss: 0.00783 | Combo score: 0.486 | Smoothed: 0.475 | MCC: 0.360 | REC: 0.505 | PRE: 0.337 | AUC: 0.859 | Threshold: 0.01559
# Epoch 23 | Train loss: 0.00673 | Val loss: 0.00777 | Combo score: 0.483 | Smoothed: 0.476 | MCC: 0.369 | REC: 0.469 | PRE: 0.370 | AUC: 0.807 | Threshold: 0.01775
# Epoch 24 | Train loss: 0.00668 | Val loss: 0.00808 | Combo score: 0.489 | Smoothed: 0.477 | MCC: 0.374 | REC: 0.479 | PRE: 0.371 | AUC: 0.844 | Threshold: 0.01767
# Epoch 25 | Train loss: 0.00659 | Val loss: 0.00747 | Combo score: 0.458 | Smoothed: 0.475 | MCC: 0.313 | REC: 0.428 | PRE: 0.314 | AUC: 0.771 | Threshold: 0.01536
# Epoch 26 | Train loss: 0.00643 | Val loss: 0.00719 | Combo score: 0.427 | Smoothed: 0.471 | MCC: 0.213 | REC: 0.577 | PRE: 0.162 | AUC: 0.767 | Threshold: 0.00946
# Epoch 27 | Train loss: 0.00590 | Val loss: 0.00622 | Combo score: 0.376 | Smoothed: 0.461 | MCC: 0.113 | REC: 0.387 | PRE: 0.121 | AUC: 0.665 | Threshold: 0.00860
# Epoch 28 | Train loss: 0.00570 | Val loss: 0.00622 | Combo score: 0.390 | Smoothed: 0.454 | MCC: 0.159 | REC: 0.314 | PRE: 0.175 | AUC: 0.682 | Threshold: 0.01057
# Epoch 29 | Train loss: 0.00556 | Val loss: 0.00606 | Combo score: 0.356 | Smoothed: 0.444 | MCC: 0.086 | REC: 0.227 | PRE: 0.125 | AUC: 0.630 | Threshold: 0.00984
# Epoch 30 | Train loss: 0.00560 | Val loss: 0.00586 | Combo score: 0.370 | Smoothed: 0.437 | MCC: 0.110 | REC: 0.304 | PRE: 0.131 | AUC: 0.652 | Threshold: 0.00878
# Epoch 31 | Train loss: 0.00537 | Val loss: 0.00567 | Combo score: 0.395 | Smoothed: 0.433 | MCC: 0.120 | REC: 0.820 | PRE: 0.092 | AUC: 0.635 | Threshold: 0.00409
# Epoch 32 | Train loss: 0.00522 | Val loss: 0.00570 | Combo score: 0.384 | Smoothed: 0.428 | MCC: 0.103 | REC: 0.680 | PRE: 0.094 | AUC: 0.640 | Threshold: 0.00496
# Epoch 33 | Train loss: 0.00507 | Val loss: 0.00576 | Combo score: 0.390 | Smoothed: 0.424 | MCC: 0.110 | REC: 0.814 | PRE: 0.089 | AUC: 0.614 | Threshold: 0.00402
# Epoch 34 | Train loss: 0.00499 | Val loss: 0.00561 | Combo score: 0.378 | Smoothed: 0.419 | MCC: 0.091 | REC: 0.701 | PRE: 0.089 | AUC: 0.611 | Threshold: 0.00450
# Early stopping at epoch 34 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 7 summary (years: [2011, 2012]) ---
# Number of fire events in validation: (194 / 2884)
# Best epoch: 20
# Threshold used: 0.01664
# Validation metrics:
# ACC: 91.0%
# PRE: 37.1%
# REC: 47.9%
# MCC: 0.37
# AUC: 0.85
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 8 (years: [2012, 2013])
# Epoch 01 | Train loss: 0.06115 | Val loss: 0.03296 | Combo score: 0.475 | Smoothed: 0.475 | MCC: 0.361 | REC: 0.447 | PRE: 0.407 | AUC: 0.737 | Threshold: 0.06615
# Epoch 02 | Train loss: 0.02099 | Val loss: 0.01692 | Combo score: 0.458 | Smoothed: 0.473 | MCC: 0.282 | REC: 0.789 | PRE: 0.207 | AUC: 0.738 | Threshold: 0.01834
# Epoch 03 | Train loss: 0.01795 | Val loss: 0.01526 | Combo score: 0.410 | Smoothed: 0.467 | MCC: 0.178 | REC: 0.687 | PRE: 0.161 | AUC: 0.641 | Threshold: 0.01522
# Epoch 04 | Train loss: 0.01643 | Val loss: 0.01315 | Combo score: 0.438 | Smoothed: 0.464 | MCC: 0.235 | REC: 0.701 | PRE: 0.192 | AUC: 0.728 | Threshold: 0.01548
# Epoch 05 | Train loss: 0.01369 | Val loss: 0.01121 | Combo score: 0.425 | Smoothed: 0.460 | MCC: 0.205 | REC: 0.732 | PRE: 0.169 | AUC: 0.684 | Threshold: 0.01174
# Epoch 06 | Train loss: 0.01262 | Val loss: 0.01109 | Combo score: 0.461 | Smoothed: 0.460 | MCC: 0.286 | REC: 0.729 | PRE: 0.221 | AUC: 0.781 | Threshold: 0.01334
# Epoch 07 | Train loss: 0.01214 | Val loss: 0.01034 | Combo score: 0.460 | Smoothed: 0.460 | MCC: 0.287 | REC: 0.722 | PRE: 0.224 | AUC: 0.770 | Threshold: 0.01237
# Epoch 08 | Train loss: 0.01187 | Val loss: 0.01027 | Combo score: 0.427 | Smoothed: 0.457 | MCC: 0.227 | REC: 0.415 | PRE: 0.252 | AUC: 0.753 | Threshold: 0.01602
# Epoch 09 | Train loss: 0.01146 | Val loss: 0.00928 | Combo score: 0.445 | Smoothed: 0.456 | MCC: 0.253 | REC: 0.694 | PRE: 0.205 | AUC: 0.738 | Threshold: 0.01112
# Epoch 10 | Train loss: 0.01015 | Val loss: 0.00842 | Combo score: 0.504 | Smoothed: 0.460 | MCC: 0.398 | REC: 0.694 | PRE: 0.331 | AUC: 0.837 | Threshold: 0.01210
# Epoch 11 | Train loss: 0.00874 | Val loss: 0.00751 | Combo score: 0.487 | Smoothed: 0.463 | MCC: 0.358 | REC: 0.609 | PRE: 0.321 | AUC: 0.830 | Threshold: 0.01128
# Epoch 12 | Train loss: 0.00764 | Val loss: 0.00559 | Combo score: 0.430 | Smoothed: 0.460 | MCC: 0.239 | REC: 0.472 | PRE: 0.246 | AUC: 0.725 | Threshold: 0.00837
# Epoch 13 | Train loss: 0.00691 | Val loss: 0.00535 | Combo score: 0.426 | Smoothed: 0.456 | MCC: 0.226 | REC: 0.482 | PRE: 0.231 | AUC: 0.723 | Threshold: 0.00783
# Epoch 14 | Train loss: 0.00663 | Val loss: 0.00520 | Combo score: 0.412 | Smoothed: 0.452 | MCC: 0.208 | REC: 0.387 | PRE: 0.242 | AUC: 0.679 | Threshold: 0.00859
# Epoch 15 | Train loss: 0.00639 | Val loss: 0.00502 | Combo score: 0.423 | Smoothed: 0.449 | MCC: 0.225 | REC: 0.482 | PRE: 0.229 | AUC: 0.699 | Threshold: 0.00728
# Epoch 16 | Train loss: 0.00626 | Val loss: 0.00527 | Combo score: 0.423 | Smoothed: 0.446 | MCC: 0.236 | REC: 0.405 | PRE: 0.266 | AUC: 0.684 | Threshold: 0.00875
# Epoch 17 | Train loss: 0.00617 | Val loss: 0.00487 | Combo score: 0.410 | Smoothed: 0.443 | MCC: 0.208 | REC: 0.377 | PRE: 0.245 | AUC: 0.663 | Threshold: 0.00816
# Epoch 18 | Train loss: 0.00600 | Val loss: 0.00487 | Combo score: 0.410 | Smoothed: 0.439 | MCC: 0.207 | REC: 0.426 | PRE: 0.228 | AUC: 0.654 | Threshold: 0.00747
# Epoch 19 | Train loss: 0.00587 | Val loss: 0.00469 | Combo score: 0.417 | Smoothed: 0.437 | MCC: 0.230 | REC: 0.356 | PRE: 0.280 | AUC: 0.663 | Threshold: 0.00833
# Epoch 20 | Train loss: 0.00574 | Val loss: 0.00454 | Combo score: 0.416 | Smoothed: 0.435 | MCC: 0.224 | REC: 0.356 | PRE: 0.272 | AUC: 0.674 | Threshold: 0.00815
# Epoch 21 | Train loss: 0.00565 | Val loss: 0.00432 | Combo score: 0.413 | Smoothed: 0.433 | MCC: 0.217 | REC: 0.440 | PRE: 0.234 | AUC: 0.647 | Threshold: 0.00655
# Epoch 22 | Train loss: 0.00561 | Val loss: 0.00438 | Combo score: 0.427 | Smoothed: 0.432 | MCC: 0.252 | REC: 0.447 | PRE: 0.267 | AUC: 0.660 | Threshold: 0.00706
# Epoch 23 | Train loss: 0.00550 | Val loss: 0.00444 | Combo score: 0.422 | Smoothed: 0.431 | MCC: 0.231 | REC: 0.489 | PRE: 0.233 | AUC: 0.664 | Threshold: 0.00645
# Epoch 24 | Train loss: 0.00549 | Val loss: 0.00443 | Combo score: 0.409 | Smoothed: 0.429 | MCC: 0.202 | REC: 0.430 | PRE: 0.223 | AUC: 0.659 | Threshold: 0.00658
# Early stopping at epoch 24 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 8 summary (years: [2012, 2013]) ---
# Number of fire events in validation: (284 / 2884)
# Best epoch: 10
# Threshold used: 0.01210
# Validation metrics:
# ACC: 83.2%
# PRE: 33.1%
# REC: 69.4%
# MCC: 0.40
# AUC: 0.84
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 9 (years: [2013, 2014])
# Epoch 01 | Train loss: 0.06062 | Val loss: 0.03010 | Combo score: 0.491 | Smoothed: 0.491 | MCC: 0.401 | REC: 0.474 | PRE: 0.458 | AUC: 0.745 | Threshold: 0.05458
# Epoch 02 | Train loss: 0.01917 | Val loss: 0.01551 | Combo score: 0.452 | Smoothed: 0.487 | MCC: 0.272 | REC: 0.617 | PRE: 0.246 | AUC: 0.775 | Threshold: 0.01954
# Epoch 03 | Train loss: 0.01449 | Val loss: 0.01293 | Combo score: 0.457 | Smoothed: 0.484 | MCC: 0.284 | REC: 0.643 | PRE: 0.249 | AUC: 0.768 | Threshold: 0.01655
# Epoch 04 | Train loss: 0.01300 | Val loss: 0.01200 | Combo score: 0.443 | Smoothed: 0.480 | MCC: 0.257 | REC: 0.604 | PRE: 0.237 | AUC: 0.740 | Threshold: 0.01524
# Epoch 05 | Train loss: 0.01206 | Val loss: 0.01082 | Combo score: 0.449 | Smoothed: 0.477 | MCC: 0.269 | REC: 0.614 | PRE: 0.244 | AUC: 0.758 | Threshold: 0.01409
# Epoch 06 | Train loss: 0.01125 | Val loss: 0.01000 | Combo score: 0.436 | Smoothed: 0.473 | MCC: 0.241 | REC: 0.523 | PRE: 0.244 | AUC: 0.749 | Threshold: 0.01365
# Epoch 07 | Train loss: 0.01030 | Val loss: 0.00782 | Combo score: 0.377 | Smoothed: 0.463 | MCC: 0.114 | REC: 0.503 | PRE: 0.155 | AUC: 0.603 | Threshold: 0.00823
# Epoch 08 | Train loss: 0.00919 | Val loss: 0.00698 | Combo score: 0.386 | Smoothed: 0.456 | MCC: 0.128 | REC: 0.529 | PRE: 0.160 | AUC: 0.632 | Threshold: 0.00727
# Epoch 09 | Train loss: 0.00842 | Val loss: 0.00655 | Combo score: 0.402 | Smoothed: 0.450 | MCC: 0.181 | REC: 0.419 | PRE: 0.216 | AUC: 0.658 | Threshold: 0.00914
# Epoch 10 | Train loss: 0.00806 | Val loss: 0.00620 | Combo score: 0.380 | Smoothed: 0.443 | MCC: 0.132 | REC: 0.425 | PRE: 0.176 | AUC: 0.605 | Threshold: 0.00772
# Epoch 11 | Train loss: 0.00782 | Val loss: 0.00620 | Combo score: 0.399 | Smoothed: 0.439 | MCC: 0.174 | REC: 0.383 | PRE: 0.219 | AUC: 0.663 | Threshold: 0.00921
# Epoch 12 | Train loss: 0.00747 | Val loss: 0.00583 | Combo score: 0.389 | Smoothed: 0.434 | MCC: 0.149 | REC: 0.425 | PRE: 0.189 | AUC: 0.633 | Threshold: 0.00746
# Epoch 13 | Train loss: 0.00726 | Val loss: 0.00589 | Combo score: 0.402 | Smoothed: 0.431 | MCC: 0.181 | REC: 0.422 | PRE: 0.216 | AUC: 0.659 | Threshold: 0.00837
# Epoch 14 | Train loss: 0.00705 | Val loss: 0.00585 | Combo score: 0.403 | Smoothed: 0.428 | MCC: 0.182 | REC: 0.432 | PRE: 0.214 | AUC: 0.658 | Threshold: 0.00806
# Epoch 15 | Train loss: 0.00689 | Val loss: 0.00581 | Combo score: 0.394 | Smoothed: 0.424 | MCC: 0.164 | REC: 0.416 | PRE: 0.202 | AUC: 0.642 | Threshold: 0.00774
# Epoch 16 | Train loss: 0.00677 | Val loss: 0.00564 | Combo score: 0.400 | Smoothed: 0.422 | MCC: 0.177 | REC: 0.416 | PRE: 0.213 | AUC: 0.657 | Threshold: 0.00800
# ...
# Epoch 16 | Train loss: 0.00938 | Val loss: 0.01000 | Combo score: 0.466 | Smoothed: 0.505 | MCC: 0.299 | REC: 0.693 | PRE: 0.237 | AUC: 0.795 | Threshold: 0.01304
# Epoch 17 | Train loss: 0.00904 | Val loss: 0.01020 | Combo score: 0.477 | Smoothed: 0.502 | MCC: 0.322 | REC: 0.738 | PRE: 0.244 | AUC: 0.815 | Threshold: 0.01280
# Epoch 18 | Train loss: 0.00890 | Val loss: 0.00994 | Combo score: 0.471 | Smoothed: 0.499 | MCC: 0.313 | REC: 0.689 | PRE: 0.249 | AUC: 0.804 | Threshold: 0.01254
# Epoch 19 | Train loss: 0.00878 | Val loss: 0.00990 | Combo score: 0.455 | Smoothed: 0.494 | MCC: 0.271 | REC: 0.704 | PRE: 0.212 | AUC: 0.779 | Threshold: 0.01110
# Epoch 20 | Train loss: 0.00869 | Val loss: 0.00977 | Combo score: 0.458 | Smoothed: 0.491 | MCC: 0.279 | REC: 0.723 | PRE: 0.214 | AUC: 0.778 | Threshold: 0.01091
# Epoch 21 | Train loss: 0.00851 | Val loss: 0.00993 | Combo score: 0.461 | Smoothed: 0.488 | MCC: 0.290 | REC: 0.667 | PRE: 0.235 | AUC: 0.790 | Threshold: 0.01214
# Epoch 22 | Train loss: 0.00843 | Val loss: 0.01031 | Combo score: 0.481 | Smoothed: 0.487 | MCC: 0.336 | REC: 0.723 | PRE: 0.259 | AUC: 0.808 | Threshold: 0.01276
# Epoch 23 | Train loss: 0.00833 | Val loss: 0.00859 | Combo score: 0.448 | Smoothed: 0.483 | MCC: 0.262 | REC: 0.637 | PRE: 0.220 | AUC: 0.763 | Threshold: 0.01146
# Epoch 24 | Train loss: 0.00830 | Val loss: 0.01012 | Combo score: 0.470 | Smoothed: 0.482 | MCC: 0.306 | REC: 0.764 | PRE: 0.225 | AUC: 0.792 | Threshold: 0.01083
# Early stopping at epoch 24 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 8 summary (years: [2012, 2013]) ---
# Number of fire events in validation: (267 / 2804)
# Best epoch: 10
# Threshold used: 0.02728
# Validation metrics:
# ACC: 89.2%
# PRE: 45.9%
# REC: 73.0%
# MCC: 0.52
# AUC: 0.90
# ==================================================
#
#
# ==================================================
# Training Bi-LSTM-AE with sequence length: monthly | Fold 9 (years: [2013, 2014])
# Epoch 01 | Train loss: 0.05916 | Val loss: 0.04021 | Combo score: 0.487 | Smoothed: 0.487 | MCC: 0.377 | REC: 0.481 | PRE: 0.413 | AUC: 0.791 | Threshold: 0.08805
# Epoch 02 | Train loss: 0.03071 | Val loss: 0.04139 | Combo score: 0.447 | Smoothed: 0.483 | MCC: 0.297 | REC: 0.481 | PRE: 0.309 | AUC: 0.686 | Threshold: 0.07518
# Epoch 03 | Train loss: 0.03082 | Val loss: 0.03657 | Combo score: 0.478 | Smoothed: 0.482 | MCC: 0.379 | REC: 0.477 | PRE: 0.417 | AUC: 0.701 | Threshold: 0.08154
# Epoch 04 | Train loss: 0.02957 | Val loss: 0.03694 | Combo score: 0.483 | Smoothed: 0.482 | MCC: 0.379 | REC: 0.481 | PRE: 0.415 | AUC: 0.745 | Threshold: 0.08206
# Epoch 05 | Train loss: 0.02565 | Val loss: 0.01885 | Combo score: 0.465 | Smoothed: 0.481 | MCC: 0.302 | REC: 0.719 | PRE: 0.239 | AUC: 0.763 | Threshold: 0.02285
# Epoch 06 | Train loss: 0.01809 | Val loss: 0.01914 | Combo score: 0.473 | Smoothed: 0.480 | MCC: 0.314 | REC: 0.779 | PRE: 0.235 | AUC: 0.782 | Threshold: 0.02202
# Epoch 07 | Train loss: 0.01768 | Val loss: 0.01897 | Combo score: 0.468 | Smoothed: 0.479 | MCC: 0.306 | REC: 0.751 | PRE: 0.235 | AUC: 0.773 | Threshold: 0.02240
# Epoch 08 | Train loss: 0.01760 | Val loss: 0.01890 | Combo score: 0.474 | Smoothed: 0.478 | MCC: 0.322 | REC: 0.723 | PRE: 0.255 | AUC: 0.783 | Threshold: 0.02427
# Epoch 09 | Train loss: 0.01800 | Val loss: 0.03099 | Combo score: 0.483 | Smoothed: 0.479 | MCC: 0.343 | REC: 0.842 | PRE: 0.242 | AUC: 0.760 | Threshold: 0.03946
# Epoch 10 | Train loss: 0.02415 | Val loss: 0.02664 | Combo score: 0.484 | Smoothed: 0.479 | MCC: 0.344 | REC: 0.677 | PRE: 0.287 | AUC: 0.826 | Threshold: 0.03070
# Epoch 11 | Train loss: 0.02134 | Val loss: 0.03470 | Combo score: 0.442 | Smoothed: 0.476 | MCC: 0.244 | REC: 0.747 | PRE: 0.194 | AUC: 0.716 | Threshold: 0.03082
# Epoch 12 | Train loss: 0.03688 | Val loss: 0.04670 | Combo score: 0.465 | Smoothed: 0.475 | MCC: 0.328 | REC: 0.358 | PRE: 0.427 | AUC: 0.775 | Threshold: 0.09804
# Epoch 13 | Train loss: 0.03724 | Val loss: 0.04658 | Combo score: 0.466 | Smoothed: 0.474 | MCC: 0.326 | REC: 0.358 | PRE: 0.423 | AUC: 0.793 | Threshold: 0.09469
# Epoch 14 | Train loss: 0.03079 | Val loss: 0.03607 | Combo score: 0.459 | Smoothed: 0.472 | MCC: 0.320 | REC: 0.337 | PRE: 0.430 | AUC: 0.747 | Threshold: 0.07375
# Epoch 15 | Train loss: 0.03115 | Val loss: 0.03723 | Combo score: 0.460 | Smoothed: 0.471 | MCC: 0.329 | REC: 0.358 | PRE: 0.429 | AUC: 0.723 | Threshold: 0.07238
# Epoch 16 | Train loss: 0.03134 | Val loss: 0.03729 | Combo score: 0.460 | Smoothed: 0.470 | MCC: 0.330 | REC: 0.358 | PRE: 0.430 | AUC: 0.717 | Threshold: 0.07227
# Epoch 17 | Train loss: 0.03130 | Val loss: 0.03825 | Combo score: 0.461 | Smoothed: 0.469 | MCC: 0.329 | REC: 0.358 | PRE: 0.429 | AUC: 0.728 | Threshold: 0.07852
# Epoch 18 | Train loss: 0.03135 | Val loss: 0.03886 | Combo score: 0.462 | Smoothed: 0.468 | MCC: 0.330 | REC: 0.358 | PRE: 0.430 | AUC: 0.733 | Threshold: 0.07919
# Epoch 19 | Train loss: 0.02615 | Val loss: 0.02311 | Combo score: 0.498 | Smoothed: 0.471 | MCC: 0.377 | REC: 0.737 | PRE: 0.298 | AUC: 0.831 | Threshold: 0.03472
# Epoch 20 | Train loss: 0.02072 | Val loss: 0.02795 | Combo score: 0.466 | Smoothed: 0.471 | MCC: 0.322 | REC: 0.344 | PRE: 0.428 | AUC: 0.810 | Threshold: 0.04985
# Epoch 21 | Train loss: 0.02297 | Val loss: 0.02875 | Combo score: 0.468 | Smoothed: 0.471 | MCC: 0.324 | REC: 0.347 | PRE: 0.429 | AUC: 0.819 | Threshold: 0.05668
# Epoch 22 | Train loss: 0.02164 | Val loss: 0.02010 | Combo score: 0.475 | Smoothed: 0.471 | MCC: 0.317 | REC: 0.765 | PRE: 0.240 | AUC: 0.796 | Threshold: 0.02294
# Epoch 23 | Train loss: 0.01936 | Val loss: 0.02665 | Combo score: 0.418 | Smoothed: 0.466 | MCC: 0.194 | REC: 0.712 | PRE: 0.170 | AUC: 0.659 | Threshold: 0.02186
# Epoch 24 | Train loss: 0.02856 | Val loss: 0.03542 | Combo score: 0.472 | Smoothed: 0.466 | MCC: 0.374 | REC: 0.484 | PRE: 0.406 | AUC: 0.650 | Threshold: 0.07039
# Epoch 25 | Train loss: 0.03963 | Val loss: 0.06939 | Combo score: 0.470 | Smoothed: 0.467 | MCC: 0.333 | REC: 0.347 | PRE: 0.444 | AUC: 0.803 | Threshold: 0.16670
# Epoch 26 | Train loss: 0.04906 | Val loss: 0.06319 | Combo score: 0.469 | Smoothed: 0.467 | MCC: 0.332 | REC: 0.347 | PRE: 0.442 | AUC: 0.802 | Threshold: 0.13483
# Epoch 27 | Train loss: 0.04443 | Val loss: 0.06500 | Combo score: 0.469 | Smoothed: 0.467 | MCC: 0.332 | REC: 0.347 | PRE: 0.442 | AUC: 0.802 | Threshold: 0.14786
# Epoch 28 | Train loss: 0.04924 | Val loss: 0.06597 | Combo score: 0.470 | Smoothed: 0.467 | MCC: 0.333 | REC: 0.347 | PRE: 0.444 | AUC: 0.804 | Threshold: 0.15149
# Epoch 29 | Train loss: 0.04933 | Val loss: 0.06488 | Combo score: 0.470 | Smoothed: 0.468 | MCC: 0.332 | REC: 0.347 | PRE: 0.442 | AUC: 0.805 | Threshold: 0.14505
# Early stopping at epoch 29 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 9 summary (years: [2013, 2014]) ---
# Number of fire events in validation: (285 / 2800)
# Best epoch: 19
# Threshold used: 0.03472
# Validation metrics:
# ACC: 79.7%
# PRE: 29.8%
# REC: 73.7%
# MCC: 0.38
# AUC: 0.83
# ==================================================
#
#
# ==================================================
# Training Bi-LSTM-AE with sequence length: monthly | Fold 10 (years: [2014, 2015])
# Epoch 01 | Train loss: 0.06275 | Val loss: 0.06232 | Combo score: 0.524 | Smoothed: 0.524 | MCC: 0.460 | REC: 0.482 | PRE: 0.539 | AUC: 0.853 | Threshold: 0.13829
# Epoch 02 | Train loss: 0.02833 | Val loss: 0.03062 | Combo score: 0.524 | Smoothed: 0.524 | MCC: 0.459 | REC: 0.496 | PRE: 0.525 | AUC: 0.854 | Threshold: 0.05754
# Epoch 03 | Train loss: 0.02467 | Val loss: 0.03124 | Combo score: 0.525 | Smoothed: 0.524 | MCC: 0.456 | REC: 0.566 | PRE: 0.467 | AUC: 0.869 | Threshold: 0.05519
# Epoch 04 | Train loss: 0.02447 | Val loss: 0.03071 | Combo score: 0.525 | Smoothed: 0.524 | MCC: 0.462 | REC: 0.493 | PRE: 0.534 | AUC: 0.851 | Threshold: 0.06297
# Epoch 05 | Train loss: 0.02197 | Val loss: 0.02779 | Combo score: 0.528 | Smoothed: 0.525 | MCC: 0.464 | REC: 0.496 | PRE: 0.533 | AUC: 0.876 | Threshold: 0.05686
# Epoch 06 | Train loss: 0.02073 | Val loss: 0.02836 | Combo score: 0.529 | Smoothed: 0.525 | MCC: 0.466 | REC: 0.500 | PRE: 0.533 | AUC: 0.879 | Threshold: 0.05927
# Epoch 07 | Train loss: 0.02012 | Val loss: 0.01809 | Combo score: 0.526 | Smoothed: 0.525 | MCC: 0.442 | REC: 0.807 | PRE: 0.334 | AUC: 0.862 | Threshold: 0.02506
# Epoch 08 | Train loss: 0.01418 | Val loss: 0.01686 | Combo score: 0.531 | Smoothed: 0.526 | MCC: 0.458 | REC: 0.777 | PRE: 0.362 | AUC: 0.867 | Threshold: 0.02534
# Epoch 09 | Train loss: 0.01417 | Val loss: 0.01657 | Combo score: 0.524 | Smoothed: 0.526 | MCC: 0.443 | REC: 0.748 | PRE: 0.357 | AUC: 0.861 | Threshold: 0.02564
# Epoch 10 | Train loss: 0.01654 | Val loss: 0.01646 | Combo score: 0.508 | Smoothed: 0.524 | MCC: 0.403 | REC: 0.737 | PRE: 0.320 | AUC: 0.847 | Threshold: 0.02414
# Epoch 11 | Train loss: 0.01420 | Val loss: 0.01625 | Combo score: 0.508 | Smoothed: 0.522 | MCC: 0.403 | REC: 0.719 | PRE: 0.326 | AUC: 0.844 | Threshold: 0.02383
# Epoch 12 | Train loss: 0.01391 | Val loss: 0.01677 | Combo score: 0.523 | Smoothed: 0.522 | MCC: 0.439 | REC: 0.770 | PRE: 0.344 | AUC: 0.861 | Threshold: 0.02458
# Epoch 13 | Train loss: 0.01389 | Val loss: 0.01585 | Combo score: 0.512 | Smoothed: 0.521 | MCC: 0.409 | REC: 0.796 | PRE: 0.306 | AUC: 0.839 | Threshold: 0.02093
# Epoch 14 | Train loss: 0.01382 | Val loss: 0.01605 | Combo score: 0.524 | Smoothed: 0.522 | MCC: 0.443 | REC: 0.766 | PRE: 0.350 | AUC: 0.850 | Threshold: 0.02308
# Epoch 15 | Train loss: 0.01382 | Val loss: 0.01633 | Combo score: 0.525 | Smoothed: 0.522 | MCC: 0.444 | REC: 0.777 | PRE: 0.346 | AUC: 0.858 | Threshold: 0.02417
# Epoch 16 | Train loss: 0.01386 | Val loss: 0.01612 | Combo score: 0.514 | Smoothed: 0.521 | MCC: 0.414 | REC: 0.777 | PRE: 0.316 | AUC: 0.848 | Threshold: 0.02226
# Epoch 17 | Train loss: 0.01383 | Val loss: 0.01712 | Combo score: 0.526 | Smoothed: 0.522 | MCC: 0.447 | REC: 0.748 | PRE: 0.362 | AUC: 0.868 | Threshold: 0.02659
# Epoch 18 | Train loss: 0.01364 | Val loss: 0.01588 | Combo score: 0.515 | Smoothed: 0.521 | MCC: 0.417 | REC: 0.766 | PRE: 0.324 | AUC: 0.854 | Threshold: 0.02298
# Epoch 19 | Train loss: 0.01392 | Val loss: 0.01625 | Combo score: 0.518 | Smoothed: 0.521 | MCC: 0.427 | REC: 0.741 | PRE: 0.343 | AUC: 0.854 | Threshold: 0.02421
# Epoch 20 | Train loss: 0.01385 | Val loss: 0.01660 | Combo score: 0.523 | Smoothed: 0.521 | MCC: 0.439 | REC: 0.748 | PRE: 0.352 | AUC: 0.861 | Threshold: 0.02535
# Epoch 21 | Train loss: 0.01377 | Val loss: 0.01626 | Combo score: 0.523 | Smoothed: 0.521 | MCC: 0.439 | REC: 0.748 | PRE: 0.353 | AUC: 0.858 | Threshold: 0.02467
# Epoch 22 | Train loss: 0.01484 | Val loss: 0.01615 | Combo score: 0.522 | Smoothed: 0.521 | MCC: 0.436 | REC: 0.785 | PRE: 0.336 | AUC: 0.853 | Threshold: 0.02260
# Epoch 23 | Train loss: 0.01386 | Val loss: 0.01591 | Combo score: 0.497 | Smoothed: 0.519 | MCC: 0.370 | REC: 0.781 | PRE: 0.275 | AUC: 0.831 | Threshold: 0.02078
# Epoch 24 | Train loss: 0.01376 | Val loss: 0.01615 | Combo score: 0.526 | Smoothed: 0.519 | MCC: 0.447 | REC: 0.741 | PRE: 0.364 | AUC: 0.862 | Threshold: 0.02516
# Early stopping at epoch 24 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 10 summary (years: [2014, 2015]) ---
# Number of fire events in validation: (274 / 2800)
# Best epoch: 8
# Threshold used: 0.02534
# Validation metrics:
# ACC: 84.4%
# PRE: 36.2%
# REC: 77.7%
# MCC: 0.46
# AUC: 0.87
# ==================================================
#
#
# ==================================================
# Training Bi-LSTM-AE with sequence length: monthly | Fold 11 (years: [2015, 2016])
# Epoch 01 | Train loss: 0.06393 | Val loss: 0.05899 | Combo score: 0.510 | Smoothed: 0.510 | MCC: 0.427 | REC: 0.502 | PRE: 0.465 | AUC: 0.839 | Threshold: 0.11822
# Epoch 02 | Train loss: 0.03692 | Val loss: 0.04826 | Combo score: 0.512 | Smoothed: 0.510 | MCC: 0.437 | REC: 0.506 | PRE: 0.479 | AUC: 0.813 | Threshold: 0.09524
# Epoch 03 | Train loss: 0.02608 | Val loss: 0.02921 | Combo score: 0.417 | Smoothed: 0.501 | MCC: 0.213 | REC: 0.358 | PRE: 0.253 | AUC: 0.727 | Threshold: 0.06038
# Epoch 04 | Train loss: 0.02266 | Val loss: 0.02801 | Combo score: 0.410 | Smoothed: 0.492 | MCC: 0.200 | REC: 0.362 | PRE: 0.236 | AUC: 0.705 | Threshold: 0.05742
# Epoch 05 | Train loss: 0.02340 | Val loss: 0.02737 | Combo score: 0.515 | Smoothed: 0.494 | MCC: 0.431 | REC: 0.483 | PRE: 0.487 | AUC: 0.868 | Threshold: 0.05777
# Epoch 06 | Train loss: 0.01811 | Val loss: 0.02622 | Combo score: 0.522 | Smoothed: 0.497 | MCC: 0.451 | REC: 0.487 | PRE: 0.516 | AUC: 0.866 | Threshold: 0.06418
# Epoch 07 | Train loss: 0.01711 | Val loss: 0.02727 | Combo score: 0.518 | Smoothed: 0.499 | MCC: 0.442 | REC: 0.502 | PRE: 0.489 | AUC: 0.855 | Threshold: 0.07905
# Epoch 08 | Train loss: 0.01123 | Val loss: 0.01659 | Combo score: 0.531 | Smoothed: 0.502 | MCC: 0.452 | REC: 0.811 | PRE: 0.339 | AUC: 0.876 | Threshold: 0.02463
# Epoch 09 | Train loss: 0.01123 | Val loss: 0.01614 | Combo score: 0.546 | Smoothed: 0.507 | MCC: 0.491 | REC: 0.796 | PRE: 0.386 | AUC: 0.896 | Threshold: 0.02894
# Epoch 10 | Train loss: 0.01042 | Val loss: 0.01478 | Combo score: 0.539 | Smoothed: 0.510 | MCC: 0.473 | REC: 0.811 | PRE: 0.361 | AUC: 0.887 | Threshold: 0.02447
# Epoch 11 | Train loss: 0.01060 | Val loss: 0.01479 | Combo score: 0.538 | Smoothed: 0.513 | MCC: 0.471 | REC: 0.823 | PRE: 0.354 | AUC: 0.883 | Threshold: 0.02275
# Epoch 12 | Train loss: 0.01162 | Val loss: 0.01329 | Combo score: 0.548 | Smoothed: 0.516 | MCC: 0.495 | REC: 0.838 | PRE: 0.374 | AUC: 0.888 | Threshold: 0.02108
# Epoch 13 | Train loss: 0.00883 | Val loss: 0.01147 | Combo score: 0.503 | Smoothed: 0.515 | MCC: 0.395 | REC: 0.596 | PRE: 0.365 | AUC: 0.861 | Threshold: 0.01764
# Epoch 14 | Train loss: 0.00797 | Val loss: 0.01058 | Combo score: 0.514 | Smoothed: 0.515 | MCC: 0.420 | REC: 0.672 | PRE: 0.360 | AUC: 0.860 | Threshold: 0.01560
# Epoch 15 | Train loss: 0.00756 | Val loss: 0.00999 | Combo score: 0.503 | Smoothed: 0.514 | MCC: 0.400 | REC: 0.547 | PRE: 0.396 | AUC: 0.856 | Threshold: 0.01771
# Epoch 16 | Train loss: 0.00738 | Val loss: 0.01018 | Combo score: 0.506 | Smoothed: 0.513 | MCC: 0.408 | REC: 0.581 | PRE: 0.389 | AUC: 0.851 | Threshold: 0.01772
# Epoch 17 | Train loss: 0.00699 | Val loss: 0.00970 | Combo score: 0.500 | Smoothed: 0.512 | MCC: 0.393 | REC: 0.540 | PRE: 0.392 | AUC: 0.852 | Threshold: 0.01813
# Epoch 18 | Train loss: 0.00679 | Val loss: 0.00968 | Combo score: 0.503 | Smoothed: 0.511 | MCC: 0.398 | REC: 0.562 | PRE: 0.386 | AUC: 0.857 | Threshold: 0.01788
# Epoch 19 | Train loss: 0.00659 | Val loss: 0.00886 | Combo score: 0.492 | Smoothed: 0.509 | MCC: 0.378 | REC: 0.479 | PRE: 0.407 | AUC: 0.843 | Threshold: 0.01961
# Epoch 20 | Train loss: 0.00628 | Val loss: 0.00911 | Combo score: 0.503 | Smoothed: 0.508 | MCC: 0.401 | REC: 0.562 | PRE: 0.390 | AUC: 0.847 | Threshold: 0.01692
# Epoch 21 | Train loss: 0.00631 | Val loss: 0.00935 | Combo score: 0.505 | Smoothed: 0.508 | MCC: 0.410 | REC: 0.472 | PRE: 0.461 | AUC: 0.853 | Threshold: 0.02432
# Epoch 22 | Train loss: 0.00711 | Val loss: 0.00956 | Combo score: 0.517 | Smoothed: 0.509 | MCC: 0.429 | REC: 0.642 | PRE: 0.385 | AUC: 0.874 | Threshold: 0.01635
# Epoch 23 | Train loss: 0.00600 | Val loss: 0.00959 | Combo score: 0.518 | Smoothed: 0.510 | MCC: 0.427 | REC: 0.717 | PRE: 0.349 | AUC: 0.871 | Threshold: 0.01385
# Epoch 24 | Train loss: 0.00585 | Val loss: 0.00929 | Combo score: 0.511 | Smoothed: 0.510 | MCC: 0.417 | REC: 0.626 | PRE: 0.377 | AUC: 0.854 | Threshold: 0.01555
# Early stopping at epoch 24 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 11 summary (years: [2015, 2016]) ---
# Number of fire events in validation: (265 / 2804)
# Best epoch: 12
# Threshold used: 0.02108
# Validation metrics:
# ACC: 85.2%
# PRE: 37.4%
# REC: 83.8%
# MCC: 0.50
# AUC: 0.89
# ==================================================
#
# Model A training and evaluation complete.

# %% [markdown]
# ### **Training Models B (S2)**

# %%
# MODEL B: Wildfire Prediction using LSTM-AE and Bi-LSTM-AE on Set 2 (S2)

random.seed(36)
np.random.seed(36)
torch.manual_seed(36)
torch.cuda.manual_seed_all(36)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark     = False
g = torch.Generator().manual_seed(36)

SEQUENCE_LENGTHS = {
    "10_day": 10,
    "2_week": 14,
    "monthly": 30
}

NUMERIC_FEATURES = [
    "NDVI_residual", "NDVI_std", "NDVI_trend", "Solar_de-seasonalized",
    "Temperature_residual", "Humidity_trend", "NDVI_var", "Humidity_residual",
    "NDVI_mean", "Temperature_trend", "Temperature [°C]_max",
    "Solar radiation [Jm2/day]_std", "Relative humidity [%]_mean",
    "Temperature [°C]_mean", "Solar radiation [Jm2/day]_sum" #### these two were added later
]

CAT_FEATURE = "State"
TARGET_COL  = "fire"

class WildfireDataset(Dataset):
    def __init__(self, df, sequence_length, only_no_fire=True):
        self.sequence_length = sequence_length
        self.data = df.copy()
        self.features = NUMERIC_FEATURES
        self.cat_feature = CAT_FEATURE
        self.target = df[TARGET_COL].values
        grouped = [group for _, group in df.groupby('State', observed=False)]
        self.sequences = []
        self.targets = []
        for g in grouped:
            for i in range(len(g) - sequence_length):
                num_seq = g[self.features].iloc[i:i + sequence_length].values.astype(np.float32)
                cat_seq = g[self.cat_feature].iloc[i:i + sequence_length]
                cat_seq_encoded = cat_seq.astype('category').cat.codes.values.astype(np.float32).reshape(-1, 1)
                full_seq = np.hstack([num_seq, cat_seq_encoded])
                label = g[TARGET_COL].iloc[i + sequence_length - 1] # It predicts the last day of the sequence as fire/no-fire
                window_labels = g[TARGET_COL].iloc[i : i + sequence_length].values
                if only_no_fire and np.any(window_labels != 0):
                    # skip *any* sequence that contains a fire anywhere
                    continue
                self.sequences.append(full_seq)
                self.targets.append(label)
    def __len__(self):
        return len(self.sequences)
    def __getitem__(self, idx):
        return torch.tensor(self.sequences[idx], dtype=torch.float32), torch.tensor(self.targets[idx], dtype=torch.float32)

class LSTMAutoencoder(nn.Module):
    def __init__(self, input_dim, embedding_dim, layer_sizes, num_states, bidirectional=False, dropout=0.3):
        super().__init__()
        self.embedding = nn.Embedding(num_states, embedding_dim)
        self.embedding_dropout = nn.Dropout(dropout)
        # Encoder
        enc_input_dim = input_dim + embedding_dim
        self.encoder_layers = nn.ModuleList()
        self.encoder_dropouts = nn.ModuleList()
        for h in layer_sizes:
            self.encoder_layers.append(
                nn.LSTM(enc_input_dim, h, batch_first=True, bidirectional=bidirectional)
            )
            self.encoder_dropouts.append(nn.Dropout(dropout))
            enc_input_dim = h * (2 if bidirectional else 1)
        # Decoder
        dec_input_dim = enc_input_dim
        self.decoder_layers = nn.ModuleList()
        self.decoder_dropouts = nn.ModuleList()
        for h in reversed(layer_sizes[:-1]):
            self.decoder_layers.append(
                nn.LSTM(dec_input_dim, h, batch_first=True)
            )
            self.decoder_dropouts.append(nn.Dropout(dropout))
            dec_input_dim = h
        # Final projection
        self.output_layer = nn.Linear(dec_input_dim, input_dim + embedding_dim)
        self.tanh = nn.Tanh()
    def forward(self, x):
        # Embedding
        state_idx = x[..., -1].long()
        emb = self.embedding(state_idx)
        emb = self.embedding_dropout(emb)
        seq = torch.cat([x[..., :-1], emb], dim=-1)
        # Encoder
        out = seq
        for lstm, dropout in zip(self.encoder_layers, self.encoder_dropouts):
            out, _ = lstm(out)
            out = dropout(self.tanh(out))
        # Decoder
        for lstm, dropout in zip(self.decoder_layers, self.decoder_dropouts):
            out, _ = lstm(out)
            out = dropout(self.tanh(out))
        # Output
        decoded = self.output_layer(out)
        decoded = self.tanh(decoded)
        return decoded

def train_one_epoch(model, dataloader, optimizer, criterion):
    model.train()
    total_loss = 0
    for x, _ in dataloader:
        optimizer.zero_grad()
        x_hat = model(x)
        # Trim output and target to match dimensions
        x_hat_trimmed = x_hat[:, :, :-embedding_dim]
        x_trimmed = x[:, :, :-1]
        loss = criterion(x_hat_trimmed, x_trimmed)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
    return total_loss / len(dataloader)

def evaluate_model(model, dataloader):
    model.eval()
    all_labels = []
    all_scores = []
    with torch.no_grad():
        for x, y in dataloader:
            x_hat = model(x)
            # Trim output and target to match dimensions
            x_hat_trimmed = x_hat[:, :, :-embedding_dim]
            x_trimmed = x[:, :, :-1]
            re = ((x_hat_trimmed - x_trimmed) ** 2).mean(dim=(1, 2))
            all_scores.extend(re.numpy())
            all_labels.extend(y.numpy())
    return np.array(all_scores), np.array(all_labels)

def compute_metrics(y_true, y_scores, threshold=None):
    if threshold is None:
        threshold = np.percentile(y_scores[y_true == 0], 95)
    y_pred = (y_scores > threshold).astype(int)
    metrics = {
        "ACC": accuracy_score(y_true, y_pred),
        "PRE": precision_score(y_true, y_pred, zero_division=0),
        "REC": recall_score(y_true, y_pred, zero_division=0),
        "MCC": matthews_corrcoef(y_true, y_pred),
    }
    metrics["AUC"] = roc_auc_score(y_true, y_scores)
    return metrics, threshold

def find_best_f1_threshold(y_true, y_scores):
    precision, recall, thresholds = precision_recall_curve(y_true, y_scores)
    f1_scores = 2 * (precision * recall) / (precision + recall + 1e-8)
    best_idx = np.argmax(f1_scores)
    return thresholds[best_idx], f1_scores[best_idx]

ALL_STATES_ORDER = [
    "Queensland", "South Australia", "Victoria", 
    "Australian Capital Territory", "New South Wales", "Tasmania", "Western Australia"
]
s2_train = pd.read_csv(os.path.join(target_dir, "S2_scaled_train.csv"))
s2_train["State"] = pd.Categorical(s2_train["State"], categories=ALL_STATES_ORDER, ordered=True)
s2_train["State_Code"] = s2_train["State"].cat.codes

logs_dir_s2 = os.path.join(target_dir, "00_1_training", "Model_B")

input_dim = len(NUMERIC_FEATURES)
embedding_dim = 4
hidden_dim = 32
num_states = s2_train[CAT_FEATURE].nunique()
layer_sizes = [256, 128, 64, 32, 16]
dropout = 0.1

s2_train["Year"] = pd.to_datetime(s2_train["Date"]).dt.year # type: ignore
years = list(range(2005, 2017))
for model_type in ["LSTM-AE", "Bi-LSTM-AE"]:
    for seq_name, seq_len in SEQUENCE_LENGTHS.items():
        print(f"Training {model_type} with sequence length: {seq_name}")
        for i in range(len(years) - 1):
            val_years   = [years[i], years[i + 1]]
            train_years = [y for y in years if y not in val_years]

            fold_train = s2_train[s2_train["Year"].isin(train_years)]
            fold_val   = s2_train[s2_train["Year"].isin(val_years)]
            
            train_ds = WildfireDataset(fold_train, seq_len, only_no_fire=True)
            val_ds = WildfireDataset(fold_val, seq_len, only_no_fire=False)

            train_loader = DataLoader(train_ds, batch_size=64, shuffle=True, generator = g)
            val_loader = DataLoader(val_ds, batch_size=64, shuffle=False)

            model = LSTMAutoencoder(
                input_dim, embedding_dim, layer_sizes, num_states,
                bidirectional=(model_type == "Bi-LSTM-AE"), dropout=dropout
            )
            optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
            criterion = nn.MSELoss()

            best_score = -float('inf')
            smoothed_best_score = -float('inf')
            min_epoch = 15
            patience, counter = 10, 0

            best_metrics = None
            best_threshold = None
            best_epoch = 0

            # Log path
            log_dir = os.path.join(logs_dir_s1, f"{model_type}")
            log_path = os.path.join(log_dir, f"01_train_{seq_name}_log.txt")

            smoothing_alpha = 0.1 # smoothing factor for exponential moving average
            smoothed_score = None

            with open(log_path, 'a') as f:
                log_and_print(f"\n{'='*50}", f)
                log_and_print(f"Training {model_type} with sequence length: {seq_name} | Fold {i+1} (years: {val_years})", f)

                for epoch in range(1, 201):
                    loss = train_one_epoch(model, train_loader, optimizer, criterion)
                    val_scores, val_labels = evaluate_model(model, val_loader)
                    threshold, _ = find_best_f1_threshold(val_labels, val_scores)
                    val_metrics, _ = compute_metrics(val_labels, val_scores, threshold)

                    val_loss = np.mean(val_scores)

                    mcc = val_metrics["MCC"]
                    rec = val_metrics["REC"]
                    pre = val_metrics["PRE"]
                    auc = val_metrics["AUC"]

                    scaled_mcc = (mcc + 1) / 2   # MCC: [-1, 1] → [0, 1]
                    scaled_auc = (auc - 0.5) * 2 # AUC: [0.5, 1] → [0, 1]

                    combo_score = 0.6 * scaled_mcc + 0.05 * rec + 0.05 * pre + 0.05 * scaled_auc
                    if smoothed_score is None:
                        smoothed_score = combo_score
                    else:
                        smoothed_score = (smoothing_alpha * combo_score + (1 - smoothing_alpha) * smoothed_score)

                    log_and_print(f"Epoch {epoch:02d} | Train loss: {loss:.5f} | Val loss: {val_loss:.5f} | "
                                f"Combo score: {combo_score:.3f} | Smoothed: {smoothed_score:.3f} | "
                                f"MCC: {mcc:.3f} | REC: {rec:.3f} | PRE: {pre:.3f} | AUC: {auc:.3f} | Threshold: {threshold:.5f}", f)

                    if combo_score > best_score or smoothed_score > smoothed_best_score:
                        smoothed_best_score = smoothed_score
                        counter = 0
                        # Always track best model based on raw combo score
                        if combo_score > best_score:
                            best_score = combo_score
                            best_metrics = val_metrics
                            best_threshold = threshold
                            best_epoch = epoch
                            torch.save(model.state_dict(), os.path.join(log_dir, f"01_train_{seq_name}_fold{i+1}_best_model.pt"))
                    # Early stopping kicks in only after min_epoch
                    elif epoch >= min_epoch:
                        counter += 1
                        if counter >= patience:
                            log_and_print(f"Early stopping at epoch {epoch:02d} (no improvement in smoothed or combo score over {patience} epochs)", f)
                            break

                # Summary logging
                log_and_print(f"\n--- Fold {i+1} summary (years: {val_years}) ---", f)
                print(f"Number of fire events in validation: ({(val_labels == 1).sum()} / {len(val_labels)})")
                log_and_print(f"Best epoch: {best_epoch}", f)
                if best_threshold is not None:
                    log_and_print(f"Threshold used: {best_threshold:.5f}", f)
                else:
                    log_and_print("Threshold used: N/A", f)
                if best_metrics is not None:
                    log_and_print("Validation metrics:", f)
                    for k, v in best_metrics.items():
                        if k in ["ACC", "PRE", "REC"]:
                            log_and_print(f"{k}: {v * 100:04.1f}%", f)
                        elif k in ["MCC", "AUC"]:
                            log_and_print(f"{k}: {v:.2f}", f)
                else:
                    log_and_print("No metrics saved.", f)

                log_and_print("=" * 50 + "\n", f)

print("Model B training and evaluation complete.")
# Out:
# Training LSTM-AE with sequence length: 10_day
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 1 (years: [2005, 2006])
# Epoch 01 | Train loss: 0.04699 | Val loss: 0.02192 | Combo score: 0.403 | Smoothed: 0.403 | MCC: 0.159 | REC: 0.653 | PRE: 0.153 | AUC: 0.653 | Threshold: 0.02221
# Epoch 02 | Train loss: 0.01538 | Val loss: 0.01906 | Combo score: 0.399 | Smoothed: 0.403 | MCC: 0.165 | REC: 0.453 | PRE: 0.185 | AUC: 0.676 | Threshold: 0.02623
# Epoch 03 | Train loss: 0.01295 | Val loss: 0.01664 | Combo score: 0.413 | Smoothed: 0.404 | MCC: 0.194 | REC: 0.559 | PRE: 0.187 | AUC: 0.678 | Threshold: 0.01989
# Epoch 04 | Train loss: 0.01086 | Val loss: 0.01606 | Combo score: 0.415 | Smoothed: 0.405 | MCC: 0.211 | REC: 0.461 | PRE: 0.221 | AUC: 0.678 | Threshold: 0.02464
# Epoch 05 | Train loss: 0.01020 | Val loss: 0.01503 | Combo score: 0.403 | Smoothed: 0.405 | MCC: 0.184 | REC: 0.382 | PRE: 0.218 | AUC: 0.680 | Threshold: 0.02498
# Epoch 06 | Train loss: 0.00981 | Val loss: 0.01457 | Combo score: 0.400 | Smoothed: 0.404 | MCC: 0.170 | REC: 0.463 | PRE: 0.187 | AUC: 0.667 | Threshold: 0.02014
# Epoch 07 | Train loss: 0.00944 | Val loss: 0.01407 | Combo score: 0.399 | Smoothed: 0.404 | MCC: 0.171 | REC: 0.392 | PRE: 0.203 | AUC: 0.677 | Threshold: 0.02146
# Epoch 08 | Train loss: 0.00877 | Val loss: 0.01295 | Combo score: 0.413 | Smoothed: 0.405 | MCC: 0.203 | REC: 0.457 | PRE: 0.215 | AUC: 0.685 | Threshold: 0.01880
# Epoch 09 | Train loss: 0.00815 | Val loss: 0.01156 | Combo score: 0.416 | Smoothed: 0.406 | MCC: 0.205 | REC: 0.502 | PRE: 0.207 | AUC: 0.690 | Threshold: 0.01525
# Epoch 10 | Train loss: 0.00770 | Val loss: 0.01124 | Combo score: 0.416 | Smoothed: 0.407 | MCC: 0.209 | REC: 0.478 | PRE: 0.216 | AUC: 0.687 | Threshold: 0.01569
# Epoch 11 | Train loss: 0.00730 | Val loss: 0.01041 | Combo score: 0.411 | Smoothed: 0.407 | MCC: 0.195 | REC: 0.488 | PRE: 0.201 | AUC: 0.679 | Threshold: 0.01391
# Epoch 12 | Train loss: 0.00696 | Val loss: 0.01065 | Combo score: 0.423 | Smoothed: 0.409 | MCC: 0.224 | REC: 0.488 | PRE: 0.226 | AUC: 0.703 | Threshold: 0.01504
# Epoch 13 | Train loss: 0.00669 | Val loss: 0.01022 | Combo score: 0.422 | Smoothed: 0.410 | MCC: 0.222 | REC: 0.533 | PRE: 0.214 | AUC: 0.682 | Threshold: 0.01329
# Epoch 14 | Train loss: 0.00646 | Val loss: 0.00978 | Combo score: 0.421 | Smoothed: 0.411 | MCC: 0.220 | REC: 0.496 | PRE: 0.220 | AUC: 0.694 | Threshold: 0.01383
# Epoch 15 | Train loss: 0.00631 | Val loss: 0.00974 | Combo score: 0.420 | Smoothed: 0.412 | MCC: 0.216 | REC: 0.527 | PRE: 0.210 | AUC: 0.687 | Threshold: 0.01304
# Epoch 16 | Train loss: 0.00603 | Val loss: 0.00938 | Combo score: 0.417 | Smoothed: 0.413 | MCC: 0.219 | REC: 0.420 | PRE: 0.241 | AUC: 0.686 | Threshold: 0.01588
# Epoch 17 | Train loss: 0.00553 | Val loss: 0.00909 | Combo score: 0.420 | Smoothed: 0.413 | MCC: 0.220 | REC: 0.484 | PRE: 0.223 | AUC: 0.690 | Threshold: 0.01344
# Epoch 18 | Train loss: 0.00520 | Val loss: 0.00858 | Combo score: 0.417 | Smoothed: 0.414 | MCC: 0.213 | REC: 0.498 | PRE: 0.214 | AUC: 0.680 | Threshold: 0.01248
# Epoch 19 | Train loss: 0.00502 | Val loss: 0.00868 | Combo score: 0.423 | Smoothed: 0.415 | MCC: 0.224 | REC: 0.514 | PRE: 0.220 | AUC: 0.689 | Threshold: 0.01252
# Epoch 20 | Train loss: 0.00482 | Val loss: 0.00846 | Combo score: 0.415 | Smoothed: 0.415 | MCC: 0.206 | REC: 0.478 | PRE: 0.212 | AUC: 0.685 | Threshold: 0.01185
# Epoch 21 | Train loss: 0.00464 | Val loss: 0.00806 | Combo score: 0.414 | Smoothed: 0.415 | MCC: 0.202 | REC: 0.492 | PRE: 0.206 | AUC: 0.686 | Threshold: 0.01133
# Epoch 22 | Train loss: 0.00451 | Val loss: 0.00787 | Combo score: 0.413 | Smoothed: 0.415 | MCC: 0.195 | REC: 0.545 | PRE: 0.190 | AUC: 0.681 | Threshold: 0.00943
# Epoch 23 | Train loss: 0.00440 | Val loss: 0.00797 | Combo score: 0.412 | Smoothed: 0.414 | MCC: 0.211 | REC: 0.298 | PRE: 0.282 | AUC: 0.693 | Threshold: 0.01656
# Epoch 24 | Train loss: 0.00435 | Val loss: 0.00765 | Combo score: 0.402 | Smoothed: 0.413 | MCC: 0.173 | REC: 0.502 | PRE: 0.182 | AUC: 0.658 | Threshold: 0.00924
# Epoch 25 | Train loss: 0.00430 | Val loss: 0.00773 | Combo score: 0.410 | Smoothed: 0.413 | MCC: 0.191 | REC: 0.500 | PRE: 0.196 | AUC: 0.677 | Threshold: 0.01008
# Epoch 26 | Train loss: 0.00422 | Val loss: 0.00747 | Combo score: 0.412 | Smoothed: 0.413 | MCC: 0.197 | REC: 0.516 | PRE: 0.197 | AUC: 0.675 | Threshold: 0.00986
# Epoch 27 | Train loss: 0.00414 | Val loss: 0.00725 | Combo score: 0.413 | Smoothed: 0.413 | MCC: 0.194 | REC: 0.553 | PRE: 0.188 | AUC: 0.674 | Threshold: 0.00852
# Epoch 28 | Train loss: 0.00410 | Val loss: 0.00745 | Combo score: 0.415 | Smoothed: 0.413 | MCC: 0.200 | REC: 0.529 | PRE: 0.197 | AUC: 0.685 | Threshold: 0.00922
# Epoch 29 | Train loss: 0.00404 | Val loss: 0.00747 | Combo score: 0.416 | Smoothed: 0.413 | MCC: 0.204 | REC: 0.535 | PRE: 0.199 | AUC: 0.685 | Threshold: 0.00918
# Early stopping at epoch 29 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 1 summary (years: [2005, 2006]) ---
# Number of fire events in validation: (490 / 5040)
# Best epoch: 12
# Threshold used: 0.01504
# Validation metrics:
# ACC: 78.8%
# PRE: 22.6%
# REC: 48.8%
# MCC: 0.22
# AUC: 0.70
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 2 (years: [2006, 2007])
# Epoch 01 | Train loss: 0.04861 | Val loss: 0.02369 | Combo score: 0.367 | Smoothed: 0.367 | MCC: 0.102 | REC: 0.392 | PRE: 0.154 | AUC: 0.591 | Threshold: 0.02791
# Epoch 02 | Train loss: 0.01642 | Val loss: 0.01725 | Combo score: 0.390 | Smoothed: 0.369 | MCC: 0.144 | REC: 0.495 | PRE: 0.168 | AUC: 0.637 | Threshold: 0.02030
# Epoch 03 | Train loss: 0.01334 | Val loss: 0.01623 | Combo score: 0.439 | Smoothed: 0.376 | MCC: 0.276 | REC: 0.372 | PRE: 0.336 | AUC: 0.711 | Threshold: 0.03249
# Epoch 04 | Train loss: 0.01125 | Val loss: 0.01379 | Combo score: 0.394 | Smoothed: 0.378 | MCC: 0.151 | REC: 0.462 | PRE: 0.178 | AUC: 0.666 | Threshold: 0.01716
# Epoch 05 | Train loss: 0.01051 | Val loss: 0.01331 | Combo score: 0.395 | Smoothed: 0.380 | MCC: 0.168 | REC: 0.349 | PRE: 0.216 | AUC: 0.662 | Threshold: 0.02103
# Epoch 06 | Train loss: 0.00984 | Val loss: 0.01190 | Combo score: 0.418 | Smoothed: 0.383 | MCC: 0.205 | REC: 0.517 | PRE: 0.208 | AUC: 0.699 | Threshold: 0.01493
# Epoch 07 | Train loss: 0.00880 | Val loss: 0.01076 | Combo score: 0.410 | Smoothed: 0.386 | MCC: 0.195 | REC: 0.442 | PRE: 0.217 | AUC: 0.683 | Threshold: 0.01499
# Epoch 08 | Train loss: 0.00802 | Val loss: 0.00975 | Combo score: 0.413 | Smoothed: 0.389 | MCC: 0.203 | REC: 0.450 | PRE: 0.223 | AUC: 0.686 | Threshold: 0.01343
# Epoch 09 | Train loss: 0.00700 | Val loss: 0.00914 | Combo score: 0.415 | Smoothed: 0.391 | MCC: 0.203 | REC: 0.452 | PRE: 0.222 | AUC: 0.699 | Threshold: 0.01313
# Epoch 10 | Train loss: 0.00642 | Val loss: 0.00886 | Combo score: 0.430 | Smoothed: 0.395 | MCC: 0.242 | REC: 0.476 | PRE: 0.252 | AUC: 0.712 | Threshold: 0.01289
# Epoch 11 | Train loss: 0.00595 | Val loss: 0.00793 | Combo score: 0.416 | Smoothed: 0.397 | MCC: 0.215 | REC: 0.404 | PRE: 0.248 | AUC: 0.691 | Threshold: 0.01243
# Epoch 12 | Train loss: 0.00563 | Val loss: 0.00790 | Combo score: 0.414 | Smoothed: 0.399 | MCC: 0.210 | REC: 0.392 | PRE: 0.247 | AUC: 0.689 | Threshold: 0.01318
# Epoch 13 | Train loss: 0.00538 | Val loss: 0.00732 | Combo score: 0.409 | Smoothed: 0.400 | MCC: 0.191 | REC: 0.464 | PRE: 0.208 | AUC: 0.679 | Threshold: 0.01000
# Epoch 14 | Train loss: 0.00512 | Val loss: 0.00753 | Combo score: 0.422 | Smoothed: 0.402 | MCC: 0.230 | REC: 0.405 | PRE: 0.263 | AUC: 0.697 | Threshold: 0.01241
# Epoch 15 | Train loss: 0.00494 | Val loss: 0.00748 | Combo score: 0.411 | Smoothed: 0.403 | MCC: 0.206 | REC: 0.400 | PRE: 0.239 | AUC: 0.675 | Threshold: 0.01174
# Epoch 16 | Train loss: 0.00476 | Val loss: 0.00736 | Combo score: 0.423 | Smoothed: 0.405 | MCC: 0.227 | REC: 0.448 | PRE: 0.245 | AUC: 0.700 | Threshold: 0.01158
# Epoch 17 | Train loss: 0.00447 | Val loss: 0.00672 | Combo score: 0.418 | Smoothed: 0.406 | MCC: 0.210 | REC: 0.501 | PRE: 0.216 | AUC: 0.692 | Threshold: 0.00923
# Epoch 18 | Train loss: 0.00421 | Val loss: 0.00695 | Combo score: 0.424 | Smoothed: 0.408 | MCC: 0.228 | REC: 0.456 | PRE: 0.244 | AUC: 0.707 | Threshold: 0.01085
# Epoch 19 | Train loss: 0.00400 | Val loss: 0.00616 | Combo score: 0.417 | Smoothed: 0.409 | MCC: 0.207 | REC: 0.495 | PRE: 0.215 | AUC: 0.699 | Threshold: 0.00847
# Epoch 20 | Train loss: 0.00383 | Val loss: 0.00591 | Combo score: 0.415 | Smoothed: 0.410 | MCC: 0.205 | REC: 0.464 | PRE: 0.220 | AUC: 0.690 | Threshold: 0.00849
# Epoch 21 | Train loss: 0.00369 | Val loss: 0.00582 | Combo score: 0.411 | Smoothed: 0.410 | MCC: 0.197 | REC: 0.450 | PRE: 0.216 | AUC: 0.690 | Threshold: 0.00823
# Epoch 22 | Train loss: 0.00357 | Val loss: 0.00582 | Combo score: 0.414 | Smoothed: 0.410 | MCC: 0.201 | REC: 0.501 | PRE: 0.209 | AUC: 0.679 | Threshold: 0.00752
# Epoch 23 | Train loss: 0.00347 | Val loss: 0.00546 | Combo score: 0.416 | Smoothed: 0.411 | MCC: 0.207 | REC: 0.481 | PRE: 0.218 | AUC: 0.687 | Threshold: 0.00721
# Epoch 24 | Train loss: 0.00336 | Val loss: 0.00546 | Combo score: 0.406 | Smoothed: 0.410 | MCC: 0.183 | REC: 0.462 | PRE: 0.202 | AUC: 0.682 | Threshold: 0.00725
# Epoch 25 | Train loss: 0.00327 | Val loss: 0.00538 | Combo score: 0.412 | Smoothed: 0.410 | MCC: 0.198 | REC: 0.472 | PRE: 0.213 | AUC: 0.680 | Threshold: 0.00739
# Epoch 26 | Train loss: 0.00318 | Val loss: 0.00526 | Combo score: 0.403 | Smoothed: 0.410 | MCC: 0.178 | REC: 0.464 | PRE: 0.198 | AUC: 0.665 | Threshold: 0.00675
# Epoch 27 | Train loss: 0.00311 | Val loss: 0.00525 | Combo score: 0.416 | Smoothed: 0.410 | MCC: 0.202 | REC: 0.513 | PRE: 0.207 | AUC: 0.689 | Threshold: 0.00688
# Epoch 28 | Train loss: 0.00302 | Val loss: 0.00519 | Combo score: 0.411 | Smoothed: 0.410 | MCC: 0.197 | REC: 0.462 | PRE: 0.214 | AUC: 0.683 | Threshold: 0.00722
# Epoch 29 | Train loss: 0.00294 | Val loss: 0.00495 | Combo score: 0.402 | Smoothed: 0.409 | MCC: 0.171 | REC: 0.452 | PRE: 0.195 | AUC: 0.680 | Threshold: 0.00657
# Epoch 30 | Train loss: 0.00287 | Val loss: 0.00492 | Combo score: 0.402 | Smoothed: 0.409 | MCC: 0.178 | REC: 0.415 | PRE: 0.208 | AUC: 0.674 | Threshold: 0.00726
# Epoch 31 | Train loss: 0.00280 | Val loss: 0.00486 | Combo score: 0.405 | Smoothed: 0.408 | MCC: 0.182 | REC: 0.456 | PRE: 0.203 | AUC: 0.671 | Threshold: 0.00648
# Epoch 32 | Train loss: 0.00273 | Val loss: 0.00482 | Combo score: 0.403 | Smoothed: 0.408 | MCC: 0.181 | REC: 0.417 | PRE: 0.211 | AUC: 0.672 | Threshold: 0.00704
# Epoch 33 | Train loss: 0.00267 | Val loss: 0.00472 | Combo score: 0.397 | Smoothed: 0.407 | MCC: 0.166 | REC: 0.400 | PRE: 0.202 | AUC: 0.666 | Threshold: 0.00707
# Early stopping at epoch 33 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 2 summary (years: [2006, 2007]) ---
# Number of fire events in validation: (513 / 5040)
# Best epoch: 3
# Threshold used: 0.03249
# Validation metrics:
# ACC: 86.1%
# PRE: 33.6%
# REC: 37.2%
# MCC: 0.28
# AUC: 0.71
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 3 (years: [2007, 2008])
# Epoch 01 | Train loss: 0.04685 | Val loss: 0.02244 | Combo score: 0.383 | Smoothed: 0.383 | MCC: 0.112 | REC: 0.604 | PRE: 0.125 | AUC: 0.630 | Threshold: 0.02006
# Epoch 02 | Train loss: 0.01639 | Val loss: 0.01595 | Combo score: 0.355 | Smoothed: 0.380 | MCC: 0.098 | REC: 0.256 | PRE: 0.155 | AUC: 0.555 | Threshold: 0.02663
# Epoch 03 | Train loss: 0.01454 | Val loss: 0.01466 | Combo score: 0.365 | Smoothed: 0.379 | MCC: 0.114 | REC: 0.243 | PRE: 0.175 | AUC: 0.600 | Threshold: 0.02686
# Epoch 04 | Train loss: 0.01214 | Val loss: 0.01227 | Combo score: 0.406 | Smoothed: 0.382 | MCC: 0.177 | REC: 0.452 | PRE: 0.183 | AUC: 0.710 | Threshold: 0.01704
# Epoch 05 | Train loss: 0.01115 | Val loss: 0.01126 | Combo score: 0.395 | Smoothed: 0.383 | MCC: 0.154 | REC: 0.485 | PRE: 0.160 | AUC: 0.663 | Threshold: 0.01390
# Epoch 06 | Train loss: 0.01051 | Val loss: 0.01031 | Combo score: 0.390 | Smoothed: 0.384 | MCC: 0.148 | REC: 0.384 | PRE: 0.173 | AUC: 0.678 | Threshold: 0.01495
# Epoch 07 | Train loss: 0.00979 | Val loss: 0.00991 | Combo score: 0.396 | Smoothed: 0.385 | MCC: 0.157 | REC: 0.465 | PRE: 0.166 | AUC: 0.672 | Threshold: 0.01331
# Epoch 08 | Train loss: 0.00900 | Val loss: 0.00861 | Combo score: 0.410 | Smoothed: 0.387 | MCC: 0.200 | REC: 0.387 | PRE: 0.221 | AUC: 0.699 | Threshold: 0.01373
# Epoch 09 | Train loss: 0.00773 | Val loss: 0.00806 | Combo score: 0.444 | Smoothed: 0.393 | MCC: 0.265 | REC: 0.528 | PRE: 0.242 | AUC: 0.761 | Threshold: 0.01135
# Epoch 10 | Train loss: 0.00690 | Val loss: 0.00716 | Combo score: 0.432 | Smoothed: 0.397 | MCC: 0.251 | REC: 0.369 | PRE: 0.287 | AUC: 0.738 | Threshold: 0.01315
# Epoch 11 | Train loss: 0.00649 | Val loss: 0.00680 | Combo score: 0.427 | Smoothed: 0.400 | MCC: 0.240 | REC: 0.362 | PRE: 0.277 | AUC: 0.731 | Threshold: 0.01173
# Epoch 12 | Train loss: 0.00619 | Val loss: 0.00658 | Combo score: 0.438 | Smoothed: 0.404 | MCC: 0.259 | REC: 0.449 | PRE: 0.262 | AUC: 0.745 | Threshold: 0.01033
# Epoch 13 | Train loss: 0.00595 | Val loss: 0.00628 | Combo score: 0.430 | Smoothed: 0.406 | MCC: 0.245 | REC: 0.391 | PRE: 0.270 | AUC: 0.732 | Threshold: 0.01046
# Epoch 14 | Train loss: 0.00577 | Val loss: 0.00625 | Combo score: 0.428 | Smoothed: 0.409 | MCC: 0.243 | REC: 0.346 | PRE: 0.289 | AUC: 0.736 | Threshold: 0.01130
# Epoch 15 | Train loss: 0.00568 | Val loss: 0.00638 | Combo score: 0.438 | Smoothed: 0.411 | MCC: 0.266 | REC: 0.351 | PRE: 0.318 | AUC: 0.746 | Threshold: 0.01224
# Epoch 16 | Train loss: 0.00549 | Val loss: 0.00611 | Combo score: 0.430 | Smoothed: 0.413 | MCC: 0.244 | REC: 0.402 | PRE: 0.264 | AUC: 0.730 | Threshold: 0.01015
# Epoch 17 | Train loss: 0.00540 | Val loss: 0.00601 | Combo score: 0.436 | Smoothed: 0.416 | MCC: 0.260 | REC: 0.420 | PRE: 0.275 | AUC: 0.735 | Threshold: 0.01018
# Epoch 18 | Train loss: 0.00526 | Val loss: 0.00614 | Combo score: 0.442 | Smoothed: 0.418 | MCC: 0.276 | REC: 0.360 | PRE: 0.327 | AUC: 0.750 | Threshold: 0.01163
# Epoch 19 | Train loss: 0.00517 | Val loss: 0.00592 | Combo score: 0.429 | Smoothed: 0.419 | MCC: 0.241 | REC: 0.481 | PRE: 0.233 | AUC: 0.713 | Threshold: 0.00896
# Epoch 20 | Train loss: 0.00503 | Val loss: 0.00565 | Combo score: 0.434 | Smoothed: 0.421 | MCC: 0.254 | REC: 0.427 | PRE: 0.265 | AUC: 0.730 | Threshold: 0.00929
# Epoch 21 | Train loss: 0.00482 | Val loss: 0.00547 | Combo score: 0.421 | Smoothed: 0.421 | MCC: 0.223 | REC: 0.400 | PRE: 0.241 | AUC: 0.723 | Threshold: 0.00900
# Epoch 22 | Train loss: 0.00463 | Val loss: 0.00512 | Combo score: 0.429 | Smoothed: 0.422 | MCC: 0.243 | REC: 0.434 | PRE: 0.251 | AUC: 0.714 | Threshold: 0.00853
# Epoch 23 | Train loss: 0.00443 | Val loss: 0.00469 | Combo score: 0.428 | Smoothed: 0.422 | MCC: 0.243 | REC: 0.407 | PRE: 0.260 | AUC: 0.721 | Threshold: 0.00795
# Epoch 24 | Train loss: 0.00421 | Val loss: 0.00467 | Combo score: 0.407 | Smoothed: 0.421 | MCC: 0.190 | REC: 0.396 | PRE: 0.208 | AUC: 0.699 | Threshold: 0.00731
# Epoch 25 | Train loss: 0.00401 | Val loss: 0.00448 | Combo score: 0.412 | Smoothed: 0.420 | MCC: 0.201 | REC: 0.407 | PRE: 0.216 | AUC: 0.704 | Threshold: 0.00700
# Epoch 26 | Train loss: 0.00387 | Val loss: 0.00459 | Combo score: 0.410 | Smoothed: 0.419 | MCC: 0.196 | REC: 0.400 | PRE: 0.213 | AUC: 0.705 | Threshold: 0.00706
# Epoch 27 | Train loss: 0.00386 | Val loss: 0.00443 | Combo score: 0.411 | Smoothed: 0.418 | MCC: 0.199 | REC: 0.380 | PRE: 0.222 | AUC: 0.709 | Threshold: 0.00715
# Epoch 28 | Train loss: 0.00369 | Val loss: 0.00422 | Combo score: 0.400 | Smoothed: 0.416 | MCC: 0.152 | REC: 0.607 | PRE: 0.144 | AUC: 0.668 | Threshold: 0.00449
# Epoch 29 | Train loss: 0.00353 | Val loss: 0.00426 | Combo score: 0.411 | Smoothed: 0.416 | MCC: 0.182 | REC: 0.544 | PRE: 0.171 | AUC: 0.705 | Threshold: 0.00521
# Epoch 30 | Train loss: 0.00344 | Val loss: 0.00433 | Combo score: 0.403 | Smoothed: 0.414 | MCC: 0.174 | REC: 0.445 | PRE: 0.182 | AUC: 0.692 | Threshold: 0.00592
# Epoch 31 | Train loss: 0.00334 | Val loss: 0.00392 | Combo score: 0.394 | Smoothed: 0.412 | MCC: 0.146 | REC: 0.503 | PRE: 0.153 | AUC: 0.672 | Threshold: 0.00469
# Epoch 32 | Train loss: 0.00329 | Val loss: 0.00393 | Combo score: 0.398 | Smoothed: 0.411 | MCC: 0.161 | REC: 0.458 | PRE: 0.170 | AUC: 0.687 | Threshold: 0.00520
# Epoch 33 | Train loss: 0.00317 | Val loss: 0.00383 | Combo score: 0.400 | Smoothed: 0.410 | MCC: 0.181 | REC: 0.290 | PRE: 0.235 | AUC: 0.698 | Threshold: 0.00705
# Early stopping at epoch 33 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 3 summary (years: [2007, 2008]) ---
# Number of fire events in validation: (445 / 5047)
# Best epoch: 9
# Threshold used: 0.01135
# Validation metrics:
# ACC: 81.2%
# PRE: 24.2%
# REC: 52.8%
# MCC: 0.26
# AUC: 0.76
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 4 (years: [2008, 2009])
# Epoch 01 | Train loss: 0.04580 | Val loss: 0.01834 | Combo score: 0.424 | Smoothed: 0.424 | MCC: 0.219 | REC: 0.495 | PRE: 0.234 | AUC: 0.718 | Threshold: 0.02420
# Epoch 02 | Train loss: 0.01553 | Val loss: 0.01598 | Combo score: 0.444 | Smoothed: 0.426 | MCC: 0.279 | REC: 0.431 | PRE: 0.319 | AUC: 0.723 | Threshold: 0.02668
# Epoch 03 | Train loss: 0.01343 | Val loss: 0.01379 | Combo score: 0.468 | Smoothed: 0.430 | MCC: 0.343 | REC: 0.365 | PRE: 0.455 | AUC: 0.741 | Threshold: 0.02906
# Epoch 04 | Train loss: 0.01144 | Val loss: 0.01128 | Combo score: 0.454 | Smoothed: 0.432 | MCC: 0.297 | REC: 0.504 | PRE: 0.308 | AUC: 0.747 | Threshold: 0.01688
# Epoch 05 | Train loss: 0.01015 | Val loss: 0.01067 | Combo score: 0.469 | Smoothed: 0.436 | MCC: 0.336 | REC: 0.460 | PRE: 0.377 | AUC: 0.757 | Threshold: 0.01793
# Epoch 06 | Train loss: 0.00953 | Val loss: 0.01129 | Combo score: 0.466 | Smoothed: 0.439 | MCC: 0.339 | REC: 0.356 | PRE: 0.456 | AUC: 0.735 | Threshold: 0.02305
# Epoch 07 | Train loss: 0.00906 | Val loss: 0.01026 | Combo score: 0.485 | Smoothed: 0.444 | MCC: 0.375 | REC: 0.489 | PRE: 0.413 | AUC: 0.776 | Threshold: 0.01809
# Epoch 08 | Train loss: 0.00839 | Val loss: 0.00882 | Combo score: 0.463 | Smoothed: 0.446 | MCC: 0.326 | REC: 0.377 | PRE: 0.417 | AUC: 0.749 | Threshold: 0.01814
# Epoch 09 | Train loss: 0.00787 | Val loss: 0.00804 | Combo score: 0.472 | Smoothed: 0.448 | MCC: 0.360 | REC: 0.325 | PRE: 0.528 | AUC: 0.718 | Threshold: 0.01724
# Epoch 10 | Train loss: 0.00687 | Val loss: 0.00696 | Combo score: 0.474 | Smoothed: 0.451 | MCC: 0.341 | REC: 0.543 | PRE: 0.342 | AUC: 0.775 | Threshold: 0.01011
# Epoch 11 | Train loss: 0.00629 | Val loss: 0.00716 | Combo score: 0.487 | Smoothed: 0.454 | MCC: 0.378 | REC: 0.433 | PRE: 0.456 | AUC: 0.790 | Threshold: 0.01368
# Epoch 12 | Train loss: 0.00596 | Val loss: 0.00645 | Combo score: 0.481 | Smoothed: 0.457 | MCC: 0.364 | REC: 0.448 | PRE: 0.424 | AUC: 0.778 | Threshold: 0.01177
# Epoch 13 | Train loss: 0.00580 | Val loss: 0.00660 | Combo score: 0.477 | Smoothed: 0.459 | MCC: 0.352 | REC: 0.500 | PRE: 0.375 | AUC: 0.782 | Threshold: 0.01056
# Epoch 14 | Train loss: 0.00566 | Val loss: 0.00633 | Combo score: 0.483 | Smoothed: 0.461 | MCC: 0.375 | REC: 0.430 | PRE: 0.454 | AUC: 0.763 | Threshold: 0.01175
# Epoch 15 | Train loss: 0.00553 | Val loss: 0.00729 | Combo score: 0.500 | Smoothed: 0.465 | MCC: 0.414 | REC: 0.357 | PRE: 0.598 | AUC: 0.778 | Threshold: 0.01487
# Epoch 16 | Train loss: 0.00537 | Val loss: 0.00665 | Combo score: 0.478 | Smoothed: 0.467 | MCC: 0.360 | REC: 0.477 | PRE: 0.400 | AUC: 0.760 | Threshold: 0.00969
# Epoch 17 | Train loss: 0.00533 | Val loss: 0.00691 | Combo score: 0.498 | Smoothed: 0.470 | MCC: 0.413 | REC: 0.372 | PRE: 0.579 | AUC: 0.770 | Threshold: 0.01437
# Epoch 18 | Train loss: 0.00525 | Val loss: 0.00692 | Combo score: 0.503 | Smoothed: 0.473 | MCC: 0.421 | REC: 0.366 | PRE: 0.601 | AUC: 0.789 | Threshold: 0.01447
# Epoch 19 | Train loss: 0.00509 | Val loss: 0.00703 | Combo score: 0.490 | Smoothed: 0.475 | MCC: 0.391 | REC: 0.413 | PRE: 0.494 | AUC: 0.774 | Threshold: 0.01254
# Epoch 20 | Train loss: 0.00499 | Val loss: 0.00714 | Combo score: 0.472 | Smoothed: 0.475 | MCC: 0.352 | REC: 0.403 | PRE: 0.438 | AUC: 0.744 | Threshold: 0.01140
# Epoch 21 | Train loss: 0.00487 | Val loss: 0.00630 | Combo score: 0.488 | Smoothed: 0.476 | MCC: 0.384 | REC: 0.415 | PRE: 0.480 | AUC: 0.784 | Threshold: 0.01097
# Epoch 22 | Train loss: 0.00464 | Val loss: 0.00674 | Combo score: 0.487 | Smoothed: 0.477 | MCC: 0.382 | REC: 0.413 | PRE: 0.478 | AUC: 0.777 | Threshold: 0.01109
# Epoch 23 | Train loss: 0.00447 | Val loss: 0.00593 | Combo score: 0.478 | Smoothed: 0.477 | MCC: 0.357 | REC: 0.449 | PRE: 0.413 | AUC: 0.777 | Threshold: 0.00859
# Epoch 24 | Train loss: 0.00436 | Val loss: 0.00650 | Combo score: 0.490 | Smoothed: 0.478 | MCC: 0.395 | REC: 0.318 | PRE: 0.611 | AUC: 0.749 | Threshold: 0.01500
# Epoch 25 | Train loss: 0.00447 | Val loss: 0.00641 | Combo score: 0.488 | Smoothed: 0.479 | MCC: 0.384 | REC: 0.444 | PRE: 0.457 | AUC: 0.780 | Threshold: 0.00960
# Epoch 26 | Train loss: 0.00414 | Val loss: 0.00587 | Combo score: 0.477 | Smoothed: 0.479 | MCC: 0.358 | REC: 0.413 | PRE: 0.440 | AUC: 0.773 | Threshold: 0.00907
# Epoch 27 | Train loss: 0.00399 | Val loss: 0.00583 | Combo score: 0.485 | Smoothed: 0.480 | MCC: 0.379 | REC: 0.323 | PRE: 0.570 | AUC: 0.769 | Threshold: 0.01218
# Epoch 28 | Train loss: 0.00390 | Val loss: 0.00539 | Combo score: 0.474 | Smoothed: 0.479 | MCC: 0.357 | REC: 0.327 | PRE: 0.520 | AUC: 0.744 | Threshold: 0.01029
# Epoch 29 | Train loss: 0.00379 | Val loss: 0.00492 | Combo score: 0.474 | Smoothed: 0.479 | MCC: 0.354 | REC: 0.287 | PRE: 0.566 | AUC: 0.751 | Threshold: 0.01160
# Epoch 30 | Train loss: 0.00366 | Val loss: 0.00512 | Combo score: 0.470 | Smoothed: 0.478 | MCC: 0.345 | REC: 0.318 | PRE: 0.507 | AUC: 0.754 | Threshold: 0.01066
# Epoch 31 | Train loss: 0.00355 | Val loss: 0.00463 | Combo score: 0.469 | Smoothed: 0.477 | MCC: 0.342 | REC: 0.274 | PRE: 0.557 | AUC: 0.751 | Threshold: 0.01146
# Epoch 32 | Train loss: 0.00344 | Val loss: 0.00420 | Combo score: 0.454 | Smoothed: 0.475 | MCC: 0.302 | REC: 0.410 | PRE: 0.359 | AUC: 0.749 | Threshold: 0.00738
# Epoch 33 | Train loss: 0.00332 | Val loss: 0.00431 | Combo score: 0.468 | Smoothed: 0.474 | MCC: 0.335 | REC: 0.327 | PRE: 0.476 | AUC: 0.770 | Threshold: 0.00946
# Epoch 34 | Train loss: 0.00324 | Val loss: 0.00427 | Combo score: 0.454 | Smoothed: 0.472 | MCC: 0.308 | REC: 0.307 | PRE: 0.447 | AUC: 0.740 | Threshold: 0.00928
# Epoch 35 | Train loss: 0.00319 | Val loss: 0.00478 | Combo score: 0.466 | Smoothed: 0.471 | MCC: 0.334 | REC: 0.359 | PRE: 0.444 | AUC: 0.761 | Threshold: 0.00902
# Epoch 36 | Train loss: 0.00314 | Val loss: 0.00415 | Combo score: 0.477 | Smoothed: 0.472 | MCC: 0.357 | REC: 0.339 | PRE: 0.505 | AUC: 0.780 | Threshold: 0.00901
# Epoch 37 | Train loss: 0.00303 | Val loss: 0.00393 | Combo score: 0.451 | Smoothed: 0.470 | MCC: 0.294 | REC: 0.372 | PRE: 0.371 | AUC: 0.752 | Threshold: 0.00710
# Early stopping at epoch 37 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 4 summary (years: [2008, 2009]) ---
# Number of fire events in validation: (554 / 5047)
# Best epoch: 18
# Threshold used: 0.01447
# Validation metrics:
# ACC: 90.4%
# PRE: 60.1%
# REC: 36.6%
# MCC: 0.42
# AUC: 0.79
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 5 (years: [2009, 2010])
# Epoch 01 | Train loss: 0.04662 | Val loss: 0.01853 | Combo score: 0.465 | Smoothed: 0.465 | MCC: 0.314 | REC: 0.538 | PRE: 0.310 | AUC: 0.786 | Threshold: 0.02796
# Epoch 02 | Train loss: 0.01596 | Val loss: 0.01516 | Combo score: 0.453 | Smoothed: 0.464 | MCC: 0.297 | REC: 0.430 | PRE: 0.337 | AUC: 0.761 | Threshold: 0.02445
# Epoch 03 | Train loss: 0.01322 | Val loss: 0.01403 | Combo score: 0.446 | Smoothed: 0.462 | MCC: 0.285 | REC: 0.493 | PRE: 0.295 | AUC: 0.713 | Threshold: 0.02128
# Epoch 04 | Train loss: 0.01199 | Val loss: 0.01255 | Combo score: 0.457 | Smoothed: 0.462 | MCC: 0.323 | REC: 0.315 | PRE: 0.464 | AUC: 0.708 | Threshold: 0.03147
# Epoch 05 | Train loss: 0.01092 | Val loss: 0.01141 | Combo score: 0.429 | Smoothed: 0.458 | MCC: 0.249 | REC: 0.399 | PRE: 0.293 | AUC: 0.695 | Threshold: 0.02036
# Epoch 06 | Train loss: 0.01024 | Val loss: 0.01112 | Combo score: 0.449 | Smoothed: 0.457 | MCC: 0.302 | REC: 0.330 | PRE: 0.412 | AUC: 0.711 | Threshold: 0.02536
# Epoch 07 | Train loss: 0.00928 | Val loss: 0.01039 | Combo score: 0.443 | Smoothed: 0.456 | MCC: 0.285 | REC: 0.363 | PRE: 0.360 | AUC: 0.713 | Threshold: 0.02150
# Epoch 08 | Train loss: 0.00837 | Val loss: 0.00878 | Combo score: 0.462 | Smoothed: 0.457 | MCC: 0.328 | REC: 0.421 | PRE: 0.386 | AUC: 0.737 | Threshold: 0.01745
# Epoch 09 | Train loss: 0.00760 | Val loss: 0.00760 | Combo score: 0.468 | Smoothed: 0.458 | MCC: 0.346 | REC: 0.380 | PRE: 0.443 | AUC: 0.728 | Threshold: 0.01730
# Epoch 10 | Train loss: 0.00726 | Val loss: 0.00737 | Combo score: 0.468 | Smoothed: 0.459 | MCC: 0.349 | REC: 0.369 | PRE: 0.458 | AUC: 0.717 | Threshold: 0.01708
# Epoch 11 | Train loss: 0.00682 | Val loss: 0.00692 | Combo score: 0.461 | Smoothed: 0.459 | MCC: 0.331 | REC: 0.382 | PRE: 0.417 | AUC: 0.721 | Threshold: 0.01499
# Epoch 12 | Train loss: 0.00664 | Val loss: 0.00686 | Combo score: 0.467 | Smoothed: 0.460 | MCC: 0.342 | REC: 0.356 | PRE: 0.458 | AUC: 0.738 | Threshold: 0.01588
# Epoch 13 | Train loss: 0.00633 | Val loss: 0.00653 | Combo score: 0.485 | Smoothed: 0.462 | MCC: 0.384 | REC: 0.287 | PRE: 0.631 | AUC: 0.743 | Threshold: 0.01909
# Epoch 14 | Train loss: 0.00612 | Val loss: 0.00653 | Combo score: 0.484 | Smoothed: 0.464 | MCC: 0.383 | REC: 0.291 | PRE: 0.624 | AUC: 0.732 | Threshold: 0.01893
# Epoch 15 | Train loss: 0.00593 | Val loss: 0.00625 | Combo score: 0.491 | Smoothed: 0.467 | MCC: 0.396 | REC: 0.291 | PRE: 0.655 | AUC: 0.752 | Threshold: 0.01890
# Epoch 16 | Train loss: 0.00580 | Val loss: 0.00600 | Combo score: 0.486 | Smoothed: 0.469 | MCC: 0.383 | REC: 0.298 | PRE: 0.611 | AUC: 0.753 | Threshold: 0.01640
# Epoch 17 | Train loss: 0.00601 | Val loss: 0.00677 | Combo score: 0.457 | Smoothed: 0.468 | MCC: 0.320 | REC: 0.378 | PRE: 0.403 | AUC: 0.722 | Threshold: 0.01244
# Epoch 18 | Train loss: 0.00616 | Val loss: 0.00633 | Combo score: 0.465 | Smoothed: 0.468 | MCC: 0.339 | REC: 0.330 | PRE: 0.478 | AUC: 0.733 | Threshold: 0.01405
# Epoch 19 | Train loss: 0.00582 | Val loss: 0.00607 | Combo score: 0.470 | Smoothed: 0.468 | MCC: 0.348 | REC: 0.372 | PRE: 0.454 | AUC: 0.742 | Threshold: 0.01212
# Epoch 20 | Train loss: 0.00565 | Val loss: 0.00603 | Combo score: 0.479 | Smoothed: 0.469 | MCC: 0.368 | REC: 0.322 | PRE: 0.544 | AUC: 0.753 | Threshold: 0.01490
# Epoch 21 | Train loss: 0.00547 | Val loss: 0.00576 | Combo score: 0.470 | Smoothed: 0.469 | MCC: 0.347 | REC: 0.343 | PRE: 0.479 | AUC: 0.745 | Threshold: 0.01311
# Epoch 22 | Train loss: 0.00535 | Val loss: 0.00599 | Combo score: 0.483 | Smoothed: 0.470 | MCC: 0.381 | REC: 0.320 | PRE: 0.575 | AUC: 0.740 | Threshold: 0.01444
# Epoch 23 | Train loss: 0.00523 | Val loss: 0.00587 | Combo score: 0.485 | Smoothed: 0.472 | MCC: 0.383 | REC: 0.324 | PRE: 0.574 | AUC: 0.753 | Threshold: 0.01480
# Epoch 24 | Train loss: 0.00516 | Val loss: 0.00559 | Combo score: 0.481 | Smoothed: 0.473 | MCC: 0.377 | REC: 0.315 | PRE: 0.573 | AUC: 0.740 | Threshold: 0.01435
# Epoch 25 | Train loss: 0.00502 | Val loss: 0.00597 | Combo score: 0.481 | Smoothed: 0.474 | MCC: 0.372 | REC: 0.369 | PRE: 0.499 | AUC: 0.758 | Threshold: 0.01309
# Epoch 26 | Train loss: 0.00504 | Val loss: 0.00594 | Combo score: 0.479 | Smoothed: 0.474 | MCC: 0.372 | REC: 0.337 | PRE: 0.534 | AUC: 0.742 | Threshold: 0.01433
# Epoch 27 | Train loss: 0.00486 | Val loss: 0.00535 | Combo score: 0.483 | Smoothed: 0.475 | MCC: 0.382 | REC: 0.322 | PRE: 0.575 | AUC: 0.738 | Threshold: 0.01385
# Epoch 28 | Train loss: 0.00479 | Val loss: 0.00543 | Combo score: 0.485 | Smoothed: 0.476 | MCC: 0.386 | REC: 0.337 | PRE: 0.562 | AUC: 0.748 | Threshold: 0.01350
# Epoch 29 | Train loss: 0.00471 | Val loss: 0.00545 | Combo score: 0.488 | Smoothed: 0.477 | MCC: 0.391 | REC: 0.328 | PRE: 0.585 | AUC: 0.749 | Threshold: 0.01362
# Epoch 30 | Train loss: 0.00465 | Val loss: 0.00525 | Combo score: 0.493 | Smoothed: 0.479 | MCC: 0.405 | REC: 0.318 | PRE: 0.631 | AUC: 0.741 | Threshold: 0.01448
# Epoch 31 | Train loss: 0.00455 | Val loss: 0.00531 | Combo score: 0.480 | Smoothed: 0.479 | MCC: 0.374 | REC: 0.331 | PRE: 0.544 | AUC: 0.745 | Threshold: 0.01313
# Epoch 32 | Train loss: 0.00450 | Val loss: 0.00530 | Combo score: 0.488 | Smoothed: 0.480 | MCC: 0.387 | REC: 0.322 | PRE: 0.584 | AUC: 0.765 | Threshold: 0.01433
# Epoch 33 | Train loss: 0.00439 | Val loss: 0.00525 | Combo score: 0.485 | Smoothed: 0.480 | MCC: 0.388 | REC: 0.326 | PRE: 0.581 | AUC: 0.734 | Threshold: 0.01394
# Epoch 34 | Train loss: 0.00428 | Val loss: 0.00507 | Combo score: 0.475 | Smoothed: 0.480 | MCC: 0.361 | REC: 0.341 | PRE: 0.508 | AUC: 0.747 | Threshold: 0.01243
# Epoch 35 | Train loss: 0.00422 | Val loss: 0.00508 | Combo score: 0.485 | Smoothed: 0.480 | MCC: 0.383 | REC: 0.315 | PRE: 0.587 | AUC: 0.750 | Threshold: 0.01375
# Epoch 36 | Train loss: 0.00418 | Val loss: 0.00505 | Combo score: 0.482 | Smoothed: 0.481 | MCC: 0.377 | REC: 0.339 | PRE: 0.542 | AUC: 0.746 | Threshold: 0.01328
# Epoch 37 | Train loss: 0.00410 | Val loss: 0.00487 | Combo score: 0.472 | Smoothed: 0.480 | MCC: 0.350 | REC: 0.317 | PRE: 0.514 | AUC: 0.755 | Threshold: 0.01276
# Epoch 38 | Train loss: 0.00396 | Val loss: 0.00478 | Combo score: 0.478 | Smoothed: 0.480 | MCC: 0.366 | REC: 0.318 | PRE: 0.545 | AUC: 0.751 | Threshold: 0.01254
# Epoch 39 | Train loss: 0.00389 | Val loss: 0.00489 | Combo score: 0.477 | Smoothed: 0.479 | MCC: 0.364 | REC: 0.337 | PRE: 0.517 | AUC: 0.748 | Threshold: 0.01231
# Epoch 40 | Train loss: 0.00381 | Val loss: 0.00447 | Combo score: 0.469 | Smoothed: 0.478 | MCC: 0.340 | REC: 0.354 | PRE: 0.457 | AUC: 0.763 | Threshold: 0.01014
# Epoch 41 | Train loss: 0.00374 | Val loss: 0.00455 | Combo score: 0.476 | Smoothed: 0.478 | MCC: 0.361 | REC: 0.328 | PRE: 0.522 | AUC: 0.757 | Threshold: 0.01149
# Epoch 42 | Train loss: 0.00363 | Val loss: 0.00451 | Combo score: 0.484 | Smoothed: 0.479 | MCC: 0.378 | REC: 0.304 | PRE: 0.591 | AUC: 0.762 | Threshold: 0.01283
# Epoch 43 | Train loss: 0.00359 | Val loss: 0.00438 | Combo score: 0.481 | Smoothed: 0.479 | MCC: 0.372 | REC: 0.309 | PRE: 0.570 | AUC: 0.758 | Threshold: 0.01227
# Epoch 44 | Train loss: 0.00353 | Val loss: 0.00437 | Combo score: 0.472 | Smoothed: 0.478 | MCC: 0.348 | REC: 0.331 | PRE: 0.493 | AUC: 0.763 | Threshold: 0.01094
# Epoch 45 | Train loss: 0.00350 | Val loss: 0.00464 | Combo score: 0.475 | Smoothed: 0.478 | MCC: 0.358 | REC: 0.345 | PRE: 0.497 | AUC: 0.754 | Threshold: 0.01051
# Epoch 46 | Train loss: 0.00344 | Val loss: 0.00420 | Combo score: 0.461 | Smoothed: 0.476 | MCC: 0.323 | REC: 0.352 | PRE: 0.429 | AUC: 0.747 | Threshold: 0.00953
# Early stopping at epoch 46 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 5 summary (years: [2009, 2010]) ---
# Number of fire events in validation: (537 / 5040)
# Best epoch: 30
# Threshold used: 0.01448
# Validation metrics:
# ACC: 90.8%
# PRE: 63.1%
# REC: 31.8%
# MCC: 0.41
# AUC: 0.74
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 6 (years: [2010, 2011])
# Epoch 01 | Train loss: 0.04965 | Val loss: 0.01962 | Combo score: 0.425 | Smoothed: 0.425 | MCC: 0.219 | REC: 0.560 | PRE: 0.187 | AUC: 0.716 | Threshold: 0.02447
# Epoch 02 | Train loss: 0.01607 | Val loss: 0.01543 | Combo score: 0.406 | Smoothed: 0.423 | MCC: 0.191 | REC: 0.353 | PRE: 0.215 | AUC: 0.701 | Threshold: 0.02475
# Epoch 03 | Train loss: 0.01325 | Val loss: 0.01439 | Combo score: 0.392 | Smoothed: 0.420 | MCC: 0.156 | REC: 0.372 | PRE: 0.175 | AUC: 0.676 | Threshold: 0.02146
# Epoch 04 | Train loss: 0.01178 | Val loss: 0.01329 | Combo score: 0.399 | Smoothed: 0.418 | MCC: 0.155 | REC: 0.601 | PRE: 0.140 | AUC: 0.657 | Threshold: 0.01450
# Epoch 05 | Train loss: 0.01077 | Val loss: 0.01263 | Combo score: 0.400 | Smoothed: 0.416 | MCC: 0.153 | REC: 0.659 | PRE: 0.133 | AUC: 0.648 | Threshold: 0.01226
# Epoch 06 | Train loss: 0.01006 | Val loss: 0.01149 | Combo score: 0.379 | Smoothed: 0.412 | MCC: 0.134 | REC: 0.365 | PRE: 0.158 | AUC: 0.627 | Threshold: 0.01698
# Epoch 07 | Train loss: 0.00943 | Val loss: 0.00993 | Combo score: 0.395 | Smoothed: 0.410 | MCC: 0.145 | REC: 0.623 | PRE: 0.132 | AUC: 0.642 | Threshold: 0.01068
# Epoch 08 | Train loss: 0.00869 | Val loss: 0.00967 | Combo score: 0.382 | Smoothed: 0.408 | MCC: 0.132 | REC: 0.476 | PRE: 0.141 | AUC: 0.614 | Threshold: 0.01194
# Epoch 09 | Train loss: 0.00731 | Val loss: 0.00792 | Combo score: 0.388 | Smoothed: 0.406 | MCC: 0.156 | REC: 0.312 | PRE: 0.191 | AUC: 0.662 | Threshold: 0.01341
# Epoch 10 | Train loss: 0.00673 | Val loss: 0.00793 | Combo score: 0.393 | Smoothed: 0.404 | MCC: 0.169 | REC: 0.341 | PRE: 0.195 | AUC: 0.660 | Threshold: 0.01349
# Epoch 11 | Train loss: 0.00642 | Val loss: 0.00731 | Combo score: 0.399 | Smoothed: 0.404 | MCC: 0.181 | REC: 0.345 | PRE: 0.206 | AUC: 0.673 | Threshold: 0.01248
# Epoch 12 | Train loss: 0.00614 | Val loss: 0.00744 | Combo score: 0.402 | Smoothed: 0.404 | MCC: 0.187 | REC: 0.360 | PRE: 0.209 | AUC: 0.678 | Threshold: 0.01261
# Epoch 13 | Train loss: 0.00597 | Val loss: 0.00699 | Combo score: 0.395 | Smoothed: 0.403 | MCC: 0.176 | REC: 0.266 | PRE: 0.232 | AUC: 0.678 | Threshold: 0.01412
# Epoch 14 | Train loss: 0.00580 | Val loss: 0.00721 | Combo score: 0.403 | Smoothed: 0.403 | MCC: 0.188 | REC: 0.372 | PRE: 0.205 | AUC: 0.675 | Threshold: 0.01192
# Epoch 15 | Train loss: 0.00567 | Val loss: 0.00721 | Combo score: 0.403 | Smoothed: 0.403 | MCC: 0.191 | REC: 0.357 | PRE: 0.214 | AUC: 0.674 | Threshold: 0.01272
# Epoch 16 | Train loss: 0.00553 | Val loss: 0.00732 | Combo score: 0.402 | Smoothed: 0.403 | MCC: 0.188 | REC: 0.370 | PRE: 0.206 | AUC: 0.672 | Threshold: 0.01217
# Epoch 17 | Train loss: 0.00548 | Val loss: 0.00681 | Combo score: 0.396 | Smoothed: 0.402 | MCC: 0.171 | REC: 0.353 | PRE: 0.195 | AUC: 0.675 | Threshold: 0.01116
# Epoch 18 | Train loss: 0.00532 | Val loss: 0.00691 | Combo score: 0.401 | Smoothed: 0.402 | MCC: 0.183 | REC: 0.372 | PRE: 0.201 | AUC: 0.671 | Threshold: 0.01146
# Epoch 19 | Train loss: 0.00520 | Val loss: 0.00701 | Combo score: 0.409 | Smoothed: 0.403 | MCC: 0.188 | REC: 0.527 | PRE: 0.171 | AUC: 0.676 | Threshold: 0.00941
# Epoch 20 | Train loss: 0.00508 | Val loss: 0.00657 | Combo score: 0.398 | Smoothed: 0.402 | MCC: 0.183 | REC: 0.304 | PRE: 0.224 | AUC: 0.668 | Threshold: 0.01178
# Epoch 21 | Train loss: 0.00500 | Val loss: 0.00675 | Combo score: 0.407 | Smoothed: 0.403 | MCC: 0.213 | REC: 0.237 | PRE: 0.306 | AUC: 0.661 | Threshold: 0.01502
# Epoch 22 | Train loss: 0.00498 | Val loss: 0.00691 | Combo score: 0.415 | Smoothed: 0.404 | MCC: 0.227 | REC: 0.242 | PRE: 0.327 | AUC: 0.683 | Threshold: 0.01517
# Epoch 23 | Train loss: 0.00487 | Val loss: 0.00671 | Combo score: 0.411 | Smoothed: 0.405 | MCC: 0.218 | REC: 0.261 | PRE: 0.296 | AUC: 0.676 | Threshold: 0.01330
# Epoch 24 | Train loss: 0.00476 | Val loss: 0.00655 | Combo score: 0.412 | Smoothed: 0.405 | MCC: 0.219 | REC: 0.292 | PRE: 0.278 | AUC: 0.678 | Threshold: 0.01302
# Early stopping at epoch 24 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 6 summary (years: [2010, 2011]) ---
# Number of fire events in validation: (414 / 5040)
# Best epoch: 1
# Threshold used: 0.02447
# Validation metrics:
# ACC: 76.4%
# PRE: 18.7%
# REC: 56.0%
# MCC: 0.22
# AUC: 0.72
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 7 (years: [2011, 2012])
# Epoch 01 | Train loss: 0.05050 | Val loss: 0.01987 | Combo score: 0.420 | Smoothed: 0.420 | MCC: 0.210 | REC: 0.549 | PRE: 0.232 | AUC: 0.677 | Threshold: 0.02290
# Epoch 02 | Train loss: 0.01689 | Val loss: 0.01535 | Combo score: 0.420 | Smoothed: 0.420 | MCC: 0.210 | REC: 0.494 | PRE: 0.243 | AUC: 0.705 | Threshold: 0.01910
# Epoch 03 | Train loss: 0.01463 | Val loss: 0.01552 | Combo score: 0.446 | Smoothed: 0.422 | MCC: 0.263 | REC: 0.560 | PRE: 0.272 | AUC: 0.759 | Threshold: 0.01977
# Epoch 04 | Train loss: 0.01275 | Val loss: 0.01265 | Combo score: 0.419 | Smoothed: 0.422 | MCC: 0.225 | REC: 0.413 | PRE: 0.282 | AUC: 0.667 | Threshold: 0.01810
# Epoch 05 | Train loss: 0.01154 | Val loss: 0.01216 | Combo score: 0.396 | Smoothed: 0.420 | MCC: 0.147 | REC: 0.620 | PRE: 0.181 | AUC: 0.621 | Threshold: 0.01129
# Epoch 06 | Train loss: 0.01163 | Val loss: 0.01363 | Combo score: 0.386 | Smoothed: 0.416 | MCC: 0.124 | REC: 0.648 | PRE: 0.166 | AUC: 0.582 | Threshold: 0.01075
# Epoch 07 | Train loss: 0.01132 | Val loss: 0.01118 | Combo score: 0.377 | Smoothed: 0.412 | MCC: 0.123 | REC: 0.400 | PRE: 0.193 | AUC: 0.607 | Threshold: 0.01301
# Epoch 08 | Train loss: 0.01033 | Val loss: 0.01084 | Combo score: 0.386 | Smoothed: 0.410 | MCC: 0.128 | REC: 0.590 | PRE: 0.174 | AUC: 0.593 | Threshold: 0.00960
# Epoch 09 | Train loss: 0.00932 | Val loss: 0.00884 | Combo score: 0.415 | Smoothed: 0.410 | MCC: 0.205 | REC: 0.517 | PRE: 0.234 | AUC: 0.664 | Threshold: 0.01043
# Epoch 10 | Train loss: 0.00766 | Val loss: 0.00714 | Combo score: 0.438 | Smoothed: 0.413 | MCC: 0.264 | REC: 0.501 | PRE: 0.291 | AUC: 0.692 | Threshold: 0.00994
# Epoch 11 | Train loss: 0.00680 | Val loss: 0.00677 | Combo score: 0.436 | Smoothed: 0.415 | MCC: 0.255 | REC: 0.499 | PRE: 0.283 | AUC: 0.701 | Threshold: 0.00937
# Epoch 12 | Train loss: 0.00647 | Val loss: 0.00662 | Combo score: 0.439 | Smoothed: 0.418 | MCC: 0.260 | REC: 0.531 | PRE: 0.278 | AUC: 0.704 | Threshold: 0.00867
# Epoch 13 | Train loss: 0.00623 | Val loss: 0.00660 | Combo score: 0.427 | Smoothed: 0.419 | MCC: 0.230 | REC: 0.526 | PRE: 0.253 | AUC: 0.689 | Threshold: 0.00847
# Epoch 14 | Train loss: 0.00606 | Val loss: 0.00637 | Combo score: 0.439 | Smoothed: 0.421 | MCC: 0.262 | REC: 0.518 | PRE: 0.284 | AUC: 0.701 | Threshold: 0.00870
# Epoch 15 | Train loss: 0.00585 | Val loss: 0.00638 | Combo score: 0.431 | Smoothed: 0.422 | MCC: 0.245 | REC: 0.456 | PRE: 0.288 | AUC: 0.701 | Threshold: 0.00935
# Epoch 16 | Train loss: 0.00576 | Val loss: 0.00630 | Combo score: 0.453 | Smoothed: 0.425 | MCC: 0.305 | REC: 0.410 | PRE: 0.380 | AUC: 0.716 | Threshold: 0.01083
# Epoch 17 | Train loss: 0.00561 | Val loss: 0.00615 | Combo score: 0.447 | Smoothed: 0.427 | MCC: 0.290 | REC: 0.396 | PRE: 0.368 | AUC: 0.715 | Threshold: 0.00955
# Epoch 18 | Train loss: 0.00553 | Val loss: 0.00657 | Combo score: 0.436 | Smoothed: 0.428 | MCC: 0.273 | REC: 0.282 | PRE: 0.423 | AUC: 0.691 | Threshold: 0.01274
# Epoch 19 | Train loss: 0.00544 | Val loss: 0.00600 | Combo score: 0.460 | Smoothed: 0.431 | MCC: 0.330 | REC: 0.279 | PRE: 0.540 | AUC: 0.696 | Threshold: 0.01417
# Epoch 20 | Train loss: 0.00532 | Val loss: 0.00642 | Combo score: 0.446 | Smoothed: 0.433 | MCC: 0.296 | REC: 0.290 | PRE: 0.458 | AUC: 0.700 | Threshold: 0.01331
# Epoch 21 | Train loss: 0.00520 | Val loss: 0.00683 | Combo score: 0.456 | Smoothed: 0.435 | MCC: 0.316 | REC: 0.273 | PRE: 0.518 | AUC: 0.712 | Threshold: 0.01385
# Epoch 22 | Train loss: 0.00515 | Val loss: 0.00645 | Combo score: 0.439 | Smoothed: 0.435 | MCC: 0.277 | REC: 0.311 | PRE: 0.406 | AUC: 0.699 | Threshold: 0.01104
# Epoch 23 | Train loss: 0.00503 | Val loss: 0.00571 | Combo score: 0.445 | Smoothed: 0.436 | MCC: 0.292 | REC: 0.290 | PRE: 0.452 | AUC: 0.702 | Threshold: 0.01179
# Epoch 24 | Train loss: 0.00491 | Val loss: 0.00627 | Combo score: 0.460 | Smoothed: 0.439 | MCC: 0.329 | REC: 0.260 | PRE: 0.566 | AUC: 0.698 | Threshold: 0.01342
# Epoch 25 | Train loss: 0.00488 | Val loss: 0.00620 | Combo score: 0.436 | Smoothed: 0.438 | MCC: 0.260 | REC: 0.448 | PRE: 0.306 | AUC: 0.700 | Threshold: 0.00865
# Epoch 26 | Train loss: 0.00476 | Val loss: 0.00673 | Combo score: 0.453 | Smoothed: 0.440 | MCC: 0.313 | REC: 0.282 | PRE: 0.500 | AUC: 0.705 | Threshold: 0.01263
# Epoch 27 | Train loss: 0.00469 | Val loss: 0.00625 | Combo score: 0.434 | Smoothed: 0.439 | MCC: 0.256 | REC: 0.450 | PRE: 0.301 | AUC: 0.700 | Threshold: 0.00801
# Epoch 28 | Train loss: 0.00467 | Val loss: 0.00597 | Combo score: 0.441 | Smoothed: 0.439 | MCC: 0.267 | REC: 0.470 | PRE: 0.305 | AUC: 0.720 | Threshold: 0.00765
# Epoch 29 | Train loss: 0.00461 | Val loss: 0.00619 | Combo score: 0.443 | Smoothed: 0.440 | MCC: 0.287 | REC: 0.279 | PRE: 0.453 | AUC: 0.699 | Threshold: 0.01219
# Epoch 30 | Train loss: 0.00448 | Val loss: 0.00579 | Combo score: 0.435 | Smoothed: 0.439 | MCC: 0.245 | REC: 0.545 | PRE: 0.261 | AUC: 0.713 | Threshold: 0.00640
# Epoch 31 | Train loss: 0.00442 | Val loss: 0.00592 | Combo score: 0.451 | Smoothed: 0.441 | MCC: 0.307 | REC: 0.301 | PRE: 0.468 | AUC: 0.705 | Threshold: 0.01134
# Epoch 32 | Train loss: 0.00435 | Val loss: 0.00547 | Combo score: 0.442 | Smoothed: 0.441 | MCC: 0.273 | REC: 0.442 | PRE: 0.324 | AUC: 0.721 | Threshold: 0.00724
# Epoch 33 | Train loss: 0.00428 | Val loss: 0.00535 | Combo score: 0.429 | Smoothed: 0.440 | MCC: 0.237 | REC: 0.485 | PRE: 0.270 | AUC: 0.706 | Threshold: 0.00646
# Epoch 34 | Train loss: 0.00424 | Val loss: 0.00601 | Combo score: 0.441 | Smoothed: 0.440 | MCC: 0.275 | REC: 0.338 | PRE: 0.383 | AUC: 0.729 | Threshold: 0.00980
# Epoch 35 | Train loss: 0.00421 | Val loss: 0.00583 | Combo score: 0.433 | Smoothed: 0.439 | MCC: 0.260 | REC: 0.368 | PRE: 0.343 | AUC: 0.693 | Threshold: 0.00926
# Epoch 36 | Train loss: 0.00421 | Val loss: 0.00523 | Combo score: 0.453 | Smoothed: 0.441 | MCC: 0.304 | REC: 0.402 | PRE: 0.383 | AUC: 0.730 | Threshold: 0.00853
# Epoch 37 | Train loss: 0.00413 | Val loss: 0.00554 | Combo score: 0.436 | Smoothed: 0.440 | MCC: 0.252 | REC: 0.494 | PRE: 0.281 | AUC: 0.720 | Threshold: 0.00676
# Epoch 38 | Train loss: 0.00403 | Val loss: 0.00510 | Combo score: 0.431 | Smoothed: 0.439 | MCC: 0.252 | REC: 0.367 | PRE: 0.333 | AUC: 0.701 | Threshold: 0.00812
# Epoch 39 | Train loss: 0.00398 | Val loss: 0.00490 | Combo score: 0.438 | Smoothed: 0.439 | MCC: 0.274 | REC: 0.311 | PRE: 0.401 | AUC: 0.701 | Threshold: 0.00962
# Epoch 40 | Train loss: 0.00392 | Val loss: 0.00496 | Combo score: 0.432 | Smoothed: 0.438 | MCC: 0.255 | REC: 0.370 | PRE: 0.335 | AUC: 0.703 | Threshold: 0.00820
# Epoch 41 | Train loss: 0.00385 | Val loss: 0.00502 | Combo score: 0.441 | Smoothed: 0.439 | MCC: 0.282 | REC: 0.293 | PRE: 0.430 | AUC: 0.702 | Threshold: 0.00954
# Epoch 42 | Train loss: 0.00379 | Val loss: 0.00485 | Combo score: 0.435 | Smoothed: 0.438 | MCC: 0.264 | REC: 0.360 | PRE: 0.352 | AUC: 0.699 | Threshold: 0.00833
# Early stopping at epoch 42 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 7 summary (years: [2011, 2012]) ---
# Number of fire events in validation: (627 / 5047)
# Best epoch: 24
# Threshold used: 0.01342
# Validation metrics:
# ACC: 88.3%
# PRE: 56.6%
# REC: 26.0%
# MCC: 0.33
# AUC: 0.70
# ==================================================
#
#
# ==================================================
# Training LSTM-AE with sequence length: 10_day | Fold 8 (years: [2012, 2013])
# Epoch 01 | Train loss: 0.04454 | Val loss: 0.01748 | Combo score: 0.468 | Smoothed: 0.468 | MCC: 0.315 | REC: 0.647 | PRE: 0.326 | AUC: 0.750 | Threshold: 0.02113
# Epoch 02 | Train loss: 0.01537 | Val loss: 0.01453 | Combo score: 0.446 | Smoothed: 0.466 | MCC: 0.296 | REC: 0.465 | PRE: 0.375 | AUC: 0.647 | Threshold: 0.02072
# Epoch 03 | Train loss: 0.01312 | Val loss: 0.01261 | Combo score: 0.471 | Smoothed: 0.466 | MCC: 0.354 | REC: 0.420 | PRE: 0.478 | AUC: 0.701 | Threshold: 0.02069
# Epoch 04 | Train loss: 0.01180 | Val loss: 0.01168 | Combo score: 0.474 | Smoothed: 0.467 | MCC: 0.360 | REC: 0.446 | PRE: 0.468 | AUC: 0.703 | Threshold: 0.01981
# Epoch 05 | Train loss: 0.01094 | Val loss: 0.01008 | Combo score: 0.436 | Smoothed: 0.464 | MCC: 0.267 | REC: 0.405 | PRE: 0.368 | AUC: 0.673 | Threshold: 0.01473
# Epoch 06 | Train loss: 0.00978 | Val loss: 0.00827 | Combo score: 0.442 | Smoothed: 0.462 | MCC: 0.261 | REC: 0.558 | PRE: 0.305 | AUC: 0.703 | Threshold: 0.00988
# Epoch 07 | Train loss: 0.00800 | Val loss: 0.00686 | Combo score: 0.473 | Smoothed: 0.463 | MCC: 0.338 | REC: 0.553 | PRE: 0.383 | AUC: 0.750 | Threshold: 0.00889
# Epoch 08 | Train loss: 0.00724 | Val loss: 0.00703 | Combo score: 0.462 | Smoothed: 0.463 | MCC: 0.314 | REC: 0.539 | PRE: 0.363 | AUC: 0.728 | Threshold: 0.00917
# Epoch 09 | Train loss: 0.00686 | Val loss: 0.00598 | Combo score: 0.472 | Smoothed: 0.464 | MCC: 0.338 | REC: 0.517 | PRE: 0.400 | AUC: 0.742 | Threshold: 0.00835
# Epoch 10 | Train loss: 0.00649 | Val loss: 0.00626 | Combo score: 0.474 | Smoothed: 0.465 | MCC: 0.335 | REC: 0.632 | PRE: 0.349 | AUC: 0.749 | Threshold: 0.00733
# Epoch 11 | Train loss: 0.00631 | Val loss: 0.00601 | Combo score: 0.470 | Smoothed: 0.465 | MCC: 0.341 | REC: 0.462 | PRE: 0.432 | AUC: 0.725 | Threshold: 0.00965
# Epoch 12 | Train loss: 0.00611 | Val loss: 0.00551 | Combo score: 0.464 | Smoothed: 0.465 | MCC: 0.320 | REC: 0.554 | PRE: 0.363 | AUC: 0.727 | Threshold: 0.00737
# Epoch 13 | Train loss: 0.00594 | Val loss: 0.00557 | Combo score: 0.470 | Smoothed: 0.466 | MCC: 0.340 | REC: 0.474 | PRE: 0.424 | AUC: 0.729 | Threshold: 0.00866
# Epoch 14 | Train loss: 0.00580 | Val loss: 0.00570 | Combo score: 0.483 | Smoothed: 0.467 | MCC: 0.372 | REC: 0.490 | PRE: 0.456 | AUC: 0.740 | Threshold: 0.00940
# Epoch 15 | Train loss: 0.00568 | Val loss: 0.00533 | Combo score: 0.476 | Smoothed: 0.468 | MCC: 0.356 | REC: 0.494 | PRE: 0.434 | AUC: 0.727 | Threshold: 0.00869
# Epoch 16 | Train loss: 0.00561 | Val loss: 0.00549 | Combo score: 0.467 | Smoothed: 0.468 | MCC: 0.328 | REC: 0.549 | PRE: 0.374 | AUC: 0.723 | Threshold: 0.00726
# Epoch 17 | Train loss: 0.00556 | Val loss: 0.00519 | Combo score: 0.476 | Smoothed: 0.469 | MCC: 0.351 | REC: 0.480 | PRE: 0.435 | AUC: 0.746 | Threshold: 0.00816
# Epoch 18 | Train loss: 0.00537 | Val loss: 0.00504 | Combo score: 0.472 | Smoothed: 0.469 | MCC: 0.339 | REC: 0.563 | PRE: 0.380 | AUC: 0.733 | Threshold: 0.00679
# Epoch 19 | Train loss: 0.00530 | Val loss: 0.00501 | Combo score: 0.465 | Smoothed: 0.469 | MCC: 0.324 | REC: 0.544 | PRE: 0.372 | AUC: 0.719 | Threshold: 0.00682
# Epoch 20 | Train loss: 0.00518 | Val loss: 0.00506 | Combo score: 0.462 | Smoothed: 0.468 | MCC: 0.326 | REC: 0.420 | PRE: 0.437 | AUC: 0.712 | Threshold: 0.00852
# Epoch 21 | Train loss: 0.00508 | Val loss: 0.00503 | Combo score: 0.469 | Smoothed: 0.468 | MCC: 0.332 | REC: 0.557 | PRE: 0.375 | AUC: 0.725 | Threshold: 0.00673
# Epoch 22 | Train loss: 0.00494 | Val loss: 0.00483 | Combo score: 0.471 | Smoothed: 0.468 | MCC: 0.341 | REC: 0.545 | PRE: 0.391 | AUC: 0.721 | Threshold: 0.00689
# Epoch 23 | Train loss: 0.00488 | Val loss: 0.00469 | Combo score: 0.466 | Smoothed: 0.468 | MCC: 0.333 | REC: 0.437 | PRE: 0.437 | AUC: 0.722 | Threshold: 0.00767
# Epoch 24 | Train loss: 0.00482 | Val loss: 0.00472 | Combo score: 0.470 | Smoothed: 0.468 | MCC: 0.339 | REC: 0.485 | PRE: 0.417 | AUC: 0.725 | Threshold: 0.00712
# Epoch 25 | Train loss: 0.00469 | Val loss: 0.00482 | Combo score: 0.456 | Smoothed: 0.467 | MCC: 0.299 | REC: 0.535 | PRE: 0.349 | AUC: 0.725 | Threshold: 0.00626
# Epoch 26 | Train loss: 0.00465 | Val loss: 0.00528 | Combo score: 0.438 | Smoothed: 0.464 | MCC: 0.262 | REC: 0.490 | PRE: 0.328 | AUC: 0.687 | Threshold: 0.00743
# Epoch 27 | Train loss: 0.00473 | Val loss: 0.00455 | Combo score: 0.476 | Smoothed: 0.465 | MCC: 0.352 | REC: 0.515 | PRE: 0.418 | AUC: 0.737 | Threshold: 0.00686
# Epoch 28 | Train loss: 0.00451 | Val loss: 0.00465 | Combo score: 0.458 | Smoothed: 0.465 | MCC: 0.311 | REC: 0.441 | PRE: 0.405 | AUC: 0.728 | Threshold: 0.00718
# Early stopping at epoch 28 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 8 summary (years: [2012, 2013]) ---
# ...
# Epoch 12 | Train loss: 0.01100 | Val loss: 0.01888 | Combo score: 0.504 | Smoothed: 0.496 | MCC: 0.393 | REC: 0.738 | PRE: 0.364 | AUC: 0.812 | Threshold: 0.02108
# Epoch 13 | Train loss: 0.01069 | Val loss: 0.01681 | Combo score: 0.485 | Smoothed: 0.495 | MCC: 0.354 | REC: 0.600 | PRE: 0.377 | AUC: 0.795 | Threshold: 0.02291
# Epoch 14 | Train loss: 0.01042 | Val loss: 0.01741 | Combo score: 0.482 | Smoothed: 0.494 | MCC: 0.341 | REC: 0.638 | PRE: 0.350 | AUC: 0.798 | Threshold: 0.02081
# Epoch 15 | Train loss: 0.00985 | Val loss: 0.01631 | Combo score: 0.485 | Smoothed: 0.493 | MCC: 0.355 | REC: 0.576 | PRE: 0.388 | AUC: 0.799 | Threshold: 0.02326
# Epoch 16 | Train loss: 0.00916 | Val loss: 0.01391 | Combo score: 0.496 | Smoothed: 0.493 | MCC: 0.363 | REC: 0.829 | PRE: 0.310 | AUC: 0.799 | Threshold: 0.01194
# Epoch 17 | Train loss: 0.00967 | Val loss: 0.01752 | Combo score: 0.489 | Smoothed: 0.493 | MCC: 0.366 | REC: 0.561 | PRE: 0.407 | AUC: 0.808 | Threshold: 0.02855
# Epoch 18 | Train loss: 0.00911 | Val loss: 0.01602 | Combo score: 0.481 | Smoothed: 0.492 | MCC: 0.347 | REC: 0.587 | PRE: 0.376 | AUC: 0.791 | Threshold: 0.02277
# Epoch 19 | Train loss: 0.00894 | Val loss: 0.01633 | Combo score: 0.477 | Smoothed: 0.490 | MCC: 0.335 | REC: 0.596 | PRE: 0.359 | AUC: 0.788 | Threshold: 0.02168
# Epoch 20 | Train loss: 0.00881 | Val loss: 0.01628 | Combo score: 0.484 | Smoothed: 0.490 | MCC: 0.354 | REC: 0.591 | PRE: 0.381 | AUC: 0.790 | Threshold: 0.02302
# Epoch 21 | Train loss: 0.00866 | Val loss: 0.01517 | Combo score: 0.476 | Smoothed: 0.488 | MCC: 0.336 | REC: 0.588 | PRE: 0.364 | AUC: 0.775 | Threshold: 0.02105
# Epoch 22 | Train loss: 0.00862 | Val loss: 0.01524 | Combo score: 0.484 | Smoothed: 0.488 | MCC: 0.355 | REC: 0.602 | PRE: 0.378 | AUC: 0.784 | Threshold: 0.01977
# Epoch 23 | Train loss: 0.00869 | Val loss: 0.01579 | Combo score: 0.485 | Smoothed: 0.487 | MCC: 0.353 | REC: 0.619 | PRE: 0.369 | AUC: 0.794 | Threshold: 0.02088
# Epoch 24 | Train loss: 0.00856 | Val loss: 0.01520 | Combo score: 0.476 | Smoothed: 0.486 | MCC: 0.335 | REC: 0.584 | PRE: 0.364 | AUC: 0.779 | Threshold: 0.02078
# Early stopping at epoch 24 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 8 summary (years: [2012, 2013]) ---
# Number of fire events in validation: (748 / 4907)
# Best epoch: 4
# Threshold used: 0.04163
# Validation metrics:
# ACC: 75.4%
# PRE: 36.0%
# REC: 79.4%
# MCC: 0.41
# AUC: 0.82
# ==================================================
#
#
# ==================================================
# Training Bi-LSTM-AE with sequence length: monthly | Fold 9 (years: [2013, 2014])
# Epoch 01 | Train loss: 0.05310 | Val loss: 0.04769 | Combo score: 0.482 | Smoothed: 0.482 | MCC: 0.340 | REC: 0.698 | PRE: 0.330 | AUC: 0.783 | Threshold: 0.04665
# Epoch 02 | Train loss: 0.02711 | Val loss: 0.03939 | Combo score: 0.474 | Smoothed: 0.481 | MCC: 0.316 | REC: 0.796 | PRE: 0.285 | AUC: 0.747 | Threshold: 0.03090
# Epoch 03 | Train loss: 0.03400 | Val loss: 0.06136 | Combo score: 0.419 | Smoothed: 0.475 | MCC: 0.219 | REC: 0.417 | PRE: 0.307 | AUC: 0.673 | Threshold: 0.08406
# Epoch 04 | Train loss: 0.03702 | Val loss: 0.04618 | Combo score: 0.476 | Smoothed: 0.475 | MCC: 0.337 | REC: 0.582 | PRE: 0.367 | AUC: 0.777 | Threshold: 0.06043
# Epoch 05 | Train loss: 0.02031 | Val loss: 0.02541 | Combo score: 0.517 | Smoothed: 0.479 | MCC: 0.425 | REC: 0.718 | PRE: 0.403 | AUC: 0.830 | Threshold: 0.03603
# Epoch 06 | Train loss: 0.01437 | Val loss: 0.02014 | Combo score: 0.475 | Smoothed: 0.479 | MCC: 0.336 | REC: 0.585 | PRE: 0.365 | AUC: 0.771 | Threshold: 0.02938
# Epoch 07 | Train loss: 0.01290 | Val loss: 0.01681 | Combo score: 0.469 | Smoothed: 0.478 | MCC: 0.324 | REC: 0.605 | PRE: 0.346 | AUC: 0.740 | Threshold: 0.02078
# Epoch 08 | Train loss: 0.01115 | Val loss: 0.01568 | Combo score: 0.473 | Smoothed: 0.477 | MCC: 0.334 | REC: 0.565 | PRE: 0.372 | AUC: 0.761 | Threshold: 0.02290
# Epoch 09 | Train loss: 0.01038 | Val loss: 0.01552 | Combo score: 0.477 | Smoothed: 0.477 | MCC: 0.340 | REC: 0.619 | PRE: 0.357 | AUC: 0.755 | Threshold: 0.01957
# Epoch 10 | Train loss: 0.01003 | Val loss: 0.01630 | Combo score: 0.482 | Smoothed: 0.478 | MCC: 0.353 | REC: 0.628 | PRE: 0.366 | AUC: 0.764 | Threshold: 0.02196
# Epoch 11 | Train loss: 0.01015 | Val loss: 0.01698 | Combo score: 0.482 | Smoothed: 0.478 | MCC: 0.345 | REC: 0.652 | PRE: 0.350 | AUC: 0.782 | Threshold: 0.02182
# Epoch 12 | Train loss: 0.01001 | Val loss: 0.01640 | Combo score: 0.480 | Smoothed: 0.478 | MCC: 0.348 | REC: 0.598 | PRE: 0.373 | AUC: 0.771 | Threshold: 0.02425
# Epoch 13 | Train loss: 0.00964 | Val loss: 0.01559 | Combo score: 0.484 | Smoothed: 0.479 | MCC: 0.359 | REC: 0.611 | PRE: 0.379 | AUC: 0.770 | Threshold: 0.02159
# Epoch 14 | Train loss: 0.00981 | Val loss: 0.01732 | Combo score: 0.462 | Smoothed: 0.477 | MCC: 0.307 | REC: 0.549 | PRE: 0.349 | AUC: 0.754 | Threshold: 0.02648
# Epoch 15 | Train loss: 0.00999 | Val loss: 0.01650 | Combo score: 0.454 | Smoothed: 0.475 | MCC: 0.291 | REC: 0.533 | PRE: 0.340 | AUC: 0.734 | Threshold: 0.02575
# Epoch 16 | Train loss: 0.00974 | Val loss: 0.01653 | Combo score: 0.460 | Smoothed: 0.473 | MCC: 0.302 | REC: 0.569 | PRE: 0.338 | AUC: 0.744 | Threshold: 0.02538
# Epoch 17 | Train loss: 0.00955 | Val loss: 0.01493 | Combo score: 0.446 | Smoothed: 0.471 | MCC: 0.266 | REC: 0.573 | PRE: 0.303 | AUC: 0.725 | Threshold: 0.01953
# Epoch 18 | Train loss: 0.00921 | Val loss: 0.01420 | Combo score: 0.473 | Smoothed: 0.471 | MCC: 0.328 | REC: 0.618 | PRE: 0.345 | AUC: 0.766 | Threshold: 0.01824
# Epoch 19 | Train loss: 0.00843 | Val loss: 0.01556 | Combo score: 0.479 | Smoothed: 0.472 | MCC: 0.348 | REC: 0.595 | PRE: 0.374 | AUC: 0.762 | Threshold: 0.02256
# Epoch 20 | Train loss: 0.00847 | Val loss: 0.01363 | Combo score: 0.473 | Smoothed: 0.472 | MCC: 0.336 | REC: 0.545 | PRE: 0.382 | AUC: 0.757 | Threshold: 0.02178
# Epoch 21 | Train loss: 0.00812 | Val loss: 0.01321 | Combo score: 0.456 | Smoothed: 0.470 | MCC: 0.298 | REC: 0.477 | PRE: 0.369 | AUC: 0.747 | Threshold: 0.02123
# Epoch 22 | Train loss: 0.00795 | Val loss: 0.01352 | Combo score: 0.473 | Smoothed: 0.471 | MCC: 0.328 | REC: 0.641 | PRE: 0.338 | AUC: 0.752 | Threshold: 0.01714
# Epoch 23 | Train loss: 0.00780 | Val loss: 0.01390 | Combo score: 0.465 | Smoothed: 0.470 | MCC: 0.314 | REC: 0.546 | PRE: 0.358 | AUC: 0.753 | Threshold: 0.02097
# Epoch 24 | Train loss: 0.00796 | Val loss: 0.01341 | Combo score: 0.460 | Smoothed: 0.469 | MCC: 0.305 | REC: 0.517 | PRE: 0.360 | AUC: 0.748 | Threshold: 0.01902
# Early stopping at epoch 24 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 9 summary (years: [2013, 2014]) ---
# Number of fire events in validation: (749 / 4900)
# Best epoch: 5
# Threshold used: 0.03603
# Validation metrics:
# ACC: 79.4%
# PRE: 40.3%
# REC: 71.8%
# MCC: 0.43
# AUC: 0.83
# ==================================================
#
#
# ==================================================
# Training Bi-LSTM-AE with sequence length: monthly | Fold 10 (years: [2014, 2015])
# Epoch 01 | Train loss: 0.05619 | Val loss: 0.04505 | Combo score: 0.470 | Smoothed: 0.470 | MCC: 0.324 | REC: 0.585 | PRE: 0.341 | AUC: 0.767 | Threshold: 0.06581
# Epoch 02 | Train loss: 0.02287 | Val loss: 0.02246 | Combo score: 0.457 | Smoothed: 0.469 | MCC: 0.295 | REC: 0.617 | PRE: 0.303 | AUC: 0.728 | Threshold: 0.03005
# Epoch 03 | Train loss: 0.01474 | Val loss: 0.02055 | Combo score: 0.474 | Smoothed: 0.470 | MCC: 0.332 | REC: 0.647 | PRE: 0.327 | AUC: 0.755 | Threshold: 0.02755
# Epoch 04 | Train loss: 0.01322 | Val loss: 0.02145 | Combo score: 0.474 | Smoothed: 0.470 | MCC: 0.330 | REC: 0.628 | PRE: 0.332 | AUC: 0.775 | Threshold: 0.03011
# Epoch 05 | Train loss: 0.01549 | Val loss: 0.02334 | Combo score: 0.500 | Smoothed: 0.473 | MCC: 0.383 | REC: 0.787 | PRE: 0.328 | AUC: 0.797 | Threshold: 0.02469
# Epoch 06 | Train loss: 0.01228 | Val loss: 0.02458 | Combo score: 0.483 | Smoothed: 0.474 | MCC: 0.351 | REC: 0.637 | PRE: 0.349 | AUC: 0.783 | Threshold: 0.03496
# Epoch 07 | Train loss: 0.01191 | Val loss: 0.01919 | Combo score: 0.465 | Smoothed: 0.473 | MCC: 0.308 | REC: 0.496 | PRE: 0.359 | AUC: 0.798 | Threshold: 0.02901
# Epoch 08 | Train loss: 0.01143 | Val loss: 0.01973 | Combo score: 0.500 | Smoothed: 0.476 | MCC: 0.378 | REC: 0.785 | PRE: 0.324 | AUC: 0.814 | Threshold: 0.01861
# Epoch 09 | Train loss: 0.01095 | Val loss: 0.01764 | Combo score: 0.443 | Smoothed: 0.473 | MCC: 0.275 | REC: 0.375 | PRE: 0.380 | AUC: 0.727 | Threshold: 0.02839
# Epoch 10 | Train loss: 0.01302 | Val loss: 0.01822 | Combo score: 0.470 | Smoothed: 0.472 | MCC: 0.325 | REC: 0.589 | PRE: 0.341 | AUC: 0.761 | Threshold: 0.02240
# Epoch 11 | Train loss: 0.01040 | Val loss: 0.01662 | Combo score: 0.463 | Smoothed: 0.471 | MCC: 0.311 | REC: 0.566 | PRE: 0.335 | AUC: 0.749 | Threshold: 0.01900
# Epoch 12 | Train loss: 0.00998 | Val loss: 0.01656 | Combo score: 0.430 | Smoothed: 0.467 | MCC: 0.220 | REC: 0.624 | PRE: 0.243 | AUC: 0.701 | Threshold: 0.01326
# Epoch 13 | Train loss: 0.00982 | Val loss: 0.01531 | Combo score: 0.456 | Smoothed: 0.466 | MCC: 0.308 | REC: 0.437 | PRE: 0.388 | AUC: 0.723 | Threshold: 0.02241
# Epoch 14 | Train loss: 0.00874 | Val loss: 0.01429 | Combo score: 0.440 | Smoothed: 0.464 | MCC: 0.265 | REC: 0.481 | PRE: 0.319 | AUC: 0.704 | Threshold: 0.01546
# Epoch 15 | Train loss: 0.00851 | Val loss: 0.01444 | Combo score: 0.413 | Smoothed: 0.458 | MCC: 0.185 | REC: 0.563 | PRE: 0.230 | AUC: 0.682 | Threshold: 0.01180
# Epoch 16 | Train loss: 0.00855 | Val loss: 0.01352 | Combo score: 0.429 | Smoothed: 0.456 | MCC: 0.195 | REC: 0.849 | PRE: 0.195 | AUC: 0.681 | Threshold: 0.00695
# Epoch 17 | Train loss: 0.00807 | Val loss: 0.01435 | Combo score: 0.432 | Smoothed: 0.453 | MCC: 0.223 | REC: 0.631 | PRE: 0.244 | AUC: 0.711 | Threshold: 0.01093
# Epoch 18 | Train loss: 0.00792 | Val loss: 0.01330 | Combo score: 0.434 | Smoothed: 0.451 | MCC: 0.247 | REC: 0.464 | PRE: 0.307 | AUC: 0.714 | Threshold: 0.01334
# Epoch 19 | Train loss: 0.00751 | Val loss: 0.01178 | Combo score: 0.458 | Smoothed: 0.452 | MCC: 0.311 | REC: 0.494 | PRE: 0.364 | AUC: 0.717 | Threshold: 0.01285
# Epoch 20 | Train loss: 0.00687 | Val loss: 0.01258 | Combo score: 0.458 | Smoothed: 0.453 | MCC: 0.296 | REC: 0.591 | PRE: 0.312 | AUC: 0.741 | Threshold: 0.01100
# Epoch 21 | Train loss: 0.00701 | Val loss: 0.01198 | Combo score: 0.452 | Smoothed: 0.452 | MCC: 0.303 | REC: 0.395 | PRE: 0.405 | AUC: 0.710 | Threshold: 0.01628
# Epoch 22 | Train loss: 0.00718 | Val loss: 0.01230 | Combo score: 0.448 | Smoothed: 0.452 | MCC: 0.282 | REC: 0.486 | PRE: 0.336 | AUC: 0.718 | Threshold: 0.01287
# Epoch 23 | Train loss: 0.00671 | Val loss: 0.01035 | Combo score: 0.423 | Smoothed: 0.449 | MCC: 0.217 | REC: 0.490 | PRE: 0.270 | AUC: 0.698 | Threshold: 0.00902
# Epoch 24 | Train loss: 0.00601 | Val loss: 0.01046 | Combo score: 0.429 | Smoothed: 0.447 | MCC: 0.228 | REC: 0.488 | PRE: 0.280 | AUC: 0.721 | Threshold: 0.00930
# Early stopping at epoch 24 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 10 summary (years: [2014, 2015]) ---
# Number of fire events in validation: (694 / 4900)
# Best epoch: 5
# Threshold used: 0.02469
# Validation metrics:
# ACC: 74.1%
# PRE: 32.8%
# REC: 78.7%
# MCC: 0.38
# AUC: 0.80
# ==================================================
#
#
# ==================================================
# Training Bi-LSTM-AE with sequence length: monthly | Fold 11 (years: [2015, 2016])
# Epoch 01 | Train loss: 0.05140 | Val loss: 0.02900 | Combo score: 0.488 | Smoothed: 0.488 | MCC: 0.348 | REC: 0.826 | PRE: 0.286 | AUC: 0.779 | Threshold: 0.02996
# Epoch 02 | Train loss: 0.01765 | Val loss: 0.02308 | Combo score: 0.481 | Smoothed: 0.487 | MCC: 0.337 | REC: 0.754 | PRE: 0.297 | AUC: 0.769 | Threshold: 0.02611
# Epoch 03 | Train loss: 0.01373 | Val loss: 0.01855 | Combo score: 0.489 | Smoothed: 0.487 | MCC: 0.359 | REC: 0.664 | PRE: 0.345 | AUC: 0.803 | Threshold: 0.02248
# Epoch 04 | Train loss: 0.01144 | Val loss: 0.01764 | Combo score: 0.491 | Smoothed: 0.488 | MCC: 0.374 | REC: 0.608 | PRE: 0.382 | AUC: 0.793 | Threshold: 0.02489
# Epoch 05 | Train loss: 0.01222 | Val loss: 0.01743 | Combo score: 0.476 | Smoothed: 0.487 | MCC: 0.344 | REC: 0.561 | PRE: 0.369 | AUC: 0.763 | Threshold: 0.02651
# Epoch 06 | Train loss: 0.01117 | Val loss: 0.02022 | Combo score: 0.494 | Smoothed: 0.487 | MCC: 0.380 | REC: 0.662 | PRE: 0.366 | AUC: 0.783 | Threshold: 0.02543
# Epoch 07 | Train loss: 0.01023 | Val loss: 0.01873 | Combo score: 0.474 | Smoothed: 0.486 | MCC: 0.337 | REC: 0.586 | PRE: 0.351 | AUC: 0.765 | Threshold: 0.02492
# Epoch 08 | Train loss: 0.00979 | Val loss: 0.01726 | Combo score: 0.487 | Smoothed: 0.486 | MCC: 0.360 | REC: 0.700 | PRE: 0.333 | AUC: 0.778 | Threshold: 0.02105
# Epoch 09 | Train loss: 0.00876 | Val loss: 0.01653 | Combo score: 0.483 | Smoothed: 0.486 | MCC: 0.356 | REC: 0.614 | PRE: 0.361 | AUC: 0.777 | Threshold: 0.02316
# Epoch 10 | Train loss: 0.00815 | Val loss: 0.01447 | Combo score: 0.477 | Smoothed: 0.485 | MCC: 0.341 | REC: 0.594 | PRE: 0.352 | AUC: 0.780 | Threshold: 0.02131
# Epoch 11 | Train loss: 0.00766 | Val loss: 0.01653 | Combo score: 0.487 | Smoothed: 0.485 | MCC: 0.366 | REC: 0.554 | PRE: 0.397 | AUC: 0.798 | Threshold: 0.02797
# Epoch 12 | Train loss: 0.00719 | Val loss: 0.01455 | Combo score: 0.482 | Smoothed: 0.485 | MCC: 0.353 | REC: 0.576 | PRE: 0.372 | AUC: 0.784 | Threshold: 0.02274
# Epoch 13 | Train loss: 0.00675 | Val loss: 0.01371 | Combo score: 0.484 | Smoothed: 0.485 | MCC: 0.359 | REC: 0.569 | PRE: 0.383 | AUC: 0.783 | Threshold: 0.02167
# Epoch 14 | Train loss: 0.00664 | Val loss: 0.01581 | Combo score: 0.479 | Smoothed: 0.484 | MCC: 0.343 | REC: 0.629 | PRE: 0.342 | AUC: 0.781 | Threshold: 0.02504
# Epoch 15 | Train loss: 0.00684 | Val loss: 0.01056 | Combo score: 0.502 | Smoothed: 0.486 | MCC: 0.388 | REC: 0.778 | PRE: 0.333 | AUC: 0.795 | Threshold: 0.01367
# Epoch 16 | Train loss: 0.00518 | Val loss: 0.00891 | Combo score: 0.456 | Smoothed: 0.483 | MCC: 0.283 | REC: 0.537 | PRE: 0.316 | AUC: 0.782 | Threshold: 0.01299
# Epoch 17 | Train loss: 0.00470 | Val loss: 0.00800 | Combo score: 0.451 | Smoothed: 0.480 | MCC: 0.278 | REC: 0.485 | PRE: 0.329 | AUC: 0.770 | Threshold: 0.01256
# Epoch 18 | Train loss: 0.00426 | Val loss: 0.00769 | Combo score: 0.478 | Smoothed: 0.480 | MCC: 0.314 | REC: 0.874 | PRE: 0.252 | AUC: 0.771 | Threshold: 0.00616
# Epoch 19 | Train loss: 0.00432 | Val loss: 0.00730 | Combo score: 0.446 | Smoothed: 0.476 | MCC: 0.273 | REC: 0.389 | PRE: 0.367 | AUC: 0.765 | Threshold: 0.01346
# Epoch 20 | Train loss: 0.00378 | Val loss: 0.00749 | Combo score: 0.467 | Smoothed: 0.475 | MCC: 0.287 | REC: 0.865 | PRE: 0.237 | AUC: 0.760 | Threshold: 0.00485
# Epoch 21 | Train loss: 0.00370 | Val loss: 0.00743 | Combo score: 0.458 | Smoothed: 0.474 | MCC: 0.295 | REC: 0.447 | PRE: 0.365 | AUC: 0.786 | Threshold: 0.01272
# Epoch 22 | Train loss: 0.00361 | Val loss: 0.00732 | Combo score: 0.459 | Smoothed: 0.472 | MCC: 0.304 | REC: 0.406 | PRE: 0.398 | AUC: 0.780 | Threshold: 0.01399
# Epoch 23 | Train loss: 0.00442 | Val loss: 0.00688 | Combo score: 0.467 | Smoothed: 0.472 | MCC: 0.326 | REC: 0.392 | PRE: 0.439 | AUC: 0.773 | Threshold: 0.01351
# Epoch 24 | Train loss: 0.00374 | Val loss: 0.00757 | Combo score: 0.462 | Smoothed: 0.471 | MCC: 0.312 | REC: 0.418 | PRE: 0.402 | AUC: 0.778 | Threshold: 0.01315
# Epoch 25 | Train loss: 0.00351 | Val loss: 0.00707 | Combo score: 0.458 | Smoothed: 0.469 | MCC: 0.300 | REC: 0.386 | PRE: 0.404 | AUC: 0.781 | Threshold: 0.01298
# Early stopping at epoch 25 (no improvement in smoothed or combo score over 10 epochs)
#
# --- Fold 11 summary (years: [2015, 2016]) ---
# Number of fire events in validation: (684 / 4907)
# Best epoch: 15
# Threshold used: 0.01367
# Validation metrics:
# ACC: 75.2%
# PRE: 33.3%
# REC: 77.8%
# MCC: 0.39
# AUC: 0.80
# ==================================================
#
# Model B training and evaluation complete.
